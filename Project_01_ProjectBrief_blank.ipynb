# %% [markdown]
# # Project 1: Explanatory Data Analysis & Data Presentation (Movies Dataset)

# %% [markdown]
# # Project Brief for Self-Coders

# %% [markdown]
# Here you´ll have the opportunity to code major parts of Project 1 on your own. If you need any help or inspiration, have a look at the Videos or the Jupyter Notebook with the full code. <br> <br>
# Keep in mind that it´s all about __getting the right results/conclusions__. It´s not about finding the identical code. Things can be coded in many different ways. Even if you come to the same conclusions, it´s very unlikely that we have the very same code.

# %% [markdown]
# ## Data Import and first Inspection

# %% [markdown]
# 1. __Import__ the movies dataset from the CSV file "movies_complete.csv". __Inspect__ the data.

# %% [markdown]
# __Some additional information on Features/Columns__:

# %% [markdown]
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %%
import pandas as pd
import numpy as np
from IPython.core.pylabtools import figsize
from IPython.display import HTML
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
movies = pd.read_csv('movies_complete.csv', index_col='id')

# %%
# movies.budget_musd.fillna(0, inplace=True)
# movies.revenue_musd.fillna(0, inplace=True)
# movies

# %% [markdown]
# ## The best and the worst movies...

# %% [markdown]
# 2. __Filter__ the Dataset and __find the best/worst n Movies__ with the

# %% [markdown]
# - Highest Revenue
# - Highest Budget
# - Highest Profit (=Revenue - Budget)
# - Lowest Profit (=Revenue - Budget)
# - Highest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Lowest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Highest number of Votes
# - Highest Rating (only movies with 10 or more Ratings)
# - Lowest Rating (only movies with 10 or more Ratings)
# - Highest Popularity

# %% [markdown]
# __Define__ an appropriate __user-defined function__ to reuse code.

# %% [markdown]
# __Movies Top 5 - Highest Revenue__

# %%
movies.sort_values('revenue_musd', ascending=False).head()
# Out:
#                                title  \
# id
# 19995                         Avatar
# 140607  Star Wars: The Force Awakens
# 597                          Titanic
# 24428                   The Avengers
# 135397                Jurassic World
#
#                                           tagline release_date  \
# id
# 19995                 Enter the World of Pandora.   2009-12-10
# 140607              Every generation has a story.   2015-12-15
# 597     Nothing on Earth could come between them.   1997-11-18
# 24428                     Some assembly required.   2012-04-25
# 135397                          The park is open.   2015-06-09
#
#                                            genres     belongs_to_collection  \
# id
# 19995    Action|Adventure|Fantasy|Science Fiction         Avatar Collection
# 140607   Action|Adventure|Science Fiction|Fantasy      Star Wars Collection
# 597                        Drama|Romance|Thriller                       NaN
# 24428            Science Fiction|Action|Adventure   The Avengers Collection
# 135397  Action|Adventure|Science Fiction|Thriller  Jurassic Park Collection
#
#        original_language  budget_musd  revenue_musd  \
# id
# 19995                 en        237.0   2787.965087
# 140607                en        245.0   2068.223624
# 597                   en        200.0   1845.034188
# 24428                 en        220.0   1519.557910
# 135397                en        150.0   1513.528810
#
#                                      production_companies  \
# id
# 19995   Ingenious Film Partners|Twentieth Century Fox ...
# 140607          Lucasfilm|Truenorth Productions|Bad Robot
# 597     Paramount Pictures|Twentieth Century Fox Film ...
# 24428                   Paramount Pictures|Marvel Studios
# 135397  Universal Studios|Amblin Entertainment|Legenda...
#
#                            production_countries  ...  vote_average  \
# id                                               ...
# 19995   United States of America|United Kingdom  ...           7.2
# 140607                 United States of America  ...           7.5
# 597                    United States of America  ...           7.5
# 24428                  United States of America  ...           7.4
# 135397                 United States of America  ...           6.5
#
#         popularity  runtime  \
# id
# 19995   185.070892    162.0
# 140607   31.626013    136.0
# 597      26.889070    194.0
# 24428    89.887648    143.0
# 135397   32.790475    124.0
#
#                                                  overview  \
# id
# 19995   In the 22nd century, a paraplegic Marine is di...
# 140607  Thirty years after defeating the Galactic Empi...
# 597     84 years later, a 101-year-old woman named Ros...
# 24428   When an unexpected enemy emerges and threatens...
# 135397  Twenty-two years after the events of Jurassic ...
#
#                                          spoken_languages  \
# id
# 19995                                     English|Español
# 140607                                            English
# 597     English|Français|Deutsch|svenska|Italiano|Pусский
# 24428                                             English
# 135397                                            English
#
#                                               poster_path  \
# id
# 19995   <img src='http://image.tmdb.org/t/p/w185//btnl...
# 140607  <img src='http://image.tmdb.org/t/p/w185//9rd0...
# 597     <img src='http://image.tmdb.org/t/p/w185//9xjZ...
# 24428   <img src='http://image.tmdb.org/t/p/w185//RYMX...
# 135397  <img src='http://image.tmdb.org/t/p/w185//rhr4...
#
#                                                      cast cast_size  \
# id
# 19995   Sam Worthington|Zoe Saldana|Sigourney Weaver|S...        83
# 140607  Daisy Ridley|John Boyega|Adam Driver|Harrison ...        84
# 597     Kate Winslet|Leonardo DiCaprio|Frances Fisher|...       136
# 24428   Robert Downey Jr.|Chris Evans|Mark Ruffalo|Chr...       115
# 135397  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...        28
#
#         crew_size         director
# id
# 19995         153    James Cameron
# 140607        113      J.J. Abrams
# 597            65    James Cameron
# 24428         147      Joss Whedon
# 135397        435  Colin Trevorrow
#
# [5 rows x 21 columns]

# %% [markdown]
# __Movies Top 5 - Highest Budget__

# %%
movies.sort_values('budget_musd', ascending=False).head()
# Out:
#                                               title  \
# id
# 1865    Pirates of the Caribbean: On Stranger Tides
# 285        Pirates of the Caribbean: At World's End
# 99861                       Avengers: Age of Ultron
# 1452                               Superman Returns
# 335988                Transformers: The Last Knight
#
#                                                tagline release_date  \
# id
# 1865                       Live Forever Or Die Trying.   2011-05-14
# 285     At the end of the world, the adventure begins.   2007-05-19
# 99861                              A New Age Has Come.   2015-04-22
# 1452                                               NaN   2006-06-28
# 335988      For one world to live, the other must die.   2017-06-21
#
#                                            genres  \
# id
# 1865                     Adventure|Action|Fantasy
# 285                      Adventure|Fantasy|Action
# 99861            Action|Adventure|Science Fiction
# 1452     Adventure|Fantasy|Action|Science Fiction
# 335988  Action|Science Fiction|Thriller|Adventure
#
#                       belongs_to_collection original_language  budget_musd  \
# id
# 1865    Pirates of the Caribbean Collection                en        380.0
# 285     Pirates of the Caribbean Collection                en        300.0
# 99861               The Avengers Collection                en        280.0
# 1452                    Superman Collection                en        270.0
# 335988              Transformers Collection                en        260.0
#
#         revenue_musd                               production_companies  \
# id
# 1865     1045.713802  Walt Disney Pictures|Jerry Bruckheimer Films|M...
# 285       961.000000  Walt Disney Pictures|Jerry Bruckheimer Films|S...
# 99861    1405.403694  Marvel Studios|Prime Focus|Revolution Sun Studios
# 1452      391.081192  DC Comics|Legendary Pictures|Warner Bros.|Bad ...
# 335988    604.942143  Paramount Pictures|Di Bonaventura Pictures|Ang...
#
#             production_countries  ...  vote_average  popularity  runtime  \
# id                                ...
# 1865    United States of America  ...           6.4   27.887720    136.0
# 285     United States of America  ...           6.9   31.363664    169.0
# 99861   United States of America  ...           7.3   37.379420    141.0
# 1452    United States of America  ...           5.4   13.284712    154.0
# 335988  United States of America  ...           6.2   39.186819    149.0
#
#                                                  overview  \
# id
# 1865    Captain Jack Sparrow crosses paths with a woma...
# 285     Captain Barbossa, long believed to be dead, ha...
# 99861   When Tony Stark tries to jumpstart a dormant p...
# 1452    Superman returns to discover his 5-year absenc...
# 335988  Autobots and Decepticons are at war, with huma...
#
#                 spoken_languages  \
# id
# 1865             English|Español
# 285                      English
# 99861                    English
# 1452    English|Français|Deutsch
# 335988                   English
#
#                                               poster_path  \
# id
# 1865    <img src='http://image.tmdb.org/t/p/w185//keGf...
# 285     <img src='http://image.tmdb.org/t/p/w185//oVh3...
# 99861   <img src='http://image.tmdb.org/t/p/w185//4ssD...
# 1452    <img src='http://image.tmdb.org/t/p/w185//6ZYO...
# 335988  <img src='http://image.tmdb.org/t/p/w185//s5HQ...
#
#                                                      cast cast_size  \
# id
# 1865    Johnny Depp|Penélope Cruz|Ian McShane|Kevin Mc...        36
# 285     Johnny Depp|Orlando Bloom|Keira Knightley|Stel...        34
# 99861   Robert Downey Jr.|Chris Hemsworth|Mark Ruffalo...        72
# 1452    Brandon Routh|Kevin Spacey|Kate Bosworth|James...        18
# 335988  Mark Wahlberg|Josh Duhamel|Laura Haddock|Antho...       110
#
#         crew_size        director
# id
# 1865           39    Rob Marshall
# 285            32  Gore Verbinski
# 99861          74     Joss Whedon
# 1452           24    Bryan Singer
# 335988         51     Michael Bay
#
# [5 rows x 21 columns]

# %% [markdown]
# __Movies Top 5 - Highest Profit__

# %%
movies['gross_profit_musd'] = movies['revenue_musd'] - movies['budget_musd']

# %%
column_order = ['title', 'tagline', 'release_date', 'genres', 'belongs_to_collection',
       'original_language', 'budget_musd', 'revenue_musd',
       'gross_profit_musd',
       'production_companies', 'production_countries', 'vote_count',
       'vote_average', 'popularity', 'runtime', 'overview', 'spoken_languages',
       'poster_path', 'cast', 'cast_size', 'crew_size', 'director']

# %%
movies =movies[column_order]

# %%
movies.loc[movies.budget_musd >= 5].sort_values('gross_profit_musd', ascending=False).head()
# Out:
#                                title  \
# id
# 19995                         Avatar
# 140607  Star Wars: The Force Awakens
# 597                          Titanic
# 135397                Jurassic World
# 168259                     Furious 7
#
#                                           tagline release_date  \
# id
# 19995                 Enter the World of Pandora.   2009-12-10
# 140607              Every generation has a story.   2015-12-15
# 597     Nothing on Earth could come between them.   1997-11-18
# 135397                          The park is open.   2015-06-09
# 168259                        Vengeance Hits Home   2015-04-01
#
#                                            genres  \
# id
# 19995    Action|Adventure|Fantasy|Science Fiction
# 140607   Action|Adventure|Science Fiction|Fantasy
# 597                        Drama|Romance|Thriller
# 135397  Action|Adventure|Science Fiction|Thriller
# 168259                                     Action
#
#                       belongs_to_collection original_language  budget_musd  \
# id
# 19995                     Avatar Collection                en        237.0
# 140607                 Star Wars Collection                en        245.0
# 597                                     NaN                en        200.0
# 135397             Jurassic Park Collection                en        150.0
# 168259  The Fast and the Furious Collection                en        190.0
#
#         revenue_musd  gross_profit_musd  \
# id
# 19995    2787.965087        2550.965087
# 140607   2068.223624        1823.223624
# 597      1845.034188        1645.034188
# 135397   1513.528810        1363.528810
# 168259   1506.249360        1316.249360
#
#                                      production_companies  ... vote_average  \
# id                                                         ...
# 19995   Ingenious Film Partners|Twentieth Century Fox ...  ...          7.2
# 140607          Lucasfilm|Truenorth Productions|Bad Robot  ...          7.5
# 597     Paramount Pictures|Twentieth Century Fox Film ...  ...          7.5
# 135397  Universal Studios|Amblin Entertainment|Legenda...  ...          6.5
# 168259  Universal Pictures|Original Film|Fuji Televisi...  ...          7.3
#
#         popularity  runtime  \
# id
# 19995   185.070892    162.0
# 140607   31.626013    136.0
# 597      26.889070    194.0
# 135397   32.790475    124.0
# 168259   27.275687    137.0
#
#                                                  overview  \
# id
# 19995   In the 22nd century, a paraplegic Marine is di...
# 140607  Thirty years after defeating the Galactic Empi...
# 597     84 years later, a 101-year-old woman named Ros...
# 135397  Twenty-two years after the events of Jurassic ...
# 168259  Deckard Shaw seeks revenge against Dominic Tor...
#
#                                          spoken_languages  \
# id
# 19995                                     English|Español
# 140607                                            English
# 597     English|Français|Deutsch|svenska|Italiano|Pусский
# 135397                                            English
# 168259                                            English
#
#                                               poster_path  \
# id
# 19995   <img src='http://image.tmdb.org/t/p/w185//btnl...
# 140607  <img src='http://image.tmdb.org/t/p/w185//9rd0...
# 597     <img src='http://image.tmdb.org/t/p/w185//9xjZ...
# 135397  <img src='http://image.tmdb.org/t/p/w185//rhr4...
# 168259  <img src='http://image.tmdb.org/t/p/w185//d9jZ...
#
#                                                      cast cast_size crew_size  \
# id
# 19995   Sam Worthington|Zoe Saldana|Sigourney Weaver|S...        83       153
# 140607  Daisy Ridley|John Boyega|Adam Driver|Harrison ...        84       113
# 597     Kate Winslet|Leonardo DiCaprio|Frances Fisher|...       136        65
# 135397  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...        28       435
# 168259  Vin Diesel|Paul Walker|Dwayne Johnson|Michelle...        52        98
#
#                director
# id
# 19995     James Cameron
# 140607      J.J. Abrams
# 597       James Cameron
# 135397  Colin Trevorrow
# 168259        James Wan
#
# [5 rows x 22 columns]

# %% [markdown]
# p__Movies Top 5 - Lowest Profit__

# %%
movies.loc[movies.budget_musd >= 5].sort_values('gross_profit_musd', ascending=True).head()
# Out:
#                                               title  \
# id
# 57201                               The Lone Ranger
# 10733                                     The Alamo
# 50321                               Mars Needs Moms
# 339964  Valerian and the City of a Thousand Planets
# 1911                               The 13th Warrior
#
#                           tagline release_date  \
# id
# 57201     Never Take Off the Mask   2013-07-03
# 10733       You will never forget   2004-04-07
# 50321   Mom needs a little space.   2011-03-09
# 339964                        NaN   2017-07-20
# 1911         Prey for the living.   1999-08-27
#
#                                   genres belongs_to_collection  \
# id
# 57201           Action|Adventure|Western                   NaN
# 10733                Western|History|War                   NaN
# 50321         Adventure|Animation|Family                   NaN
# 339964  Adventure|Science Fiction|Action                   NaN
# 1911            Adventure|Fantasy|Action                   NaN
#
#        original_language  budget_musd  revenue_musd  gross_profit_musd  \
# id
# 57201                 en   255.000000     89.289910        -165.710090
# 10733                 en   145.000000     25.819961        -119.180039
# 50321                 en   150.000000     38.992758        -111.007242
# 339964                en   197.471676     90.024292        -107.447384
# 1911                  en   160.000000     61.698899         -98.301101
#
#                                      production_companies  ... vote_average  \
# id                                                         ...
# 57201   Walt Disney Pictures|Jerry Bruckheimer Films|I...  ...          5.9
# 10733           Imagine Entertainment|Touchstone Pictures  ...          5.8
# 50321                       Walt Disney Animation Studios  ...          5.6
# 339964                                         EuropaCorp  ...          6.7
# 1911                                  Touchstone Pictures  ...          6.4
#
#         popularity  runtime  \
# id
# 57201    12.729104    149.0
# 10733    12.240901    137.0
# 50321     7.247170     88.0
# 339964   15.262706    137.0
# 1911     10.308026    102.0
#
#                                                  overview  spoken_languages  \
# id
# 57201   The Texas Rangers chase down a gang of outlaws...           English
# 10733   Based on the 1836 standoff between a group of ...   English|Español
# 50321   When Martians suddenly abduct his mom, mischie...           English
# 339964  In the 28th century, Valerian and Laureline ar...  Français|English
# 1911    In AD 922, Arab courtier, Ahmad Ibn Fadlan acc...     English|Norsk
#
#                                               poster_path  \
# id
# 57201   <img src='http://image.tmdb.org/t/p/w185//b2je...
# 10733   <img src='http://image.tmdb.org/t/p/w185//aZrW...
# 50321   <img src='http://image.tmdb.org/t/p/w185//lOKq...
# 339964  <img src='http://image.tmdb.org/t/p/w185//jfIp...
# 1911    <img src='http://image.tmdb.org/t/p/w185//7pyh...
#
#                                                      cast cast_size crew_size  \
# id
# 57201   Johnny Depp|Armie Hammer|William Fichtner|Hele...        60        35
# 10733   Dennis Quaid|Billy Bob Thornton|Jason Patric|P...        20       145
# 50321   Seth Green|Joan Cusack|Dan Fogler|Breckin Meye...        12         7
# 339964  Dane DeHaan|Cara Delevingne|Clive Owen|Rihanna...       118       316
# 1911    Antonio Banderas|Vladimir Kulich|Dennis Storhø...        19        17
#
#                 director
# id
# 57201     Gore Verbinski
# 10733   John Lee Hancock
# 50321        Simon Wells
# 339964        Luc Besson
# 1911      John McTiernan
#
# [5 rows x 22 columns]

# %% [markdown]
# __Movies Top 5 - Highest ROI__

# %%
movies['ROI'] = movies['revenue_musd'] / movies['budget_musd']

# %%
column_order = ['title', 'tagline', 'release_date', 'genres', 'belongs_to_collection',
       'original_language', 'budget_musd', 'revenue_musd',
       'gross_profit_musd', 'ROI',
       'production_companies', 'production_countries', 'vote_count',
       'vote_average', 'popularity', 'runtime', 'overview', 'spoken_languages',
       'poster_path', 'cast', 'cast_size', 'crew_size', 'director']

# %%
movies =movies[column_order]

# %%
movies.loc[movies.budget_musd >= 5].sort_values('ROI', ascending=False)
# Out:
#                                                  title  \
# id
# 601                         E.T. the Extra-Terrestrial
# 8346                          My Big Fat Greek Wedding
# 11                                           Star Wars
# 578                                               Jaws
# 9671                                  Crocodile Dundee
# ...                                                ...
# 59914                     The Blonde with Bare Breasts
# 407448                                         Detroit
# 277839  Good Guys Go to Heaven, Bad Guys Go to Pattaya
# 248705                      The Visitors: Bastille Day
# 39164                        House of the Long Shadows
#
#                                                   tagline release_date  \
# id
# 601     He is afraid. He is alone. He is three million...   1982-04-03
# 8346            Love is here to stay... so is her family.   2002-02-22
# 11           A long time ago in a galaxy far, far away...   1977-05-25
# 578                                Don't go in the water.   1975-06-18
# 9671                There's a little of him in all of us.   1986-09-26
# ...                                                   ...          ...
# 59914                                                 NaN   2010-07-21
# 407448                                  It's time we knew   2017-07-28
# 277839                                                NaN   2016-02-24
# 248705                                                NaN   2016-03-23
# 39164                                                 NaN   1983-06-17
#
#                                           genres  \
# id
# 601     Science Fiction|Adventure|Family|Fantasy
# 8346                        Comedy|Drama|Romance
# 11              Adventure|Action|Science Fiction
# 578                    Horror|Thriller|Adventure
# 9671                            Adventure|Comedy
# ...                                          ...
# 59914                               Comedy|Drama
# 407448              Thriller|Crime|Drama|History
# 277839                                    Comedy
# 248705                                    Comedy
# 39164                      Horror|Comedy|Mystery
#
#                       belongs_to_collection original_language  budget_musd  \
# id
# 601                                     NaN                en    10.500000
# 8346    My Big Fat Greek Wedding Collection                en     5.000000
# 11                     Star Wars Collection                en    11.000000
# 578                     The Jaws Collection                en     7.000000
# 9671            Crocodile Dundee Collection                en     5.000000
# ...                                     ...               ...          ...
# 59914                                   NaN                en     7.500000
# 407448                                  NaN                en    34.000000
# 277839                                  NaN                fr     5.402000
# 248705              The Visitors Collection                fr    25.868826
# 39164                                   NaN                en     7.500000
#
#         revenue_musd  gross_profit_musd        ROI  ... vote_average  \
# id                                                  ...
# 601       792.965326         782.465326  75.520507  ...          7.3
# 8346      368.744044         363.744044  73.748809  ...          6.2
# 11        775.398007         764.398007  70.490728  ...          8.1
# 578       470.654000         463.654000  67.236286  ...          7.5
# 9671      328.203506         323.203506  65.640701  ...          6.3
# ...              ...                ...        ...  ...          ...
# 59914            NaN                NaN        NaN  ...          4.0
# 407448           NaN                NaN        NaN  ...          7.3
# 277839           NaN                NaN        NaN  ...          5.3
# 248705           NaN                NaN        NaN  ...          4.0
# 39164            NaN                NaN        NaN  ...          6.1
#
#        popularity  runtime                                           overview  \
# id
# 601     19.358546    115.0  After a gentle alien becomes stranded on Earth...
# 8346     6.719949     95.0  A young Greek woman falls in love with a non-G...
# 11      42.149697    121.0  Princess Leia is captured and held hostage by ...
# 578     19.726114    124.0  An insatiable great white shark terrorizes the...
# 9671     7.791212     97.0  When a New York reporter plucks crocodile hunt...
# ...           ...      ...                                                ...
# 59914    0.882188    100.0  Julian, 25, and Louis, 12, are two brothers wh...
# 407448   9.797505    143.0  A police raid in Detroit in 1967 results in on...
# 277839   5.613875    100.0  Franky and Krimo dream of leaving the grey gri...
# 248705   7.294920    110.0  Stuck in the corridors of time, Godefroy de Mo...
# 39164    1.185515    100.0  An American writer goes to a remote Welsh mano...
#
#         spoken_languages                                        poster_path  \
# id
# 601              English  <img src='http://image.tmdb.org/t/p/w185//cBfk...
# 8346    ελληνικά|English  <img src='http://image.tmdb.org/t/p/w185//3TB2...
# 11               English  <img src='http://image.tmdb.org/t/p/w185//6FfC...
# 578              English  <img src='http://image.tmdb.org/t/p/w185//s2xc...
# 9671             English  <img src='http://image.tmdb.org/t/p/w185//kiwO...
# ...                  ...                                                ...
# 59914           Français  <img src='http://image.tmdb.org/t/p/w185//zBjp...
# 407448           English  <img src='http://image.tmdb.org/t/p/w185//7APL...
# 277839          Français  <img src='http://image.tmdb.org/t/p/w185//cfVB...
# 248705          Français  <img src='http://image.tmdb.org/t/p/w185//kBlm...
# 39164            English  <img src='http://image.tmdb.org/t/p/w185//21ZG...
#
#                                                      cast cast_size crew_size  \
# id
# 601     Henry Thomas|Drew Barrymore|Robert MacNaughton...        13        21
# 8346    Nia Vardalos|John Corbett|Lainie Kazan|Michael...        16         9
# 11      Mark Hamill|Harrison Ford|Carrie Fisher|Peter ...       106        20
# 578     Roy Scheider|Robert Shaw|Richard Dreyfuss|Lorr...        29        28
# 9671    Paul Hogan|Linda Kozlowski|Mark Blum|David Gul...        10        10
# ...                                                   ...       ...       ...
# 59914   Vahina Giocante|Nicolas Duvauchelle|Steve Le R...         5         2
# 407448  John Boyega|Will Poulter|Algee Smith|Jason Mit...        46        32
# 277839  Ramzy Bedia|Malik Bentalha|Franck Gastambide|G...        19        10
# 248705  Jean Reno|Christian Clavier|Franck Dubosc|Kari...        41         3
# 39164   Vincent Price|Christopher Lee|Peter Cushing|De...        11        12
#
#                  director
# id
# 601      Steven Spielberg
# 8346           Joel Zwick
# 11           George Lucas
# 578      Steven Spielberg
# 9671         Peter Faiman
# ...                   ...
# 59914       Manuel Pradal
# 407448    Kathryn Bigelow
# 277839  Franck Gastambide
# 248705   Jean-Marie Poiré
# 39164         Pete Walker
#
# [5449 rows x 23 columns]

# %% [markdown]
# __Movies Top 5 - Lowest ROI__

# %%
movies.loc[movies.budget_musd >= 5].sort_values('ROI', ascending=True)
# Out:
#                                                  title  \
# id
# 14844                                  Chasing Liberty
# 18475                                      The Cookout
# 48781                          Never Talk to Strangers
# 33927                                         Deadfall
# 10944                                       In the Cut
# ...                                                ...
# 59914                     The Blonde with Bare Breasts
# 407448                                         Detroit
# 277839  Good Guys Go to Heaven, Bad Guys Go to Pattaya
# 248705                      The Visitors: Bastille Day
# 39164                        House of the Long Shadows
#
#                                                   tagline release_date  \
# id
# 14844   How do you fall in love with the whole world w...   2004-01-09
# 18475                     This summer, get your grill on!   2004-09-03
# 48781   In A World Where Love Isn't Always Safe, Trust...   1995-10-20
# 33927                                 ...The ultimate con   1993-10-08
# 10944     Everything you know about desire is dead wrong.   2003-09-09
# ...                                                   ...          ...
# 59914                                                 NaN   2010-07-21
# 407448                                  It's time we knew   2017-07-28
# 277839                                                NaN   2016-02-24
# 248705                                                NaN   2016-03-23
# 39164                                                 NaN   1983-06-17
#
#                               genres    belongs_to_collection  \
# id
# 14844                 Comedy|Romance                      NaN
# 18475                   Comedy|Drama                      NaN
# 48781               Thriller|Romance                      NaN
# 33927           Crime|Drama|Thriller                      NaN
# 10944               Mystery|Thriller                      NaN
# ...                              ...                      ...
# 59914                   Comedy|Drama                      NaN
# 407448  Thriller|Crime|Drama|History                      NaN
# 277839                        Comedy                      NaN
# 248705                        Comedy  The Visitors Collection
# 39164          Horror|Comedy|Mystery                      NaN
#
#        original_language  budget_musd  revenue_musd  gross_profit_musd  \
# id
# 14844                 en    23.000000      0.000012         -22.999988
# 18475                 en    16.000000      0.000012         -15.999988
# 48781                 en     6.400000      0.000006          -6.399994
# 33927                 en    10.000000      0.000018          -9.999982
# 10944                 en    12.000000      0.000023         -11.999977
# ...                  ...          ...           ...                ...
# 59914                 en     7.500000           NaN                NaN
# 407448                en    34.000000           NaN                NaN
# 277839                fr     5.402000           NaN                NaN
# 248705                fr    25.868826           NaN                NaN
# 39164                 en     7.500000           NaN                NaN
#
#                  ROI  ... vote_average popularity  runtime  \
# id                    ...
# 14844   5.217391e-07  ...          6.1   5.950792    111.0
# 18475   7.500000e-07  ...          4.6   1.758079     97.0
# 48781   9.375000e-07  ...          4.7   7.506958     86.0
# 33927   1.800000e-06  ...          3.1   1.145806     98.0
# 10944   1.916667e-06  ...          4.7   5.799628    119.0
# ...              ...  ...          ...        ...      ...
# 59914            NaN  ...          4.0   0.882188    100.0
# 407448           NaN  ...          7.3   9.797505    143.0
# 277839           NaN  ...          5.3   5.613875    100.0
# 248705           NaN  ...          4.0   7.294920    110.0
# 39164            NaN  ...          6.1   1.185515    100.0
#
#                                                  overview  \
# id
# 14844   The President's daughter, unable to experience...
# 18475   When Todd Anderson signs a $30 million deal wi...
# 48781   Sarah Taylor, a police psychologist, meets a m...
# 33927   After he accidentally kills his father, Mike, ...
# 10944   Following the gruesome murder of a young woman...
# ...                                                   ...
# 59914   Julian, 25, and Louis, 12, are two brothers wh...
# 407448  A police raid in Detroit in 1967 results in on...
# 277839  Franky and Krimo dream of leaving the grey gri...
# 248705  Stuck in the corridors of time, Godefroy de Mo...
# 39164   An American writer goes to a remote Welsh mano...
#
#                                          spoken_languages  \
# id
# 14844   English|Français|עִבְרִית|Italiano|Español|Deu...
# 18475                                             English
# 48781                                             English
# 33927                                     English|Español
# 10944                                             English
# ...                                                   ...
# 59914                                            Français
# 407448                                            English
# 277839                                           Français
# 248705                                           Français
# 39164                                             English
#
#                                               poster_path  \
# id
# 14844   <img src='http://image.tmdb.org/t/p/w185//7qzv...
# 18475   <img src='http://image.tmdb.org/t/p/w185//eUVE...
# 48781   <img src='http://image.tmdb.org/t/p/w185//IHZZ...
# 33927   <img src='http://image.tmdb.org/t/p/w185//kgfv...
# 10944   <img src='http://image.tmdb.org/t/p/w185//lcor...
# ...                                                   ...
# 59914   <img src='http://image.tmdb.org/t/p/w185//zBjp...
# 407448  <img src='http://image.tmdb.org/t/p/w185//7APL...
# 277839  <img src='http://image.tmdb.org/t/p/w185//cfVB...
# 248705  <img src='http://image.tmdb.org/t/p/w185//kBlm...
# 39164   <img src='http://image.tmdb.org/t/p/w185//21ZG...
#
#                                                      cast cast_size crew_size  \
# id
# 14844   Mandy Moore|Stark Sands|Tony Jayawardena|Jerem...        11        26
# 18475   Ja Rule|Tim Meadows|Jenifer Lewis|Jonathan Sil...         6         4
# 48781   Rebecca De Mornay|Antonio Banderas|Dennis Mill...         7         3
# 33927   Michael Biehn|Sarah Trigger|Nicolas Cage|James...        12         3
# 10944   Meg Ryan|Mark Ruffalo|Jennifer Jason Leigh|Nic...         6        25
# ...                                                   ...       ...       ...
# 59914   Vahina Giocante|Nicolas Duvauchelle|Steve Le R...         5         2
# 407448  John Boyega|Will Poulter|Algee Smith|Jason Mit...        46        32
# 277839  Ramzy Bedia|Malik Bentalha|Franck Gastambide|G...        19        10
# 248705  Jean Reno|Christian Clavier|Franck Dubosc|Kari...        41         3
# 39164   Vincent Price|Christopher Lee|Peter Cushing|De...        11        12
#
#                    director
# id
# 14844           Andy Cadiff
# 18475          Lance Rivera
# 48781            Peter Hall
# 33927   Christopher Coppola
# 10944          Jane Campion
# ...                     ...
# 59914         Manuel Pradal
# 407448      Kathryn Bigelow
# 277839    Franck Gastambide
# 248705     Jean-Marie Poiré
# 39164           Pete Walker
#
# [5449 rows x 23 columns]

# %% [markdown]
# __Movies Top 5 - Most Votes__

# %%
movies.loc[movies.budget_musd >= 5].sort_values('vote_count', ascending=False).head()
# Out:
#                   title                                  tagline release_date  \
# id
# 27205         Inception     Your mind is the scene of the crime.   2010-07-14
# 155     The Dark Knight                          Why So Serious?   2008-07-16
# 19995            Avatar              Enter the World of Pandora.   2009-12-10
# 24428      The Avengers                  Some assembly required.   2012-04-25
# 293660         Deadpool  Witness the beginning of a happy ending   2016-02-09
#
#                                                    genres  \
# id
# 27205   Action|Thriller|Science Fiction|Mystery|Adventure
# 155                           Drama|Action|Crime|Thriller
# 19995            Action|Adventure|Fantasy|Science Fiction
# 24428                    Science Fiction|Action|Adventure
# 293660                            Action|Adventure|Comedy
#
#              belongs_to_collection original_language  budget_musd  \
# id
# 27205                          NaN                en        160.0
# 155     The Dark Knight Collection                en        185.0
# 19995            Avatar Collection                en        237.0
# 24428      The Avengers Collection                en        220.0
# 293660         Deadpool Collection                en         58.0
#
#         revenue_musd  gross_profit_musd        ROI  ... vote_average  \
# id                                                  ...
# 27205     825.532764         665.532764   5.159580  ...          8.1
# 155      1004.558444         819.558444   5.430046  ...          8.3
# 19995    2787.965087        2550.965087  11.763566  ...          7.2
# 24428    1519.557910        1299.557910   6.907081  ...          7.4
# 293660    783.112979         725.112979  13.501948  ...          7.4
#
#         popularity  runtime  \
# id
# 27205    29.108149    148.0
# 155     123.167259    152.0
# 19995   185.070892    162.0
# 24428    89.887648    143.0
# 293660  187.860492    108.0
#
#                                                  overview  spoken_languages  \
# id
# 27205   Cobb, a skilled thief who commits corporate es...           English
# 155     Batman raises the stakes in his war on crime. ...       English|普通话
# 19995   In the 22nd century, a paraplegic Marine is di...   English|Español
# 24428   When an unexpected enemy emerges and threatens...           English
# 293660  Deadpool tells the origin story of former Spec...           English
#
#                                               poster_path  \
# id
# 27205   <img src='http://image.tmdb.org/t/p/w185//9gk7...
# 155     <img src='http://image.tmdb.org/t/p/w185//qJ2t...
# 19995   <img src='http://image.tmdb.org/t/p/w185//btnl...
# 24428   <img src='http://image.tmdb.org/t/p/w185//RYMX...
# 293660  <img src='http://image.tmdb.org/t/p/w185//fSRb...
#
#                                                      cast cast_size crew_size  \
# id
# 27205   Leonardo DiCaprio|Joseph Gordon-Levitt|Ellen P...        29        18
# 155     Christian Bale|Michael Caine|Heath Ledger|Aaro...       134        81
# 19995   Sam Worthington|Zoe Saldana|Sigourney Weaver|S...        83       153
# 24428   Robert Downey Jr.|Chris Evans|Mark Ruffalo|Chr...       115       147
# 293660  Ryan Reynolds|Morena Baccarin|Ed Skrein|T.J. M...        46        88
#
#                  director
# id
# 27205   Christopher Nolan
# 155     Christopher Nolan
# 19995       James Cameron
# 24428         Joss Whedon
# 293660         Tim Miller
#
# [5 rows x 23 columns]

# %% [markdown]
# __Movies Top 5 - Highest Rating__

# %%
movies.loc[movies.budget_musd >= 5].sort_values('vote_average', ascending=False).head()
# Out:
#                               title  \
# id
# 19404   Dilwale Dulhania Le Jayenge
# 153779       The Kingdom of Solomon
# 359364                        Human
# 88641            There Goes My Baby
# 238                   The Godfather
#
#                                                   tagline release_date  \
# id
# 19404                                Come... Fall In Love   1995-10-20
# 153779                                                NaN   2010-10-06
# 359364  Accepting your true identity is accepting who ...   2015-09-12
# 88641                                                 NaN   1994-09-02
# 238                            An offer you can't refuse.   1972-03-14
#
#                       genres     belongs_to_collection original_language  \
# id
# 19404   Comedy|Drama|Romance                       NaN                hi
# 153779         Drama|History                       NaN                en
# 359364           Documentary                       NaN                fr
# 88641           Drama|Comedy                       NaN                en
# 238              Drama|Crime  The Godfather Collection                en
#
#         budget_musd  revenue_musd  gross_profit_musd        ROI  ...  \
# id                                                               ...
# 19404          13.2    100.000000          86.800000   7.575758  ...
# 153779          5.0           NaN                NaN        NaN  ...
# 359364         13.0           NaN                NaN        NaN  ...
# 88641          10.5      0.123509         -10.376491   0.011763  ...
# 238             6.0    245.066411         239.066411  40.844402  ...
#
#        vote_average popularity  runtime  \
# id
# 19404           9.1  34.457024    190.0
# 153779          9.0   1.027956    110.0
# 359364          8.6   3.845853    263.0
# 88641           8.5   0.377787     99.0
# 238             8.5  41.109264    175.0
#
#                                                  overview  \
# id
# 19404   Raj is a rich, carefree, happy-go-lucky second...
# 153779  Solomon, Prophet and the King, has asked God t...
# 359364  A combination of first-person stories and excl...
# 88641   A group of high school seniors meets in the su...
# 238     Spanning the years 1945 to 1955, a chronicle o...
#
#                                          spoken_languages  \
# id
# 19404                                              हिन्दी
# 153779                                       فارسی|Türkçe
# 359364  Pусский|ελληνικά|English|Español|Français|Ital...
# 88641                                             English
# 238                                English|Italiano|Latin
#
#                                               poster_path  \
# id
# 19404   <img src='http://image.tmdb.org/t/p/w185//2CAL...
# 153779  <img src='http://image.tmdb.org/t/p/w185//j24f...
# 359364  <img src='http://image.tmdb.org/t/p/w185//vdZg...
# 88641   <img src='http://image.tmdb.org/t/p/w185//7jXj...
# 238     <img src='http://image.tmdb.org/t/p/w185//iVZ3...
#
#                                                      cast cast_size crew_size  \
# id
# 19404   Shah Rukh Khan|Kajol|Amrish Puri|Anupam Kher|S...        27        30
# 153779                                                NaN         0         2
# 359364                                         Luis Cancu         1         8
# 88641   Dermot Mulroney|Ricky Schroder|Kelli Williams|...         9        15
# 238     Marlon Brando|Al Pacino|James Caan|Richard S. ...        58        42
#
#                     director
# id
# 19404          Aditya Chopra
# 153779      Shahriar Bahrani
# 359364  Yann Arthus-Bertrand
# 88641           Floyd Mutrux
# 238     Francis Ford Coppola
#
# [5 rows x 23 columns]

# %% [markdown]
# __Movies Top 5 - Lowest Rating__

# %%
movies.loc[movies.budget_musd >= 5].sort_values('vote_average', ascending=True).head()
# Out:
#                         title tagline release_date  \
# id
# 111744            Joe and Max     NaN   2002-03-03
# 63898                 Antidur     NaN   2007-09-06
# 220669                Королёв     NaN   2007-10-29
# 42078   Elf Bowling the Movie     NaN   2007-10-02
# 272610             Black Rose     NaN   2014-04-17
#
#                              genres belongs_to_collection original_language  \
# id
# 111744               Drama|TV Movie                   NaN                en
# 63898   Action|Comedy|Crime|Foreign                   NaN                ru
# 220669                        Drama                   NaN                ru
# 42078      Animation|Comedy|Fantasy                   NaN                en
# 272610           Drama|Crime|Action                   NaN                en
#
#         budget_musd  revenue_musd  gross_profit_musd       ROI  ...  \
# id                                                              ...
# 111744          8.0           NaN                NaN       NaN  ...
# 63898           5.0       1.41300           -3.58700  0.282600  ...
# 220669          6.0       0.03100           -5.96900  0.005167  ...
# 42078           6.5           NaN                NaN       NaN  ...
# 272610          7.0       0.85545           -6.14455  0.122207  ...
#
#        vote_average popularity  runtime  \
# id
# 111744          0.0   1.669115    109.0
# 63898           1.0   0.039793     91.0
# 220669          1.0   0.292296      NaN
# 42078           2.0   0.648653     82.0
# 272610          2.0   2.482771     83.0
#
#                                                  overview  \
# id
# 111744  True story of boxers Joe Louis and Max Schmeli...
# 63898   Failing to complete an important assignment wi...
# 220669                                                NaN
# 42078   So you think you know the real story behind Sa...
# 272610  A Russian Police Major is enlisted by the LAPD...
#
#                 spoken_languages  \
# id
# 111744  English|Deutsch|Italiano
# 63898                    Pусский
# 220669                       NaN
# 42078                    English
# 272610           English|Pусский
#
#                                               poster_path  \
# id
# 111744  <img src='http://image.tmdb.org/t/p/w185//1Ver...
# 63898   <img src='http://image.tmdb.org/t/p/w185//f5XO...
# 220669  <img src='http://image.tmdb.org/t/p/w185//mIYS...
# 42078   <img src='http://image.tmdb.org/t/p/w185//oFcH...
# 272610  <img src='http://image.tmdb.org/t/p/w185//zvyR...
#
#                                                      cast cast_size crew_size  \
# id
# 111744  Leonard Roberts|Til Schweiger|Peta Wilson|Rich...        11         2
# 63898   Vladimir Turchinsky|Dmitriy Dyuzhev|Tatyana Do...         4         1
# 220669                                     Sergei Astahov         1         2
# 42078                     Joe Alaskey|Sean Hart|Tom Kenny         3         2
# 272610  Alexander Nevsky|Kristanna Loken|Adrian Paul|R...         9         8
#
#                     director
# id
# 111744           Steve James
# 63898   Vladimir Shchegolkov
# 220669            Yuriy Kara
# 42078              Rex Piano
# 272610      Alexander Nevsky
#
# [5 rows x 23 columns]

# %% [markdown]
# __Movies Top 5 - Most Popular__

# %%
movies.loc[movies.budget_musd >= 5].sort_values('popularity', ascending=False).head()
# Out:
#                        title                                         tagline  \
# id
# 211672               Minions    Before Gru, they had a history of bad bosses
# 297762          Wonder Woman                   Power. Grace. Wisdom. Wonder.
# 321612  Beauty and the Beast                                   Be our guest.
# 339403           Baby Driver               All you need is one killer track.
# 177572            Big Hero 6  From the creators of Wreck-it Ralph and Frozen
#
#        release_date                                    genres  \
# id
# 211672   2015-06-17         Family|Animation|Adventure|Comedy
# 297762   2017-05-30                  Action|Adventure|Fantasy
# 321612   2017-03-16                    Family|Fantasy|Romance
# 339403   2017-06-28                              Action|Crime
# 177572   2014-10-24  Adventure|Family|Animation|Action|Comedy
#
#            belongs_to_collection original_language  budget_musd  revenue_musd  \
# id
# 211672  Despicable Me Collection                en         74.0   1156.730962
# 297762   Wonder Woman Collection                en        149.0    820.580447
# 321612                       NaN                en        160.0   1262.886337
# 339403                       NaN                en         34.0    224.511319
# 177572                       NaN                en        165.0    652.105443
#
#         gross_profit_musd        ROI  ... vote_average  popularity  runtime  \
# id                                    ...
# 211672        1082.730962  15.631499  ...          6.4  547.488298     91.0
# 297762         671.580447   5.507251  ...          7.2  294.337037    141.0
# 321612        1102.886337   7.893040  ...          6.8  287.253654    129.0
# 339403         190.511319   6.603274  ...          7.2  228.032744    113.0
# 177572         487.105443   3.952154  ...          7.8  213.849907    102.0
#
#                                                  overview  spoken_languages  \
# id
# 211672  Minions Stuart, Kevin and Bob are recruited by...           English
# 297762  An Amazon princess comes to the world of Man t...   Deutsch|English
# 321612  A live-action adaptation of Disney's version o...           English
# 339403  After being coerced into working for a crime b...           English
# 177572  The special bond that develops between plus-si...           English
#
#                                               poster_path  \
# id
# 211672  <img src='http://image.tmdb.org/t/p/w185//tMaG...
# 297762  <img src='http://image.tmdb.org/t/p/w185//gfJG...
# 321612  <img src='http://image.tmdb.org/t/p/w185//tWqi...
# 339403  <img src='http://image.tmdb.org/t/p/w185//rmnQ...
# 177572  <img src='http://image.tmdb.org/t/p/w185//xozr...
#
#                                                      cast cast_size crew_size  \
# id
# 211672  Sandra Bullock|Jon Hamm|Michael Keaton|Allison...        17        12
# 297762  Gal Gadot|Chris Pine|Robin Wright|Danny Huston...       106       195
# 321612  Emma Watson|Dan Stevens|Luke Evans|Kevin Kline...       156       115
# 339403  Ansel Elgort|Lily James|Kevin Spacey|Jamie Fox...        56       183
# 177572  Scott Adsit|Ryan Potter|Daniel Henney|T.J. Mil...        46        39
#
#               director
# id
# 211672      Kyle Balda
# 297762   Patty Jenkins
# 321612     Bill Condon
# 339403    Edgar Wright
# 177572  Chris Williams
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Find your next Movie

# %% [markdown]
# 3. __Filter__ the Dataset for movies that meet the following conditions:

# %% [markdown]
# __Search 1: Science Fiction Action Movie with Bruce Willis (sorted from high to low Rating)__

# %% [markdown]
# __Search 2: Movies with Uma Thurman and directed by Quentin Tarantino (sorted from short to long runtime)__

# %% [markdown]
# __Search 3: Most Successful Pixar Studio Movies between 2010 and 2015 (sorted from high to low Revenue)__

# %% [markdown]
# __Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent movies first)__

# %%
filter_genres = movies.genres.str.contains("Science Fiction") & movies.genres.str.contains("Action")
filter_actor = movies.cast.str.contains("Bruce Willis")
filtered_movies = movies[filter_genres & filter_actor]
filtered_movies.sort_values('vote_average', ascending=False)
# Out:
#                         title  \
# id
# 18          The Fifth Element
# 59967                  Looper
# 95                 Armageddon
# 19959              Surrogates
# 72559   G.I. Joe: Retaliation
# 307663                   Vice
#
#                                                   tagline release_date  \
# id
# 18                         There is no future without it.   1997-05-07
# 59967         Hunted By Your Future, Haunted By Your Past   2012-09-26
# 95      The Earth's Darkest Day Will Be Man's Finest Hour   1998-07-01
# 19959   How do you save humanity when the only thing t...   2009-09-24
# 72559                                                 NaN   2013-03-26
# 307663                     Where the future is your past.   2015-01-16
#
#                                                    genres  \
# id
# 18      Adventure|Fantasy|Action|Thriller|Science Fiction
# 59967                     Action|Thriller|Science Fiction
# 95              Action|Thriller|Science Fiction|Adventure
# 19959                     Action|Science Fiction|Thriller
# 72559           Adventure|Action|Science Fiction|Thriller
# 307663          Thriller|Science Fiction|Action|Adventure
#
#                     belongs_to_collection original_language  budget_musd  \
# id
# 18                                    NaN                en         90.0
# 59967                                 NaN                en         30.0
# 95                                    NaN                en        140.0
# 19959                                 NaN                en         80.0
# 72559   G.I. Joe (Live-Action) Collection                en        130.0
# 307663                                NaN                en         10.0
#
#         revenue_musd  gross_profit_musd       ROI  ... vote_average  \
# id                                                 ...
# 18        263.920180         173.920180  2.932446  ...          7.3
# 59967      47.042000          17.042000  1.568067  ...          6.6
# 95        553.799566         413.799566  3.955711  ...          6.5
# 19959     122.444772          42.444772  1.530560  ...          5.9
# 72559     371.876278         241.876278  2.860587  ...          5.4
# 307663           NaN                NaN       NaN  ...          4.1
#
#        popularity  runtime                                           overview  \
# id
# 18      24.305260    126.0  In 2257, a taxi driver is unintentionally give...
# 59967   12.727269    118.0  In the futuristic action thriller Looper, time...
# 95      13.235112    151.0  When an asteroid threatens to collide with Ear...
# 19959   16.211937     89.0  Set in a futuristic world where humans live in...
# 72559   10.560608    110.0  Framed for crimes against the country, the G.I...
# 307663  19.236571     96.0  Julian Michaels has designed the ultimate reso...
#
#                spoken_languages  \
# id
# 18      English|svenska|Deutsch
# 59967                   English
# 95              English|Pусский
# 19959          English|Français
# 72559                   English
# 307663                  English
#
#                                               poster_path  \
# id
# 18      <img src='http://image.tmdb.org/t/p/w185//fPtl...
# 59967   <img src='http://image.tmdb.org/t/p/w185//sNjL...
# 95      <img src='http://image.tmdb.org/t/p/w185//fMtO...
# 19959   <img src='http://image.tmdb.org/t/p/w185//v3Z0...
# 72559   <img src='http://image.tmdb.org/t/p/w185//3rWI...
# 307663  <img src='http://image.tmdb.org/t/p/w185//nPqN...
#
#                                                      cast cast_size crew_size  \
# id
# 18      Bruce Willis|Gary Oldman|Ian Holm|Milla Jovovi...       114       134
# 59967   Joseph Gordon-Levitt|Bruce Willis|Emily Blunt|...        34        42
# 95      Bruce Willis|Billy Bob Thornton|Ben Affleck|Li...        67       108
# 19959   Bruce Willis|Radha Mitchell|Rosamund Pike|Jame...        44        25
# 72559   Dwayne Johnson|D.J. Cotrona|Adrianne Palicki|B...        20        28
# 307663  Ambyr Childers|Thomas Jane|Bryan Greenberg|Bru...        51        56
#
#                director
# id
# 18           Luc Besson
# 59967      Rian Johnson
# 95          Michael Bay
# 19959   Jonathan Mostow
# 72559        Jon M. Chu
# 307663   Brian A Miller
#
# [6 rows x 23 columns]

# %%
filter_director = movies.director.str.contains("Quentin Tarantino")
filter_actor = movies.cast.str.contains("Uma Thurman")
filtered_movies = movies[filter_director & filter_actor]
filtered_movies.sort_values('runtime', ascending=False)
# Out:
#                  title                                            tagline  \
# id
# 680       Pulp Fiction  Just because you are a character doesn't mean ...
# 393  Kill Bill: Vol. 2               The bride is back for the final cut.
# 24   Kill Bill: Vol. 1                                   Go for the kill.
#
#     release_date                 genres belongs_to_collection  \
# id
# 680   1994-09-10         Thriller|Crime                   NaN
# 393   2004-04-16  Action|Crime|Thriller  Kill Bill Collection
# 24    2003-10-10           Action|Crime  Kill Bill Collection
#
#     original_language  budget_musd  revenue_musd  gross_profit_musd  \
# id
# 680                en          8.0    213.928762         205.928762
# 393                en         30.0    152.159461         122.159461
# 24                 en         30.0    180.949000         150.949000
#
#            ROI  ... vote_average  popularity  runtime  \
# id              ...
# 680  26.741095  ...          8.3  140.950236    154.0
# 393   5.071982  ...          7.7   21.533072    136.0
# 24    6.031633  ...          7.7   25.261865    111.0
#
#                                               overview  \
# id
# 680  A burger-loving hit man, his philosophical par...
# 393  The Bride unwaveringly continues on her roarin...
# 24   An assassin is shot at the altar by her ruthle...
#
#                   spoken_languages  \
# id
# 680       English|Español|Français
# 393  English|普通话|Español|广州话 / 廣州話
# 24            English|日本語|Français
#
#                                            poster_path  \
# id
# 680  <img src='http://image.tmdb.org/t/p/w185//d5iI...
# 393  <img src='http://image.tmdb.org/t/p/w185//2yhg...
# 24   <img src='http://image.tmdb.org/t/p/w185//v7Ta...
#
#                                                   cast cast_size crew_size  \
# id
# 680  John Travolta|Samuel L. Jackson|Uma Thurman|Br...        54        87
# 393  Uma Thurman|David Carradine|Daryl Hannah|Micha...        27       130
# 24   Uma Thurman|Lucy Liu|Vivica A. Fox|Daryl Hanna...        36       161
#
#               director
# id
# 680  Quentin Tarantino
# 393  Quentin Tarantino
# 24   Quentin Tarantino
#
# [3 rows x 23 columns]

# %%
filter_studio = movies.production_companies.str.contains("Pixar")
filter_date = movies.release_date.between('2010-01-01','2015-12-31')
filtered_movies = movies[filter_studio & filter_date].sort_values('revenue_musd', ascending=False)
filtered_movies
# Out:
#                              title  \
# id
# 10193                  Toy Story 3
# 150540                  Inside Out
# 62211          Monsters University
# 49013                       Cars 2
# 62177                        Brave
# 105864           The Good Dinosaur
# 40619                  Day & Night
# 200481           The Blue Umbrella
# 213121        Toy Story of Terror!
# 83564                      La luna
# 77887            Hawaiian Vacation
# 82424                    Small Fry
# 130925             Partysaurus Rex
# 141423        The Legend of Mor'du
# 256835  Toy Story That Time Forgot
# 286192                        Lava
# 345637         Sanjay's Super Team
# 145316                   Air Mater
# 355338         Riley's First Date?
#
#                                                   tagline release_date  \
# id
# 10193                            No toy gets left behind.   2010-06-16
# 150540           Meet the little voices inside your head.   2015-06-09
# 62211                     School never looked this scary.   2013-06-20
# 49013                                            Ka-ciao!   2011-06-11
# 62177                                   Change your fate.   2012-06-21
# 105864                      Little Arms With Big Attitude   2015-11-14
# 40619                                                 NaN   2010-06-17
# 200481                                                NaN   2013-02-12
# 213121                          One toy gets left behind!   2013-10-15
# 83564   A young boy discovers his family's most unusua...   2011-01-01
# 77887                                                 NaN   2011-06-16
# 82424                                                 NaN   2011-11-23
# 130925                        An Electro Sudsy Good Time!   2012-09-14
# 141423                                                NaN   2012-01-01
# 256835                                                NaN   2014-12-02
# 286192                                                NaN   2015-06-21
# 345637                                                NaN   2015-11-25
# 145316                                                NaN   2011-08-04
# 355338                                                NaN   2015-11-03
#
#                                                   genres  \
# id
# 10193                            Animation|Family|Comedy
# 150540                     Drama|Comedy|Animation|Family
# 62211                                   Animation|Family
# 49013                  Animation|Family|Adventure|Comedy
# 62177   Animation|Adventure|Comedy|Family|Action|Fantasy
# 105864                        Adventure|Animation|Family
# 40619                                   Animation|Family
# 200481                                 Animation|Romance
# 213121                           Animation|Comedy|Family
# 83564                                   Animation|Family
# 77887                                   Animation|Family
# 82424                                   Animation|Family
# 130925                   Animation|Comedy|Family|Fantasy
# 141423                                  Animation|Family
# 256835                                  Animation|Family
# 286192                                  Animation|Family
# 345637                                         Animation
# 145316                                  Animation|Family
# 355338                                  Animation|Family
#
#             belongs_to_collection original_language  budget_musd  \
# id
# 10193        Toy Story Collection                en        200.0
# 150540                        NaN                en        175.0
# 62211   Monsters, Inc. Collection                en        200.0
# 49013             Cars Collection                en        200.0
# 62177                         NaN                en        185.0
# 105864                        NaN                en        175.0
# 40619                         NaN                en          NaN
# 200481                        NaN                en          NaN
# 213121                        NaN                en          NaN
# 83564                         NaN                en          NaN
# 77887                         NaN                en          NaN
# 82424                         NaN                en          NaN
# 130925                        NaN                en          NaN
# 141423                        NaN                en          NaN
# 256835                        NaN                en          NaN
# 286192                        NaN                en          NaN
# 345637                        NaN                en          NaN
# 145316                        NaN                en          NaN
# 355338                        NaN                en          NaN
#
#         revenue_musd  gross_profit_musd       ROI  ... vote_average  \
# id                                                 ...
# 10193    1066.969703         866.969703  5.334849  ...          7.6
# 150540    857.611174         682.611174  4.900635  ...          7.9
# 62211     743.559607         543.559607  3.717798  ...          7.0
# 49013     559.852396         359.852396  2.799262  ...          5.8
# 62177     538.983207         353.983207  2.913423  ...          6.7
# 105864    331.926147         156.926147  1.896721  ...          6.6
# 40619            NaN                NaN       NaN  ...          7.6
# 200481           NaN                NaN       NaN  ...          7.8
# 213121           NaN                NaN       NaN  ...          7.3
# 83564            NaN                NaN       NaN  ...          8.0
# 77887            NaN                NaN       NaN  ...          6.9
# 82424            NaN                NaN       NaN  ...          6.8
# 130925           NaN                NaN       NaN  ...          7.4
# 141423           NaN                NaN       NaN  ...          5.9
# 256835           NaN                NaN       NaN  ...          6.8
# 286192           NaN                NaN       NaN  ...          7.4
# 345637           NaN                NaN       NaN  ...          6.9
# 145316           NaN                NaN       NaN  ...          5.8
# 355338           NaN                NaN       NaN  ...          7.2
#
#        popularity  runtime                                           overview  \
# id
# 10193   16.966470    103.0  Woody, Buzz, and the rest of Andy's toys haven...
# 150540  23.985587     94.0  Growing up can be a bumpy road, and it's no ex...
# 62211   16.267502    104.0  A look at the relationship between Mike and Su...
# 49013   13.693002    106.0  Star race car Lightning McQueen and his pal Ma...
# 62177   15.876341     93.0  Brave is set in the mystical Scottish Highland...
# 105864  12.319595     93.0  An epic journey into the world of dinosaurs wh...
# 40619    6.345512      6.0  When Day, a sunny fellow, encounters Night, a ...
# 200481   6.568023      7.0  It is just another evening commute until the r...
# 213121   0.512025     22.0  What starts out as a fun road trip for the Toy...
# 83564    7.331398      7.0  A young boy comes of age in the most peculiar ...
# 77887   11.315849      6.0  The toys throw Ken and Barbie a Hawaiian vacat...
# 82424    9.858179      7.0  A fast food restaurant mini variant of Buzz fo...
# 130925   6.066171      7.0  When Rex finds himself left behind in the bath...
# 141423   3.785848      6.0  The witch from Pixar's Brave uses magical illu...
# 256835   8.609555     22.0  During a post-Christmas play date, the gang fi...
# 286192   5.761878      7.0  The story follows the love story of two volcan...
# 345637   4.335730      7.0  Sanjay's Super Team follows the daydream of a ...
# 145316   8.844424      6.0  Mater's decision to fly lands him accidentally...
# 355338   6.051285      5.0  Riley, now 12, is hanging out at home with her...
#
#                      spoken_languages  \
# id
# 10193                 English|Español
# 150540                        English
# 62211                         English
# 49013   English|日本語|Italiano|Français
# 62177                         English
# 105864                        English
# 40619                             NaN
# 200481                    No Language
# 213121                        English
# 83564                         English
# 77887                         English
# 82424                         English
# 130925                        English
# 141423                        English
# 256835                        English
# 286192                        English
# 345637                        English
# 145316                        English
# 355338                        English
#
#                                               poster_path  \
# id
# 10193   <img src='http://image.tmdb.org/t/p/w185//amY0...
# 150540  <img src='http://image.tmdb.org/t/p/w185//lRHE...
# 62211   <img src='http://image.tmdb.org/t/p/w185//tyHH...
# 49013   <img src='http://image.tmdb.org/t/p/w185//okIz...
# 62177   <img src='http://image.tmdb.org/t/p/w185//8l0p...
# 105864  <img src='http://image.tmdb.org/t/p/w185//8RSk...
# 40619   <img src='http://image.tmdb.org/t/p/w185//eQ1Q...
# 200481  <img src='http://image.tmdb.org/t/p/w185//iSWV...
# 213121  <img src='http://image.tmdb.org/t/p/w185//aNDr...
# 83564   <img src='http://image.tmdb.org/t/p/w185//iS6D...
# 77887   <img src='http://image.tmdb.org/t/p/w185//tByW...
# 82424   <img src='http://image.tmdb.org/t/p/w185//z096...
# 130925  <img src='http://image.tmdb.org/t/p/w185//ylj9...
# 141423  <img src='http://image.tmdb.org/t/p/w185//8FKR...
# 256835  <img src='http://image.tmdb.org/t/p/w185//jqQP...
# 286192  <img src='http://image.tmdb.org/t/p/w185//blZS...
# 345637  <img src='http://image.tmdb.org/t/p/w185//mShc...
# 145316  <img src='http://image.tmdb.org/t/p/w185//jDwg...
# 355338  <img src='http://image.tmdb.org/t/p/w185//pyry...
#
#                                                      cast cast_size crew_size  \
# id
# 10193   Tom Hanks|Tim Allen|Ned Beatty|Joan Cusack|Mic...        45        38
# 150540  Amy Poehler|Phyllis Smith|Richard Kind|Bill Ha...        65        50
# 62211   Billy Crystal|John Goodman|Steve Buscemi|Helen...        24        13
# 49013   Owen Wilson|Larry the Cable Guy|Michael Caine|...        47        40
# 62177   Kelly Macdonald|Billy Connolly|Emma Thompson|J...        15        44
# 105864  Raymond Ochoa|Jack Bright|Jeffrey Wright|Franc...        19        11
# 40619                                          Wayne Dyer         1         1
# 200481                                        Sarah Jaffe         1         1
# 213121  Tom Hanks|Tim Allen|Kristen Schaal|Carl Weathe...         8         8
# 83564           Krista Sheffler|Tony Fucile|Phil Sheridan         3         9
# 77887   Tim Allen|Jodi Benson|Blake Clark|Tom Hanks|Jo...        21         8
# 82424   Lori Alan|Carlos Alazraqui|Tim Allen|Bob Berge...        20         6
# 130925  Tom Hanks|Tim Allen|Wallace Shawn|Corey Burton...        28        13
# 141423          Julie Walters|Steve Purcell|Callum O'Neil         3         7
# 256835  Tom Hanks|Tim Allen|Joan Cusack|Kristen Schaal...         8         4
# 286192                    Napua Greig|Kuana Torres Kahele         2        19
# 345637                                                NaN         0         4
# 145316  Larry the Cable Guy|Stacy Keach|Keith Ferguson...        12         4
# 355338  Amy Poehler|Phyllis Smith|Bill Hader|Lewis Bla...        20         4
#
#                  director
# id
# 10193         Lee Unkrich
# 150540        Pete Docter
# 62211         Dan Scanlon
# 49013       John Lasseter
# 62177      Brenda Chapman
# 105864         Peter Sohn
# 40619        Teddy Newton
# 200481     Saschka Unseld
# 213121      Angus MacLane
# 83564     Enrico Casarosa
# 77887       Gary Rydstrom
# 82424       Angus MacLane
# 130925      Mark A. Walsh
# 141423       Brian Larsen
# 256835      Steve Purcell
# 286192  James Ford Murphy
# 345637       Sanjay Patel
# 145316          Rob Gibbs
# 355338        Josh Cooley
#
# [19 rows x 23 columns]

# %%
filter_genres = movies.genres.str.contains("Action") & movies.genres.str.contains("Thriller")
filter_lang = movies.original_language.str.contains("en")
filter_rating = movies.vote_average.between(7.5,10)
filtered_movies = movies[filter_genres & filter_lang & filter_rating].sort_values('release_date', ascending=False)
filtered_movies
# Out:
#                                      title  \
# id
# 374720                             Dunkirk
# 109424                    Captain Phillips
# 49026                The Dark Knight Rises
# 107170                  Ghost Recon: Alpha
# 84690                           Oxy-Morons
# 27205                            Inception
# 16869                 Inglourious Basterds
# 176241       Prison Break: The Final Break
# 155                        The Dark Knight
# 32534                 I Am So Proud of You
# 27442                            Senseless
# 15156                       Illegal Tender
# 752                         V for Vendetta
# 33460                                Sehar
# 393                      Kill Bill: Vol. 2
# 13905       Farscape: The Peacekeeper Wars
# 53670                          Say Nothing
# 949                                   Heat
# 29231                        The Immortals
# 288173                  Hostile Intentions
# 6075                         Carlito's Way
# 319                           True Romance
# 9702                        Bound by Honor
# 280             Terminator 2: Judgment Day
# 31942                        Midnight Ride
# 562                               Die Hard
# 679                                 Aliens
# 111                               Scarface
# 348                                  Alien
# 81772                  The Concorde Affair
# 38985                             Sorcerer
# 8333    The Taking of Pelham One Two Three
# 86600              The Internecine Project
# 119364                            The Take
# 42329                 The Valley of Gwangi
# 247                            The Killing
# 16958                   The Asphalt Jungle
# 22584                 To Have and Have Not
# 877                               Scarface
#
#                                                   tagline release_date  \
# id
# 374720                    The event that shaped our world   2017-07-19
# 109424                   Out here survival is everything.   2013-10-10
# 49026                                     The Legend Ends   2012-07-16
# 107170                                                NaN   2012-05-03
# 84690                                                 NaN   2011-10-02
# 27205                Your mind is the scene of the crime.   2010-07-14
# 16869         Once upon a time in Nazi occupied France...   2009-08-18
# 176241                     Prepare yourself for the truth   2009-05-26
# 155                                       Why So Serious?   2008-07-16
# 32534                                                 NaN   2008-01-01
# 27442                                                 NaN   2008-01-01
# 15156                                                 NaN   2007-08-24
# 752     People should not be afraid of their governmen...   2006-03-15
# 33460                                                 NaN   2005-07-29
# 393                  The bride is back for the final cut.   2004-04-16
# 13905   John Crichton may not have started the war, bu...   2004-01-01
# 53670                Think Fatal Attraction … in reverse!   2001-08-01
# 949                              A Los Angeles Crime Saga   1995-12-15
# 29231   It was a chance of a lifetime. If they lived t...   1995-10-05
# 288173  A night of adventure becomes one woman's despe...   1995-01-01
# 6075    He's got a good future if he can live past nex...   1993-11-10
# 319     Stealing, Cheating, Killing. Who said romance ...   1993-09-09
# 9702    An epic story of three brothers. Bound by bloo...   1993-02-05
# 280                                It's nothing personal.   1991-07-01
# 31942   Somewhere round the next bend, lies the road t...   1990-01-01
# 562               40 Stories. Twelve Terrorists. One Cop.   1988-07-15
# 679                                    This Time It's War   1986-07-18
# 111                                 The world is yours...   1983-12-08
# 348                  In space no one can hear you scream.   1979-05-25
# 81772                                                 NaN   1979-03-23
# 38985   WANTED. Four men willing to drive a cargo of d...   1977-06-24
# 8333    We are going to kill one passenger a minute un...   1974-10-02
# 86600              Who will be alive when the hands stop?   1974-07-24
# 119364      Meet the brother with a badge... on the take!   1974-05-01
# 42329   Cowboys Battle Monsters in the Lost World of F...   1969-07-24
# 247     ...Like No Other Picture Since "Scarface" and ...   1956-05-08
# 16958                             The City Under the City   1950-05-22
# 22584                      TALK ABOUT T.N.T.! THIS is IT!   1944-10-11
# 877          The rise and fall of a power hungry mobster.   1932-04-09
#
#                                                    genres  \
# id
# 374720                  Action|Drama|History|Thriller|War
# 109424                              Action|Drama|Thriller
# 49026                         Action|Crime|Drama|Thriller
# 107170                Action|Science Fiction|Thriller|War
# 84690                                     Action|Thriller
# 27205   Action|Thriller|Science Fiction|Mystery|Adventure
# 16869                           Drama|Action|Thriller|War
# 176241                              Action|Drama|Thriller
# 155                           Drama|Action|Crime|Thriller
# 32534           Animation|Action|Thriller|Science Fiction
# 27442      Action|Adventure|Drama|Foreign|Horror|Thriller
# 15156                         Drama|Action|Thriller|Crime
# 752                               Action|Thriller|Fantasy
# 33460                             Action|Foreign|Thriller
# 393                                 Action|Crime|Thriller
# 13905      Action|Comedy|Romance|Science Fiction|Thriller
# 53670   Action|Drama|Mystery|Romance|Science Fiction|T...
# 949                           Action|Crime|Drama|Thriller
# 29231                         Action|Crime|Drama|Thriller
# 288173                              Thriller|Action|Drama
# 6075                          Action|Crime|Drama|Thriller
# 319                         Action|Thriller|Crime|Romance
# 9702                          Action|Crime|Drama|Thriller
# 280                       Action|Thriller|Science Fiction
# 31942                              Thriller|Action|Horror
# 562                                       Action|Thriller
# 679                Horror|Action|Thriller|Science Fiction
# 111                           Action|Crime|Drama|Thriller
# 348                Horror|Action|Thriller|Science Fiction
# 81772                               Action|Crime|Thriller
# 38985                           Action|Thriller|Adventure
# 8333                      Action|Adventure|Crime|Thriller
# 86600                                     Action|Thriller
# 119364                        Action|Thriller|Documentary
# 42329     Action|Fantasy|Science Fiction|Thriller|Western
# 247                           Drama|Action|Thriller|Crime
# 16958                         Action|Crime|Drama|Thriller
# 22584         War|Action|Adventure|Drama|Romance|Thriller
# 877                 Action|Adventure|Crime|Drama|Thriller
#
#              belongs_to_collection original_language  budget_musd  \
# id
# 374720                         NaN                en    100.00000
# 109424                         NaN                en     55.00000
# 49026   The Dark Knight Collection                en    250.00000
# 107170                         NaN                en          NaN
# 84690                          NaN                en      3.50000
# 27205                          NaN                en    160.00000
# 16869                          NaN                en     70.00000
# 176241                         NaN                en          NaN
# 155     The Dark Knight Collection                en    185.00000
# 32534                          NaN                en          NaN
# 27442                          NaN                en          NaN
# 15156                          NaN                en          NaN
# 752                            NaN                en     54.00000
# 33460                          NaN                en          NaN
# 393           Kill Bill Collection                en     30.00000
# 13905                          NaN                en          NaN
# 53670                          NaN                en          NaN
# 949                            NaN                en     60.00000
# 29231                          NaN                en      0.00005
# 288173                         NaN                en          NaN
# 6075                           NaN                en     30.00000
# 319                            NaN                en     12.50000
# 9702                           NaN                en     35.00000
# 280      The Terminator Collection                en    100.00000
# 31942                          NaN                en          NaN
# 562            Die Hard Collection                en     28.00000
# 679               Alien Collection                en     18.50000
# 111                            NaN                en     25.00000
# 348               Alien Collection                en     11.00000
# 81772                          NaN                en          NaN
# 38985                          NaN                en     22.00000
# 8333                           NaN                en          NaN
# 86600                          NaN                en          NaN
# 119364                         NaN                en          NaN
# 42329                          NaN                en          NaN
# 247                            NaN                en      0.32000
# 16958                          NaN                en          NaN
# 22584                          NaN                en          NaN
# 877                            NaN                en          NaN
#
#         revenue_musd  gross_profit_musd       ROI  ... vote_average  \
# id                                                 ...
# 374720    519.876949         419.876949  5.198769  ...          7.5
# 109424     95.000000          40.000000  1.727273  ...          7.6
# 49026    1084.939099         834.939099  4.339756  ...          7.6
# 107170           NaN                NaN       NaN  ...          7.5
# 84690            NaN                NaN       NaN  ...          8.0
# 27205     825.532764         665.532764  5.159580  ...          8.1
# 16869     319.131050         249.131050  4.559015  ...          7.9
# 176241           NaN                NaN       NaN  ...          7.5
# 155      1004.558444         819.558444  5.430046  ...          8.3
# 32534            NaN                NaN       NaN  ...          8.3
# 27442            NaN                NaN       NaN  ...          7.5
# 15156       3.106835                NaN       NaN  ...          7.6
# 752       132.511035          78.511035  2.453908  ...          7.7
# 33460            NaN                NaN       NaN  ...          7.7
# 393       152.159461         122.159461  5.071982  ...          7.7
# 13905            NaN                NaN       NaN  ...          7.5
# 53670            NaN                NaN       NaN  ...          9.0
# 949       187.436818         127.436818  3.123947  ...          7.7
# 29231       0.000083           0.000033  1.660000  ...          7.8
# 288173           NaN                NaN       NaN  ...          8.0
# 6075       36.516012           6.516012  1.217200  ...          7.7
# 319        12.281551          -0.218449  0.982524  ...          7.5
# 9702             NaN                NaN       NaN  ...          7.7
# 280       520.000000         420.000000  5.200000  ...          7.7
# 31942            NaN                NaN       NaN  ...          8.0
# 562       140.767956         112.767956  5.027427  ...          7.5
# 679       183.316455         164.816455  9.908998  ...          7.7
# 111        65.884703          40.884703  2.635388  ...          8.0
# 348       104.931801          93.931801  9.539255  ...          7.9
# 81772            NaN                NaN       NaN  ...          7.5
# 38985      12.000000         -10.000000  0.545455  ...          7.5
# 8333             NaN                NaN       NaN  ...          7.6
# 86600            NaN                NaN       NaN  ...          7.8
# 119364           NaN                NaN       NaN  ...          8.0
# 42329            NaN                NaN       NaN  ...          7.5
# 247              NaN                NaN       NaN  ...          7.7
# 16958            NaN                NaN       NaN  ...          7.5
# 22584       3.650000                NaN       NaN  ...          7.6
# 877         0.600000                NaN       NaN  ...          7.5
#
#         popularity  runtime  \
# id
# 374720   30.938854    107.0
# 109424   13.776068    134.0
# 49026    20.582580    165.0
# 107170    3.036216     24.0
# 84690     0.086584    111.0
# 27205    29.108149    148.0
# 16869    16.895640    153.0
# 176241    6.526913     89.0
# 155     123.167259    152.0
# 32534     0.472132     22.0
# 27442     0.467144     87.0
# 15156     1.689926    108.0
# 752      20.214422    132.0
# 33460     0.463688      NaN
# 393      21.533072    136.0
# 13905     5.715534    182.0
# 53670     0.229743     94.0
# 949      17.924927    170.0
# 29231     0.825042     98.0
# 288173    0.062388     90.0
# 6075      8.698509    144.0
# 319      17.189328    120.0
# 9702      6.398031    180.0
# 280      22.661695    137.0
# 31942     0.766401     93.0
# 562      16.640522    131.0
# 679      21.761179    137.0
# 111      11.299673    170.0
# 348      23.377420    117.0
# 81772     0.816083     96.0
# 38985    13.966833    121.0
# 8333      7.762833    104.0
# 86600     1.672384     89.0
# 119364    0.645963     91.0
# 42329     2.082918     96.0
# 247      10.223264     85.0
# 16958    12.865590    112.0
# 22584    10.003167    100.0
# 877       4.854436     90.0
#
#                                                  overview  \
# id
# 374720  The miraculous evacuation of Allied soldiers f...
# 109424  The true story of Captain Richard Phillips and...
# 49026   Following the death of District Attorney Harve...
# 107170  Ghost Recon: Alpha sees a team led by Ghost Le...
# 84690   It's an action-packed thriller that borders on...
# 27205   Cobb, a skilled thief who commits corporate es...
# 16869   In Nazi-occupied France during World War II, a...
# 176241  The movie covers the events which occurred in ...
# 155     Batman raises the stakes in his war on crime. ...
# 32534   Dark shadows are cast over Bill's recovery, in...
# 27442   Elliott Gast (Jason Behr) is quickly climbing ...
# 15156   After the gangsters who killed his father come...
# 752     In a world in which Great Britain has become a...
# 33460   Ajay Kumar (Warsi) is the newly appointed, hon...
# 393     The Bride unwaveringly continues on her roarin...
# 13905   Sixty days on and Rygel is retrieving pieces o...
# 53670   Housewife Grace Needham (Nastassja Kinski) has...
# 949     Obsessive master thief, Neil McCauley leads a ...
# 29231   An elaborate heist unites 8 strangers in a sim...
# 288173  A weekend of fun becomes a fight for survival ...
# 6075    A Puerto-Rican ex-con, just released from pris...
# 319     Clarence marries hooker Alabama, steals cocain...
# 9702    Based on the true life experiences of poet Jim...
# 280     Nearly 10 years have passed since Sarah Connor...
# 31942   A house wife just left her cop husband, when s...
# 562     NYPD cop, John McClane's plan to reconcile wit...
# 679     When Ripley's lifepod is found by a salvage cr...
# 111     After getting a green card in exchange for ass...
# 348     During its return to the earth, commercial spa...
# 81772   A reporter tries to stop the crash of an aircr...
# 38985   Four exiled international criminals on the run...
# 8333    In New York, armed men hijack a subway car and...
# 86600   Former secret agent Robert Elliot (Coburn) wil...
# 119364  A policeman in New Mexico takes payoff money b...
# 42329   A turn of the century wild west show strugglin...
# 247     The Killing was Stanley Kubrick’s first film w...
# 16958   Recently paroled from prison, legendary burgla...
# 22584   A Martinique charter boat skipper gets mixed u...
# 877     Big Louis Costillo, last of the old-style gang...
#
#                          spoken_languages  \
# id
# 374720           English|Français|Deutsch
# 109424                     English|Somali
# 49026                             English
# 107170                            English
# 84690                             English
# 27205                             English
# 16869   Deutsch|English|Français|Italiano
# 176241                            English
# 155                           English|普通话
# 32534                                 NaN
# 27442                             English
# 15156                             English
# 752                               English
# 33460                              हिन्दी
# 393         English|普通话|Español|广州话 / 廣州話
# 13905                             English
# 53670                     English|Español
# 949                       English|Español
# 29231            English|Français|Pусский
# 288173                    Español|English
# 6075                      English|Español
# 319                      English|Italiano
# 9702                              English
# 280                       English|Español
# 31942                             English
# 562              English|Deutsch|Italiano
# 679                               English
# 111                       English|Español
# 348                       English|Español
# 81772                            Italiano
# 38985    English|Français|Deutsch|Español
# 8333                              English
# 86600                             Deutsch
# 119364                            English
# 42329                             English
# 247                               English
# 16958                             English
# 22584                    English|Français
# 877                      English|Italiano
#
#                                               poster_path  \
# id
# 374720  <img src='http://image.tmdb.org/t/p/w185//ebSn...
# 109424  <img src='http://image.tmdb.org/t/p/w185//gffn...
# 49026   <img src='http://image.tmdb.org/t/p/w185//vzvK...
# 107170  <img src='http://image.tmdb.org/t/p/w185//iCEF...
# 84690   <img src='http://image.tmdb.org/t/p/w185//5zXf...
# 27205   <img src='http://image.tmdb.org/t/p/w185//9gk7...
# 16869   <img src='http://image.tmdb.org/t/p/w185//7sfb...
# 176241  <img src='http://image.tmdb.org/t/p/w185//h1QR...
# 155     <img src='http://image.tmdb.org/t/p/w185//qJ2t...
# 32534   <img src='http://image.tmdb.org/t/p/w185//rLOR...
# 27442   <img src='http://image.tmdb.org/t/p/w185//5Cz5...
# 15156   <img src='http://image.tmdb.org/t/p/w185//5mbW...
# 752     <img src='http://image.tmdb.org/t/p/w185//2ySX...
# 33460   <img src='http://image.tmdb.org/t/p/w185//mfLI...
# 393     <img src='http://image.tmdb.org/t/p/w185//2yhg...
# 13905   <img src='http://image.tmdb.org/t/p/w185//wg2i...
# 53670   <img src='http://image.tmdb.org/t/p/w185//nUH2...
# 949     <img src='http://image.tmdb.org/t/p/w185//lbf2...
# 29231   <img src='http://image.tmdb.org/t/p/w185//2af4...
# 288173  <img src='http://image.tmdb.org/t/p/w185//mYcz...
# 6075    <img src='http://image.tmdb.org/t/p/w185//hkQa...
# 319     <img src='http://image.tmdb.org/t/p/w185//AqlP...
# 9702    <img src='http://image.tmdb.org/t/p/w185//ykkG...
# 280     <img src='http://image.tmdb.org/t/p/w185//5M0j...
# 31942   <img src='http://image.tmdb.org/t/p/w185//8lQG...
# 562     <img src='http://image.tmdb.org/t/p/w185//aJCp...
# 679     <img src='http://image.tmdb.org/t/p/w185//xwdP...
# 111     <img src='http://image.tmdb.org/t/p/w185//j5hI...
# 348     <img src='http://image.tmdb.org/t/p/w185//vfrQ...
# 81772   <img src='http://image.tmdb.org/t/p/w185//WOsg...
# 38985   <img src='http://image.tmdb.org/t/p/w185//xDQW...
# 8333    <img src='http://image.tmdb.org/t/p/w185//vNhy...
# 86600   <img src='http://image.tmdb.org/t/p/w185//HRX4...
# 119364  <img src='http://image.tmdb.org/t/p/w185//mrAB...
# 42329   <img src='http://image.tmdb.org/t/p/w185//5RP7...
# 247     <img src='http://image.tmdb.org/t/p/w185//8fT4...
# 16958   <img src='http://image.tmdb.org/t/p/w185//kIkP...
# 22584   <img src='http://image.tmdb.org/t/p/w185//5MLI...
# 877     <img src='http://image.tmdb.org/t/p/w185//bnFj...
#
#                                                      cast cast_size crew_size  \
# id
# 374720  Fionn Whitehead|Tom Glynn-Carney|Jack Lowden|H...        66       214
# 109424  Tom Hanks|Catherine Keener|Max Martini|Chris M...        17        85
# 49026   Christian Bale|Michael Caine|Gary Oldman|Anne ...       158       217
# 107170  Radek Bruna|Mark Ivanir|Keith Gilmore|Pavel Le...        11         3
# 84690   Damien Di Paola|Johnny Hickey|Tim Sylvia|Patty...         4         1
# 27205   Leonardo DiCaprio|Joseph Gordon-Levitt|Ellen P...        29        18
# 16869   Brad Pitt|Mélanie Laurent|Christoph Waltz|Eli ...        71        42
# 176241  Wentworth Miller|Sarah Wayne Callies|Dominic P...         7         3
# 155     Christian Bale|Michael Caine|Heath Ledger|Aaro...       134        81
# 32534                                      Don Hertzfeldt         1         2
# 27442   Jason Behr|Emma Catherwood|Joe Ferrara|Sean O'...         4         2
# 15156   Rick Gonzalez|Wanda De Jesus|Dania Ramirez|Del...         8         4
# 752     Natalie Portman|Hugo Weaving|Stephen Rea|Steph...        77       194
# 33460   Arshad Warsi|Sushant Singh|Pankaj Kapur|Mahima...        11         5
# 393     Uma Thurman|David Carradine|Daryl Hannah|Micha...        27       130
# 13905   Claudia Black|Ben Browder|Anthony Simcoe|Gigi ...        19        45
# 53670   William Baldwin|Hart Bochner|Nastassja Kinski|...         5         1
# 949     Al Pacino|Robert De Niro|Val Kilmer|Jon Voight...        65        71
# 29231   Eric Roberts|Joe Pantoliano|Tia Carrere|Tony C...         9        11
# 288173  Tia Carrere|Rigg Kennedy|Lisa Dean Ryan|Tricia...         5         2
# 6075    Al Pacino|Sean Penn|Penelope Ann Miller|John L...        63        40
# 319     Christian Slater|Patricia Arquette|Michael Rap...        40        39
# 9702    Дэмиан Чапа|Jesse Borrego|Benjamin Bratt|Enriq...        15        16
# 280     Arnold Schwarzenegger|Linda Hamilton|Robert Pa...        42        54
# 31942   Michael Dudikoff|Mark Hamill|Robert Mitchum|Sa...         8         4
# 562     Bruce Willis|Alan Rickman|Alexander Godunov|Bo...        47        75
# 679     Sigourney Weaver|Michael Biehn|James Remar|Pau...        26        38
# 111     Al Pacino|Steven Bauer|Michelle Pfeiffer|Mary ...        63        42
# 348     Tom Skerritt|Sigourney Weaver|Veronica Cartwri...        10        30
# 81772   James Franciscus|Mimsy Farmer|Venantino Venant...        38         6
# 38985   Roy Scheider|Bruno Cremer|Francisco Rabal|Amid...        14         9
# 8333    Walter Matthau|Robert Shaw|Martin Balsam|Hécto...        19        27
# 86600   James Coburn|Lee Grant|Harry Andrews|Ian Hendr...         9         9
# 119364  Billy Dee Williams|Eddie Albert|Frankie Avalon...        11         4
# 42329   James Franciscus|Gila Golan|Richard Carlson|La...         9         9
# 247     Sterling Hayden|Coleen Gray|Vince Edwards|Jay ...        37        24
# 16958   Sterling Hayden|Louis Calhern|Jean Hagen|James...        15        16
# 22584   Humphrey Bogart|Walter Brennan|Lauren Bacall|D...        35        38
# 877     Paul Muni|Ann Dvorak|Karen Morley|Osgood Perki...        41        22
#
#                      director
# id
# 374720      Christopher Nolan
# 109424        Paul Greengrass
# 49026       Christopher Nolan
# 107170         François Alaux
# 84690           Johnny Hickey
# 27205       Christopher Nolan
# 16869       Quentin Tarantino
# 176241            Brad Turner
# 155         Christopher Nolan
# 32534          Don Hertzfeldt
# 27442              Simon Hynd
# 15156            Franc. Reyes
# 752            James McTeigue
# 33460          Kabeer Kaushik
# 393         Quentin Tarantino
# 13905            Brian Henson
# 53670             Allan Moyle
# 949              Michael Mann
# 29231             Brian Grant
# 288173        Catherine Cyran
# 6075           Brian De Palma
# 319                Tony Scott
# 9702          Taylor Hackford
# 280             James Cameron
# 31942             Bob Bralver
# 562            John McTiernan
# 679             James Cameron
# 111            Brian De Palma
# 348              Ridley Scott
# 81772         Ruggero Deodato
# 38985        William Friedkin
# 8333           Joseph Sargent
# 86600              Ken Hughes
# 119364  Robert Hartford-Davis
# 42329          Jim O'Connolly
# 247           Stanley Kubrick
# 16958             John Huston
# 22584            Howard Hawks
# 877              Howard Hawks
#
# [39 rows x 23 columns]

# %%
title = " ".join(movies['title'].dropna())
overview = " ".join(movies['overview'].dropna())
tagline = " ".join(movies['tagline'].dropna())

# %%
# title_wordcloud = WordCloud(background_color="black", height=2000, width=4000, max_words=200).generate(title)
# plt.figure(figsize=(16, 8))
# plt.imshow(title_wordcloud, interpolation="bilinear")
# plt.axis("off")
# plt.show()

# %%
# tagline_wordcloud = WordCloud(background_color="black", height=2000, width=4000, max_words=200).generate(tagline)
# plt.figure(figsize=(16, 8))
# plt.imshow(tagline_wordcloud, interpolation="bilinear")
# plt.axis("off")
# plt.show()

# %%
# overview_wordcloud = WordCloud(background_color="black", height=2000, width=4000, max_words=200).generate(overview)
# plt.figure(figsize=(16, 8))
# plt.imshow(overview_wordcloud, interpolation="bilinear")
# plt.axis("off")
# plt.show()

# %% [markdown]
# ||## Are Franchises more successful?

# %% [markdown]
# 4. __Analyze__ the Dataset and __find out whether Franchises (Movies that belong to a collection) are more successful than stand-alone movies__ in terms of:

# %% [markdown]
# - mean revenue
# - median Return on Investment
# - mean budget raised
# - mean popularity
# - mean rating

# %% [markdown]
# hint: use groupby()

# %% [markdown]
# __Franchise vs. Stand-alone: Average Revenue__

# %%
movies['franchise'] = movies.belongs_to_collection.notna()

# %%
movies.franchise.value_counts()
# Out:
# franchise
# False    40228
# True      4463
# Name: count, dtype: int64

# %%
movies.groupby('franchise').median(numeric_only=True)

# %%
movies.groupby('franchise').agg({'budget_musd': np.mean, "revenue_musd": np.mean, "vote_count": np.mean, "popularity": np.mean, "ROI": np.median, "vote_count": np.mean})
# Out:
# C:\Users\alexb\AppData\Local\Temp\ipykernel_23856\1283429668.py:1: FutureWarning: The provided callable <function mean at 0x000001D45EE0D1C0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   movies.groupby('franchise').agg({'budget_musd': np.mean, "revenue_musd": np.mean, "vote_count": np.mean, "popularity": np.mean, "ROI": np.median, "vote_count": np.mean})
# C:\Users\alexb\AppData\Local\Temp\ipykernel_23856\1283429668.py:1: FutureWarning: The provided callable <function median at 0x000001D45EF6FA60> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   movies.groupby('franchise').agg({'budget_musd': np.mean, "revenue_musd": np.mean, "vote_count": np.mean, "popularity": np.mean, "ROI": np.median, "vote_count": np.mean})
#            budget_musd  revenue_musd  vote_count  popularity       ROI
# franchise
# False        18.047741     44.742814   78.289550    2.592726  1.619699
# True         38.319847    165.708193  412.387856    6.245051  3.709195

# %% [markdown]
# }__Franchise vs. Stand-alone: Return on Investment / Profitability (median)__

# %% [markdown]
# __Franchise vs. Stand-alone: Average Budget__

# %% [markdown]
# __Franchise vs. Stand-alone: Average Popularity__

# %% [markdown]
# __Franchise vs. Stand-alone: Average Rating__

# %% [markdown]
# ## Most Successful Franchises

# %% [markdown]
# 5. __Find__ the __most successful Franchises__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total & mean budget__
# - __total & mean revenue__
# - __mean rating__

# %%
movies.belongs_to_collection.value_counts()

# %%
franchises = movies.groupby('belongs_to_collection').agg({"title": "count", "budget_musd": ["sum", "mean"], "revenue_musd": ["sum", "mean"], "vote_average": "mean", "ROI": "median", "vote_count": "mean"})
franchises

# %%
franchises.nlargest(20, ("revenue_musd", "sum"))
# Out:
#                                     title budget_musd              \
#                                     count         sum        mean
# belongs_to_collection
# Harry Potter Collection                 8     1280.00  160.000000
# Star Wars Collection                    8      854.35  106.793750
# James Bond Collection                  26     1539.65   59.217308
# The Fast and the Furious Collection     8     1009.00  126.125000
# Pirates of the Caribbean Collection     5     1250.00  250.000000
# Transformers Collection                 5      965.00  193.000000
# Despicable Me Collection                6      299.00   74.750000
# The Twilight Collection                 5      385.00   77.000000
# Ice Age Collection                      5      429.00   85.800000
# Jurassic Park Collection                4      379.00   94.750000
# Shrek Collection                        5      535.00  133.750000
# The Hunger Games Collection             4      490.00  122.500000
# The Hobbit Collection                   3      750.00  250.000000
# The Avengers Collection                 2      500.00  250.000000
# The Lord of the Rings Collection        3      266.00   88.666667
# X-Men Collection                        6      983.00  163.833333
# Avatar Collection                       1      237.00  237.000000
# Mission: Impossible Collection          5      650.00  130.000000
# Spider-Man Collection                   3      597.00  199.000000
# The Dark Knight Collection              3      585.00  195.000000
#
#                                     revenue_musd              vote_average  \
#                                              sum         mean         mean
# belongs_to_collection
# Harry Potter Collection              7707.367425   963.420928     7.537500
# Star Wars Collection                 7434.494790   929.311849     7.375000
# James Bond Collection                7106.970239   273.345009     6.338462
# The Fast and the Furious Collection  5125.098793   640.637349     6.662500
# Pirates of the Caribbean Collection  4521.576826   904.315365     6.880000
# Transformers Collection              4366.101244   873.220249     6.140000
# Despicable Me Collection             3691.070216   922.767554     6.783333
# The Twilight Collection              3342.107290   668.421458     5.840000
# Ice Age Collection                   3216.708553   643.341711     6.380000
# Jurassic Park Collection             3031.484143   757.871036     6.500000
# Shrek Collection                     2955.807008   738.951752     6.460000
# The Hunger Games Collection          2944.162634   736.040659     6.875000
# The Hobbit Collection                2935.523356   978.507785     7.233333
# The Avengers Collection              2924.961604  1462.480802     7.350000
# The Lord of the Rings Collection     2916.544743   972.181581     8.033333
# X-Men Collection                     2808.832317   468.138720     6.816667
# Avatar Collection                    2787.965087  2787.965087     7.200000
# Mission: Impossible Collection       2778.977995   555.795599     6.600000
# Spider-Man Collection                2496.346518   832.115506     6.466667
# The Dark Knight Collection           2463.716216   821.238739     7.800000
#
#                                            ROI    vote_count
#                                         median          mean
# belongs_to_collection
# Harry Potter Collection               6.165086   5983.250000
# Star Wars Collection                  8.239637   5430.375000
# James Bond Collection                 6.128922   1284.307692
# The Fast and the Furious Collection   4.942154   3197.000000
# Pirates of the Caribbean Collection   3.453009   5016.000000
# Transformers Collection               5.197167   3046.400000
# Despicable Me Collection             12.761987   3041.333333
# The Twilight Collection              10.271932   2770.200000
# Ice Age Collection                    8.261760   2643.800000
# Jurassic Park Collection              7.027789   4608.750000
# Shrek Collection                      5.562873   2344.200000
# The Hunger Games Collection           6.267722   6543.500000
# The Hobbit Collection                 3.833600   5981.333333
# The Avengers Collection               5.963190   9454.000000
# The Lord of the Rings Collection     11.725157   8253.000000
# X-Men Collection                      3.023632   4593.833333
# Avatar Collection                    11.763566  12114.000000
# Mission: Impossible Collection        4.548868   2801.000000
# Spider-Man Collection                 3.918832   4505.666667
# The Dark Knight Collection            4.339756   9681.000000

# %% [markdown]
# ## Most Successful Directors

# %% [markdown]
# 6. __Find__ the __most successful Directors__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total revenue__
# - __mean rating__

# %%
movies.director.value_counts()
# Out:
# director
# John Ford                  66
# Michael Curtiz             65
# Werner Herzog              54
# Alfred Hitchcock           53
# Georges Méliès             49
#                            ..
# Vladimir Mashkov            1
# Pavel Ruminov               1
# Gianfranco Mingozzi         1
# Matthew Jason Walsh         1
# Rokhsareh Ghaem Maghami     1
# Name: count, Length: 17349, dtype: int64

# %%
directors = movies.groupby('director').agg({"title": "count", "budget_musd": ["sum", "mean"], "revenue_musd": ["sum", "mean"], "vote_average": "mean", "ROI": "median", "vote_count": "mean"})
directors
# Out:
#                     title budget_musd        revenue_musd            \
#                     count         sum   mean          sum      mean
# director
#  Dale Trevillion\t      2        0.00    NaN     0.000000       NaN
#  Davide Manuli          1        0.00    NaN     0.000000       NaN
#  E.W. Swackhamer        1        0.00    NaN     0.000000       NaN
#  Vitaliy Vorobyov       1        0.00    NaN     0.000000       NaN
#  Yeon Sang-Ho           4        8.95  4.475     2.129768  2.129768
# ...                   ...         ...    ...          ...       ...
# Ярополк Лапшин          1        0.00    NaN     0.000000       NaN
# پیمان معادی             1        0.00    NaN     0.000000       NaN
# 塩谷 直義                   1        0.00    NaN     0.000000       NaN
# 杰森·莫玛                   1        0.00    NaN     0.000000       NaN
# 진모영                     1        0.00    NaN     0.000000       NaN
#
#                     vote_average      ROI vote_count
#                             mean   median       mean
# director
#  Dale Trevillion\t           4.0      NaN       2.00
#  Davide Manuli               6.9      NaN      10.00
#  E.W. Swackhamer             5.9      NaN       5.00
#  Vitaliy Vorobyov            5.5      NaN       3.00
#  Yeon Sang-Ho                6.6  0.24147     259.75
# ...                          ...      ...        ...
# Ярополк Лапшин              10.0      NaN       1.00
# پیمان معادی                  6.0      NaN       2.00
# 塩谷 直義                        7.2      NaN      40.00
# 杰森·莫玛                        5.8      NaN      28.00
# 진모영                          6.0      NaN       6.00
#
# [17349 rows x 8 columns]
