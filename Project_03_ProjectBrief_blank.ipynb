# %% [markdown]
# # Project 3: Data Cleaning - Tidy up messy Datasets (Movies Dataset)

# %% [markdown]
# # Project Brief for Self-Coders

# %% [markdown]
# Here you´ll have the opportunity to code major parts of Project 3 on your own. If you need any help or inspiration, have a look at the Videos or the Jupyter Notebook with the full code. <br> <br>
# Keep in mind that it´s all about __getting the right results/conclusions__. It´s not about finding the identical code. Things can be coded in many different ways. Even if you come to the same conclusions, it´s very unlikely that we have the very same code.

# %% [markdown]
# ## First Steps

# %% [markdown]
# 1. __Load__ and __inspect__ the messy dataset __movies_metadata.csv__. Identify columns with nested / stringified json data.

# %%
import imdb_allpages
import pandas as pd
import numpy as np
from IPython.core.pylabtools import figsize
from IPython.display import HTML
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import requests
import json, ast
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
ugly_movies = pd.read_csv("movies_metadata.csv")
# Out:
# C:\Users\alexb\AppData\Local\Temp\ipykernel_22704\30819271.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   ugly_movies = pd.read_csv("movies_metadata.csv")

# %%
ugly_movies
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %% [markdown]
# ## Dropping irrelevant Columns

# %% [markdown]
# 2. __Drop__ the irrelevant columns 'adult', 'imdb_id', 'original_title', 'video' and 'homepage'.

# %%
ugly_movies.drop('adult', inplace=True, axis=1)
ugly_movies
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45461                                                NaN         0
# 45462                                                NaN         0
# 45463                                                NaN         0
# 45464                                                NaN         0
# 45465                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# ...

# %%
ugly_movies.drop(['imdb_id', 'original_title', 'video', 'homepage'], inplace=True, axis=1)
ugly_movies
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45461                                                NaN         0
# 45462                                                NaN         0
# 45463                                                NaN         0
# 45464                                                NaN         0
# 45465                                                NaN         0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# ...

# %% [markdown]
# ## How to handle stringified JSON columns

# %% [markdown]
# 3. __Evaluate__ Python Expressions in the stringified columns ["belongs_to_collection", "genres", "production_countries", "production_companies", "spoken_languages"] and __remove quotes__ ("") where possible.

# %%
ugly_movies.genres.apply(lambda x: json.loads(x.replace("'", '"')))[0]
# Out:
# [{'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'}]

# %%
ugly_movies.genres = ugly_movies.genres.apply(ast.literal_eval)

# %%
ugly_movies.belongs_to_collection = ugly_movies.belongs_to_collection.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# %%
ugly_movies.spoken_languages = ugly_movies.spoken_languages.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# %%
ugly_movies.production_countries = ugly_movies.production_countries.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# %%
ugly_movies.production_companies = ugly_movies.production_companies.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# %%
ugly_movies
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45461                                                NaN         0
# 45462                                                NaN         0
# 45463                                                NaN         0
# 45464                                                NaN         0
# 45465                                                NaN         0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# ...

# %% [markdown]
# ## How to flatten nested Columns

# %% [markdown]
# 4. __Extract__ only the __collection name__ from the column "belongs_to_collection" and __overwrite__ "belongs_to_collection". <br> For example: The value in the first row (Toy Story) should be 'Toy Story Collection'.

# %% [markdown]
# 5. __Extract__ all __genre names__ from the column "genres" and __overwrite__ "genres". If a movie has more than one genre, __seperate genres by a pipe__ "|".<br>
# For example: The value in the first row (Toy Story) should be 'Animation|Comedy|Family'.

# %% [markdown]
# 6. __Extract__ all __spoken language names__ from the column "spoken_languages" and __overwrite__ "spoken_languages". If a movie has more than one spoken language, __seperate spoken languages by a pipe__ "|".<br>
# For example: The value in the first row (Toy Story) should be 'English'.

# %% [markdown]
# 7. __Extract__ all __production countries names__ from the column "production_countries" and __overwrite__ "production_countries". If a movie has more than one production country, __seperate production countries by a pipe__ "|".<br>
# For example: The value in the first row (Toy Story) should be 'United States of America'.

# %% [markdown]
# 8. __Extract__ all __production companies names__ from the column "production_companies" and __overwrite__ "production_companies". If a movie has more than one production company, __seperate production companies by a pipe__ "|".<br>
# For example: The value in the first row (Toy Story) should be 'Pixar Animation Studios'

# %% [markdown]
# 9. __Inspect__ all columns above with value_counts(). Do you see anything strange? __Take reasonable measures__!

# %%
ugly_movies.belongs_to_collection[0]

# %%
ugly_movies.belongs_to_collection = ugly_movies.belongs_to_collection.apply(lambda x: x['name'] if isinstance(x, dict) else x)
ugly_movies

# %%
ugly_movies.genres = ugly_movies.genres.apply(lambda x: "|".join(i['name']for i in x))
ugly_movies

# %%
ugly_movies.genres = ugly_movies.genres.replace("", np.nan)
ugly_movies
# Out:
#                 belongs_to_collection    budget                    genres  \
# 0                Toy Story Collection  30000000   Animation|Comedy|Family
# 1                                 NaN  65000000  Adventure|Fantasy|Family
# 2           Grumpy Old Men Collection         0            Romance|Comedy
# 3                                 NaN  16000000      Comedy|Drama|Romance
# 4      Father of the Bride Collection         0                    Comedy
# ...                               ...       ...                       ...
# 45461                             NaN         0              Drama|Family
# 45462                             NaN         0                     Drama
# 45463                             NaN         0     Action|Drama|Thriller
# 45464                             NaN         0                       NaN
# 45465                             NaN         0                       NaN
#
#            id original_language  \
# 0         862                en
# ...

# %%
ugly_movies.genres.value_counts()

# %%
ugly_movies.spoken_languages = ugly_movies.spoken_languages.apply(lambda x: "|".join(i['name']for i in x) if isinstance(x, list) else x)
ugly_movies

# %%
ugly_movies.spoken_languages = ugly_movies.spoken_languages.replace("", np.nan)
ugly_movies

# %%
ugly_movies.production_companies = ugly_movies.production_companies.apply(lambda x: "|".join(i['name']for i in x) if isinstance(x, list) else x)
ugly_movies.production_companies = ugly_movies.production_companies.replace("", np.nan)
ugly_movies

# %%
ugly_movies.production_countries = ugly_movies.production_countries.apply(lambda x: "|".join(i['name']for i in x) if isinstance(x, list) else x)
ugly_movies.production_countries = ugly_movies.production_countries.replace("", np.nan)
ugly_movies
# Out:
#                 belongs_to_collection    budget                    genres  \
# 0                Toy Story Collection  30000000   Animation|Comedy|Family
# 1                                 NaN  65000000  Adventure|Fantasy|Family
# 2           Grumpy Old Men Collection         0            Romance|Comedy
# 3                                 NaN  16000000      Comedy|Drama|Romance
# 4      Father of the Bride Collection         0                    Comedy
# ...                               ...       ...                       ...
# 45461                             NaN         0              Drama|Family
# 45462                             NaN         0                     Drama
# 45463                             NaN         0     Action|Drama|Thriller
# 45464                             NaN         0                       NaN
# 45465                             NaN         0                       NaN
#
#            id original_language  \
# 0         862                en
# ...

# %%
ugly_movies.production_companies = ugly_movies.production_companies.apply(lambda x: "|".join(i['name']for i in x) if isinstance(x, list) else x)
ugly_movies.production_companies = ugly_movies.production_companies.replace("", np.nan)
ugly_movies

# %%
ugly_movies.production_companies = ugly_movies.production_companies.apply(lambda x: "|".join(i['name']for i in x) if isinstance(x, list) else x)
ugly_movies.production_companies = ugly_movies.production_companies.replace("", np.nan)
ugly_movies

# %%
ugly_movies.production_companies = ugly_movies.production_companies.apply(lambda x: "|".join(i['name']for i in x) if isinstance(x, list) else x)
ugly_movies.production_companies = ugly_movies.production_companies.replace("", np.nan)
ugly_movies

# %%
ugly_movies.production_companies = ugly_movies.production_companies.apply(lambda x: "|".join(i['name']for i in x) if isinstance(x, list) else x)
ugly_movies.production_companies = ugly_movies.production_companies.replace("", np.nan)
ugly_movies

# %%
ugly_movies.production_companies = ugly_movies.production_companies.apply(lambda x: "|".join(i['name']for i in x) if isinstance(x, list) else x)
ugly_movies.production_companies = ugly_movies.production_companies.replace("", np.nan)
ugly_movies

# %% [markdown]
# ## Cleaning Numerical Columns

# %% [markdown]
# 10. __Convert__ the datatype in the columns __"budget"__, __"id"__ and __"popularity"__ __to numeric__. Set invalid values as NaN.

# %% [markdown]
# 11. __Analyze__ the columns __"budget"__ and __"revenue"__ and __"runtime"__. Analyze movies with a budget/revenue/runtime of 0. Do you think the value 0 is the most appropriate value? __Take reasonable measures__!

# %% [markdown]
# 12. The columns "budget" and "revenue" shall show values in Million USD. __Convert and Overwrite__!

# %% [markdown]
# 13. __Analyze__ movies with a __vote_count of 0__. What´s the __vote_average__ for those movies? Do you think this value is the most appropriate value? __Take reasonable measures__!

# %%
ugly_movies.budget = pd.to_numeric(ugly_movies.budget, errors='coerce')

# %%
ugly_movies.budget = ugly_movies.budget.replace(0, np.nan)

# %%
ugly_movies.budget = ugly_movies.budget.div(1000000)
ugly_movies

# %%
ugly_movies.revenue = pd.to_numeric(ugly_movies.revenue, errors='coerce')
ugly_movies.revenue = ugly_movies.revenue.div(1000000)
ugly_movies

# %%
ugly_movies.rename(columns = {'revenue':'revenue_musd', 'budget':'budget_musd'}, inplace = True)

# %%
ugly_movies.runtime = ugly_movies.runtime.replace(0, np.nan)

# %%
ugly_movies.id = pd.to_numeric(ugly_movies.id, errors='coerce')

# %%
ugly_movies.popularity = pd.to_numeric(ugly_movies.popularity, errors='coerce')

# %%
ugly_movies.vote_count = pd.to_numeric(ugly_movies.vote_count, errors='coerce')

# %%
ugly_movies.vote_average = pd.to_numeric(ugly_movies.vote_average, errors='coerce')

# %%
ugly_movies.loc[ugly_movies.vote_count == 0, 'vote_average'] = np.nan

# %%
ugly_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4494 non-null   object
#  1   budget_musd            8890 non-null   float64
#  2   genres                 43024 non-null  object
#  3   id                     45463 non-null  float64
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45460 non-null  float64
#  7   poster_path            45080 non-null  object
#  8   production_companies   33588 non-null  object
#  9   production_countries   39181 non-null  object
#  10  release_date           45376 non-null  datetime64[ns]
#  11  revenue_musd           45460 non-null  float64
#  12  runtime                43645 non-null  float64
#  13  spoken_languages       41508 non-null  object
# ...

# %% [markdown]
# ## Cleaning DateTime Columns

# %% [markdown]
# 14. __Convert__ the datatype in the column __"release_date"__ __to datetime__. Set invalid values as NaN.

# %%
ugly_movies.release_date = pd.to_datetime(ugly_movies.release_date, errors='coerce')
ugly_movies
# Out:
#                 belongs_to_collection  budget_musd                    genres  \
# 0                Toy Story Collection         30.0   Animation|Comedy|Family
# 1                                 NaN         65.0  Adventure|Fantasy|Family
# 2           Grumpy Old Men Collection          NaN            Romance|Comedy
# 3                                 NaN         16.0      Comedy|Drama|Romance
# 4      Father of the Bride Collection          NaN                    Comedy
# ...                               ...          ...                       ...
# 45461                             NaN          NaN              Drama|Family
# 45462                             NaN          NaN                     Drama
# 45463                             NaN          NaN     Action|Drama|Thriller
# 45464                             NaN          NaN                       NaN
# 45465                             NaN          NaN                       NaN
#
#              id original_language  \
# ...

# %% [markdown]
# ## Cleaning Text / String Columns

# %% [markdown]
# 15. __Analyze__ the text columns "overview" and "tagline". Try to identify __missing data that is not represented by NaN__ (e.g. "No Data"). __Replace as NaN__ (np.nan)!

# %%
ugly_movies.overview = ugly_movies.overview.replace("No overview found.", np.nan)
ugly_movies.overview = ugly_movies.overview.replace("No Overview", np.nan)
ugly_movies.overview = ugly_movies.overview.replace("No movie overview available.", np.nan)

# %%
ugly_movies.overview = ugly_movies.overview.replace("No overview yet.", np.nan)
ugly_movies.overview.value_counts()

# %%
ugly_movies.overview.dropna(inplace=True)

# %%
ugly_movies.loc[ugly_movies.overview.str.contains('Chili', na=False)]
# Out:
#          belongs_to_collection  budget_musd                          genres  \
# 20     Chili Palmer Collection    30.250000           Comedy|Thriller|Crime
# 9767   Chili Palmer Collection    53.000000                    Comedy|Crime
# 23969                      NaN          NaN  Music|Documentary|Drama|Comedy
# 26212                      NaN          NaN                     Documentary
# 33556                      NaN     0.747487              Action|Crime|Drama
#
#              id original_language  \
# 20       8012.0                en
# 9767     4551.0                en
# 23969   75785.0                en
# 26212   75337.0                en
# 33556  214219.0                en
#
#                                                 overview  popularity  \
# 20     Chili Palmer is a Miami mobster who gets sent ...   12.669608
# 9767   Disenchanted with the movie industry, Chili Pa...   13.314233
# 23969  What happens when a generation's ultimate anti...    1.083836
# ...

# %%
ugly_movies.tagline = ugly_movies.tagline.replace("-", np.nan)
ugly_movies.tagline.value_counts()
# Out:
# tagline
# Based on a true story.                                                            7
# Trust no one.                                                                     4
# Be careful what you wish for.                                                     4
# Know Your Enemy                                                                   3
# Drama                                                                             3
#                                                                                  ..
# An extraordinary encounter with another human being.                              1
# I Love You... The Way You Are.                                                    1
# Envy, greed, jealousy and love.                                                   1
# In every woman there is the girl she left behind.                                 1
# Just When His World Is Back To Normal... He's In For The Surprise Of His Life!    1
# Name: count, Length: 20282, dtype: int64

# %% [markdown]
# ## Removing Duplicates

# %% [markdown]
# 16. __Identify__ and __remove__ duplicates!

# %%
ugly_movies[ugly_movies.duplicated(keep=False)]

# %%
ugly_movies.drop_duplicates(inplace=True)

# %%
ugly_movies.drop_duplicates(subset='id', inplace=True)

# %%
ugly_movies.id.value_counts(dropna=False)
# Out:
# id
# 461257.0    1
# 862.0       1
# 8844.0      1
# 15602.0     1
# 31357.0     1
#            ..
# 1408.0      1
# 10858.0     1
# 21032.0     1
# 12110.0     1
# 9087.0      1
# Name: count, Length: 45434, dtype: int64

# %% [markdown]
# ## Handling Missing Values & Removing Observations

# %% [markdown]
# 17. __Drop__ all rows/movies with unknown __id__ or __title__.

# %% [markdown]
# 18. __Keep__ only those rows/movies in the df with __10 or more non-NaN__ values.

# %%
ugly_movies.isna().sum()
# Out:
# belongs_to_collection    40945
# budget_musd              36554
# genres                    2442
# id                           1
# original_language           11
# overview                  1101
# popularity                   4
# poster_path                386
# production_companies     11871
# production_countries      6282
# release_date                88
# revenue_musd                 4
# runtime                   1819
# spoken_languages          3954
# status                      85
# tagline                  25037
# title                        4
# vote_average              2900
# vote_count                   4
# dtype: int64

# %%
ugly_movies.dropna(subset= ['id', 'title'], inplace=True)

# %%
ugly_movies

# %%
ugly_movies.id = ugly_movies.id.astype(int)

# %%
ugly_movies.notna().sum(axis=1).value_counts().sort_values(ascending=False)

# %%
ugly_movies[ugly_movies.notna().sum(axis=1) == 6]

# %%
ugly_movies.dropna(thresh=10, inplace=True)

# %%
ugly_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45302 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4487 non-null   object
#  1   budget_musd            8880 non-null   float64
#  2   genres                 42983 non-null  object
#  3   id                     45302 non-null  int64
#  4   original_language      45291 non-null  object
#  5   overview               44255 non-null  object
#  6   popularity             45302 non-null  float64
#  7   poster_path            45009 non-null  object
#  8   production_companies   33562 non-null  object
#  9   production_countries   39151 non-null  object
#  10  release_date           45251 non-null  datetime64[ns]
#  11  revenue_musd           45302 non-null  float64
#  12  runtime                43605 non-null  float64
#  13  spoken_languages       41476 non-null  object
# ...

# %% [markdown]
# ## Final (Cleaning) Steps

# %% [markdown]
# 19. __Keep__ only those rows/movies in the df with __status "Released"__. Then __drop__ the column "status".

# %% [markdown]
# 20. The Order of the columns should be as follows:

# %%
ugly_movies.status.value_counts()

# %%
ugly_movies = ugly_movies.loc[ugly_movies.status == 'Released'].copy()

# %%
ugly_movies.drop(columns=['status'], inplace=True)

# %%
new_column_order = ["id", "title", "tagline", "release_date", "genres", "belongs_to_collection",
"original_language", "budget_musd", "revenue_musd", "production_companies",
"production_countries", "vote_count", "vote_average", "popularity", "runtime",
"overview", "spoken_languages", "poster_path"]

# %%
clean_movies = ugly_movies.loc[:, new_column_order]
clean_movies
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 45461  439050                       Subdue
# 45462  111109          Century of Birthing
# 45463   67758                     Betrayal
# 45464  227506             Satan Triumphant
# 45465  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %% [markdown]
# 21. __Reset__ the Index and create a __RangeIndex__.

# %% [markdown]
# 22. __Save__ the cleaned dataset in a __csv-file__.

# %%
clean_movies.reset_index(drop=True, inplace=True)
clean_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44867 entries, 0 to 44866
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44867 non-null  int64
#  1   title                  44867 non-null  object
#  2   tagline                20285 non-null  object
#  3   release_date           44822 non-null  datetime64[ns]
#  4   genres                 42599 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44857 non-null  object
#  7   budget_musd            8855 non-null   float64
#  8   revenue_musd           44867 non-null  float64
#  9   production_companies   33357 non-null  object
#  10  production_countries   38839 non-null  object
#  11  vote_count             44867 non-null  float64
#  12  vote_average           42138 non-null  float64
#  13  popularity             44867 non-null  float64
# ...

# %%
base_poster_path = 'https://image.tmdb.org/t/p/w185/'
clean_movies['poster_path'] = "<img src='" + base_poster_path + clean_movies['poster_path'] + "' style='height: 100px;'>"
clean_movies.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# ...

# %% [markdown]
# # +++++++++ See some Hints below +++++++++++++

# %%
clean_movies.to_csv('clean_movies.csv', index=False)

# %%
pd.read_csv('clean_movies.csv')
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44862  439050                       Subdue
# 44863  111109          Century of Birthing
# 44864   67758                     Betrayal
# 44865  227506             Satan Triumphant
# 44866  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %% [markdown]
# # ++++++++++++++++ Hints++++++++++++++++++++

# %% [markdown]
# __Hints for 3.__ <br>
# apply ast.literal_eval() on all stringified elements (you have to import ast):

# %%
# # example:
# df.stringified_column = df.stringified_column.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # example:
# ----> 2 df.stringified_column = df.stringified_column.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)
#
# NameError: name 'df' is not defined

# %% [markdown]
# __Hints for 4., 5., 6., 7., 8.__<br>
# apply an appropriate lambda function on all column elements

# %% [markdown]
# __Hints for 9.__<br>
# Replace all __""__ (empty strings) in the above columns by NaN (__np.nan__)

# %% [markdown]
# __Hints for 10.__<br>
# Use pd.to_numeric() and "coerce" errors

# %% [markdown]
# __Hints for 11.__<br>
# Replace the value 0 by NaN (__np.nan__)

# %% [markdown]
# __Hints for 13.__<br>
# Replace the value 0 by NaN (__np.nan__)

# %% [markdown]
# __Hints for 14.__<br>
# Use pd.to_datetime() and "coerce" errors

# %% [markdown]
# __Hints for 16.__<br>
# There cannot be two or more movies with the same movie id.
