# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
summer = pd.read_csv('summer.csv', index_col = "Athlete")
summer2 = pd.read_csv('summer.csv')

# %%
summer.iloc[0:3]
# Out:
#                    Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred      1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto   1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                         Event   Medal
# Athlete
# HAJOS, Alfred                  100M Freestyle    Gold
# HERSCHMANN, Otto               100M Freestyle  Silver
# DRIVAS, Dimitrios  100M Freestyle For Sailors  Bronze

# %%
summer.iloc[[2, 45, 78]]
# Out:
#                    Year    City       Sport   Discipline Country Gender  \
# Athlete
# DRIVAS, Dimitrios  1896  Athens    Aquatics     Swimming     GRE    Men
# PERSAKIS, Ioannis  1896  Athens   Athletics    Athletics     GRE    Men
# PERSAKIS, Petros   1896  Athens  Gymnastics  Artistic G.     GRE    Men
#
#                                         Event   Medal
# Athlete
# DRIVAS, Dimitrios  100M Freestyle For Sailors  Bronze
# PERSAKIS, Ioannis                 Triple Jump  Bronze
# PERSAKIS, Petros                        Rings  Bronze

# %%
summer.iloc[0, 4]
# Out:
# 'HUN'

# %%
summer.iloc[0, :3]
# Out:
# Year         1896
# City       Athens
# Sport    Aquatics
# Name: HAJOS, Alfred, dtype: object

# %%
summer.iloc[34:39, [0, 2, 5, 7]]
# Out:
#                       Year      Sport Gender   Medal
# Athlete
# GARRETT, Robert       1896  Athletics    Men  Silver
# KELLNER, Gyula        1896  Athletics    Men  Bronze
# LOUIS, Spyridon       1896  Athletics    Men    Gold
# VASILAKOS, Kharilaos  1896  Athletics    Men  Silver
# DAMASKOS, Evangelos   1896  Athletics    Men  Bronze

# %%
summer.iloc[:, 4].equals(summer.Country)
# Out:
# True

# %%
summer.loc["LOUIS, Spyridon"]
# Out:
# Year               1896
# City             Athens
# Sport         Athletics
# Discipline    Athletics
# Country             GRE
# Gender              Men
# Event          Marathon
# Medal              Gold
# Name: LOUIS, Spyridon, dtype: object

# %%
summer.loc[["PHELPS, Michael", "LEWIS, Carl"], ['Medal', 'Year']]
# Out:
#                   Medal  Year
# Athlete
# PHELPS, Michael    Gold  2004
# PHELPS, Michael    Gold  2004
# PHELPS, Michael  Bronze  2004
# PHELPS, Michael    Gold  2004
# PHELPS, Michael    Gold  2004
# PHELPS, Michael  Bronze  2004
# PHELPS, Michael    Gold  2004
# PHELPS, Michael    Gold  2004
# PHELPS, Michael    Gold  2008
# PHELPS, Michael    Gold  2008
# PHELPS, Michael    Gold  2008
# PHELPS, Michael    Gold  2008
# PHELPS, Michael    Gold  2008
# PHELPS, Michael    Gold  2008
# PHELPS, Michael    Gold  2008
# PHELPS, Michael    Gold  2008
# PHELPS, Michael    Gold  2012
# PHELPS, Michael  Silver  2012
# PHELPS, Michael    Gold  2012
# PHELPS, Michael  Silver  2012
# PHELPS, Michael    Gold  2012
# PHELPS, Michael    Gold  2012
# LEWIS, Carl        Gold  1984
# LEWIS, Carl        Gold  1984
# LEWIS, Carl        Gold  1984
# LEWIS, Carl        Gold  1984
# LEWIS, Carl        Gold  1988
# LEWIS, Carl      Silver  1988
# LEWIS, Carl        Gold  1988
# ...

# %%
summer.loc[:"LOUIS, Spyridon"]
# Out:
#                              Year    City      Sport Discipline Country  \
# Athlete
# HAJOS, Alfred                1896  Athens   Aquatics   Swimming     HUN
# HERSCHMANN, Otto             1896  Athens   Aquatics   Swimming     AUT
# DRIVAS, Dimitrios            1896  Athens   Aquatics   Swimming     GRE
# MALOKINIS, Ioannis           1896  Athens   Aquatics   Swimming     GRE
# CHASAPIS, Spiridon           1896  Athens   Aquatics   Swimming     GRE
# CHOROPHAS, Efstathios        1896  Athens   Aquatics   Swimming     GRE
# HAJOS, Alfred                1896  Athens   Aquatics   Swimming     HUN
# ANDREOU, Joannis             1896  Athens   Aquatics   Swimming     GRE
# CHOROPHAS, Efstathios        1896  Athens   Aquatics   Swimming     GRE
# NEUMANN, Paul                1896  Athens   Aquatics   Swimming     AUT
# PEPANOS, Antonios            1896  Athens   Aquatics   Swimming     GRE
# LANE, Francis                1896  Athens  Athletics  Athletics     USA
# ...

# %%
summer.loc["DRIVAS, Dimitrios":"NEUMANN, Paul"]
# Out:
#                        Year    City     Sport Discipline Country Gender  \
# Athlete
# DRIVAS, Dimitrios      1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# HAJOS, Alfred          1896  Athens  Aquatics   Swimming     HUN    Men
# ANDREOU, Joannis       1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# NEUMANN, Paul          1896  Athens  Aquatics   Swimming     AUT    Men
#
#                                             Event   Medal
# Athlete
# DRIVAS, Dimitrios      100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis     100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon     100M Freestyle For Sailors  Silver
# CHOROPHAS, Efstathios             1200M Freestyle  Bronze
# ...

# %%
print(summer.loc["UNDA, Maider"]['Event'])
# Out:
# Wf 72 KG

# %%
summer.loc[["PAVIA, Automne", "OCHAL, Glenn"], ['Country','Sport']]
# Out:
#                Country   Sport
# Athlete
# PAVIA, Automne     FRA    Judo
# OCHAL, Glenn       USA  Rowing

# %%
summer2['Athlete']
# Out:
# 0                    HAJOS, Alfred
# 1                 HERSCHMANN, Otto
# 2                DRIVAS, Dimitrios
# 3               MALOKINIS, Ioannis
# 4               CHASAPIS, Spiridon
#                    ...
# 31160           JANIKOWSKI, Damian
# 31161    REZAEI, Ghasem Gholamreza
# 31162               TOTROV, Rustam
# 31163            ALEKSANYAN, Artur
# 31164               LIDBERG, Jimmy
# Name: Athlete, Length: 31165, dtype: object

# %%
athlete = summer2['Athlete']

# %%
len(athlete.unique())
# Out:
# 22762

# %%
athlete.value_counts()
# Out:
# Athlete
# PHELPS, Michael         22
# LATYNINA, Larisa        18
# ANDRIANOV, Nikolay      15
# ONO, Takashi            13
# MANGIAROTTI, Edoardo    13
#                         ..
# NABI, Heiki              1
# LOPEZ NUNEZ, Mijain      1
# LERMUSIAUX, Albin        1
# GOULDING, Grantley       1
# CURTIS, Thomas           1
# Name: count, Length: 22762, dtype: int64

# %%
athlete.mode()[0]
# Out:
# 'PHELPS, Michael'

# %%
mask1 = summer.Sport == 'Volleyball'
mask2 = summer.Medal == 'Gold'

# %%
summer.loc[mask1]
# Out:
#                    Year    City       Sport  Discipline Country Gender  \
# Athlete
# DEMACHI, Yutaka    1964   Tokyo  Volleyball  Volleyball     JPN    Men
# HIGUCHI, Tokihiko  1964   Tokyo  Volleyball  Volleyball     JPN    Men
# IKEDA, Nachiro     1964   Tokyo  Volleyball  Volleyball     JPN    Men
# KOSEDO, Toshiaki   1964   Tokyo  Volleyball  Volleyball     JPN    Men
# KOYAMA, Tsutomu    1964   Tokyo  Volleyball  Volleyball     JPN    Men
# ...                 ...     ...         ...         ...     ...    ...
# SAKODA, Saori      2012  London  Volleyball  Volleyball     JPN  Women
# SANO, Yuko         2012  London  Volleyball  Volleyball     JPN  Women
# SHINNABE, Risa     2012  London  Volleyball  Volleyball     JPN  Women
# TAKESHITA, Yoshie  2012  London  Volleyball  Volleyball     JPN  Women
# YAMAGUCHI, Mai     2012  London  Volleyball  Volleyball     JPN  Women
#
#                         Event   Medal
# Athlete
# DEMACHI, Yutaka    Volleyball  Bronze
# ...

# %%
gold_volley = summer.loc[mask1 & mask2]

# %%
gold_volley
# Out:
#                      Year    City       Sport  Discipline Country Gender  \
# Athlete
# BUGAENKOV, Ivan      1964   Tokyo  Volleyball  Volleyball     URS    Men
# BUROBIN, Nikolai     1964   Tokyo  Volleyball  Volleyball     URS    Men
# CHESNOKOV, Yuri      1964   Tokyo  Volleyball  Volleyball     URS    Men
# KALACHIKHIN, Valeri  1964   Tokyo  Volleyball  Volleyball     URS    Men
# KATCHARAVA, Vazha    1964   Tokyo  Volleyball  Volleyball     URS    Men
# ...                   ...     ...         ...         ...     ...    ...
# OLIVEIRA, Fabiana    2012  London  Volleyball  Volleyball     BRA  Women
# PEQUENO, Paula       2012  London  Volleyball  Volleyball     BRA  Women
# PEREIRA, Natalia     2012  London  Volleyball  Volleyball     BRA  Women
# RODRIGUES, Fernanda  2012  London  Volleyball  Volleyball     BRA  Women
# SILVA, Adenizia      2012  London  Volleyball  Volleyball     BRA  Women
#
#                           Event Medal
# Athlete
# ...

# %%
summer2.Athlete.map(lambda x: x[0])
# Out:
# 0        H
# 1        H
# 2        D
# 3        M
# 4        C
#         ..
# 31160    J
# 31161    R
# 31162    T
# 31163    A
# 31164    L
# Name: Athlete, Length: 31165, dtype: object

# %%
# summer.iloc[:,1:3].applymap(lambda x: x[0])
# Out:
# C:\Users\alexb\AppData\Local\Temp\ipykernel_1008\3962169842.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   summer.iloc[:,1:3].applymap(lambda x: x[0])
#                           City Sport
# Athlete
# HAJOS, Alfred                A     A
# HERSCHMANN, Otto             A     A
# DRIVAS, Dimitrios            A     A
# MALOKINIS, Ioannis           A     A
# CHASAPIS, Spiridon           A     A
# ...                        ...   ...
# JANIKOWSKI, Damian           L     W
# REZAEI, Ghasem Gholamreza    L     W
# TOTROV, Rustam               L     W
# ALEKSANYAN, Artur            L     W
# LIDBERG, Jimmy               L     W
#
# [31165 rows x 2 columns]

# %%
split1 = summer.groupby('Country')

# %%
l = list(split1)

# %%
l
# Out:
# [('AFG',
#                     Year     City      Sport Discipline Country Gender  \
#   Athlete
#   NIKPAI, Rohullah  2008  Beijing  Taekwondo  Taekwondo     AFG    Men
#   NIKPAI, Rohullah  2012   London  Taekwondo  Taekwondo     AFG    Men
#
#                          Event   Medal
#   Athlete
#   NIKPAI, Rohullah     - 58 KG  Bronze
#   NIKPAI, Rohullah  58 - 68 KG  Bronze  ),
#  ('AHO',
#                    Year   City    Sport Discipline Country Gender  \
#   Athlete
#   BOERSMA, Jan D.  1988  Seoul  Sailing    Sailing     AHO    Men
#
#                                  Event   Medal
#   Athlete
#   BOERSMA, Jan D.  Board (Division Ii)  Silver  ),
#  ('ALG',
#                         Year         City      Sport Discipline Country Gender  \
#   Athlete
#   ZAOUI, Mohamed        1984  Los Angeles     Boxing     Boxing     ALG    Men
#   MOUSSA, Mustapha      1984  Los Angeles     Boxing     Boxing     ALG    Men
# ...

# %%
split2 = summer.groupby(by = ['Country', 'Gender'])

# %%
l2 = list(split2)

# %%
l2
# Out:
# [(('AFG', 'Men'),
#                     Year     City      Sport Discipline Country Gender  \
#   Athlete
#   NIKPAI, Rohullah  2008  Beijing  Taekwondo  Taekwondo     AFG    Men
#   NIKPAI, Rohullah  2012   London  Taekwondo  Taekwondo     AFG    Men
#
#                          Event   Medal
#   Athlete
#   NIKPAI, Rohullah     - 58 KG  Bronze
#   NIKPAI, Rohullah  58 - 68 KG  Bronze  ),
#  (('AHO', 'Men'),
#                    Year   City    Sport Discipline Country Gender  \
#   Athlete
#   BOERSMA, Jan D.  1988  Seoul  Sailing    Sailing     AHO    Men
#
#                                  Event   Medal
#   Athlete
#   BOERSMA, Jan D.  Board (Division Ii)  Silver  ),
#  (('ALG', 'Men'),
#                         Year         City      Sport Discipline Country Gender  \
#   Athlete
#   ZAOUI, Mohamed        1984  Los Angeles     Boxing     Boxing     ALG    Men
#   MOUSSA, Mustapha      1984  Los Angeles     Boxing     Boxing     ALG    Men
# ...

# %%
l2[0]
# Out:
# (('AFG', 'Men'),
#                    Year     City      Sport Discipline Country Gender  \
#  Athlete
#  NIKPAI, Rohullah  2008  Beijing  Taekwondo  Taekwondo     AFG    Men
#  NIKPAI, Rohullah  2012   London  Taekwondo  Taekwondo     AFG    Men
#
#                         Event   Medal
#  Athlete
#  NIKPAI, Rohullah     - 58 KG  Bronze
#  NIKPAI, Rohullah  58 - 68 KG  Bronze  )

# %%
medals_per_country = summer.groupby('Country').Medal.count()
medals_per_country.sort_values(ascending = False)
# Out:
# Country
# USA    4585
# URS    2049
# GBR    1720
# FRA    1396
# GER    1305
#        ...
# NIG       1
# TOG       1
# TGA       1
# SUD       1
# UAE       1
# Name: Medal, Length: 147, dtype: int64

# %%
medals_per_country.plot(kind='bar', figsize=(20,10), fontsize=10)
# Out:
# <Axes: xlabel='Country'>
