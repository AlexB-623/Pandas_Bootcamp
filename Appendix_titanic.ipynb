# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
titanic = pd.read_csv('titanic.csv')
titanic2 = pd.read_csv('titanic.csv')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.describe(include= "O")
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %%
round(titanic, 0)
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked deck
# 0           0       3    male  22.0      1      0   7.0        S  NaN
# 1           1       1  female  38.0      1      0  71.0        C    C
# 2           1       3  female  26.0      0      0   8.0        S  NaN
# 3           1       1  female  35.0      1      0  53.0        S    C
# 4           0       3    male  35.0      0      0   8.0        S  NaN
# ..        ...     ...     ...   ...    ...    ...   ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0        S  NaN
# 887         1       1  female  19.0      0      0  30.0        S    B
# 888         0       3  female   NaN      1      2  23.0        S  NaN
# 889         1       1    male  26.0      0      0  30.0        C    C
# 890         0       3    male  32.0      0      0   8.0        Q  NaN
#
# [891 rows x 9 columns]

# %%
minage = min(titanic['age'])
maxage = max(titanic['age'])
print(minage, "&", maxage)
# Out:
# 0.42 & 80.0

# %%
max(titanic['fare'])
# Out:
# 512.3292

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck'],
#       dtype='object')

# %%
titanic.mean(numeric_only=True)
# Out:
# survived     0.383838
# pclass       2.308642
# age         29.699118
# sibsp        0.523008
# parch        0.381594
# fare        32.204208
# dtype: float64

# %%
titanic.median(numeric_only=True)
# Out:
# survived     0.0000
# pclass       3.0000
# age         28.0000
# sibsp        0.0000
# parch        0.0000
# fare        14.4542
# dtype: float64

# %%
type(titanic['age'])
# Out:
# pandas.core.series.Series

# %%
titanic[['age', 'sex', 'fare']]
# Out:
#       age     sex     fare
# 0    22.0    male   7.2500
# 1    38.0  female  71.2833
# 2    26.0  female   7.9250
# 3    35.0  female  53.1000
# 4    35.0    male   8.0500
# ..    ...     ...      ...
# 886  27.0    male  13.0000
# 887  19.0  female  30.0000
# 888   NaN  female  23.4500
# 889  26.0    male  30.0000
# 890  32.0    male   7.7500
#
# [891 rows x 3 columns]

# %%
type(titanic.survived)
# Out:
# pandas.core.series.Series

# %%
age = titanic['age']

# %%
age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64

# %%
age.sum()
# Out:
# np.float64(21205.17)

# %%
age.median()
# Out:
# np.float64(28.0)

# %%
age.nunique()
# Out:
# 88

# %%
age.unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
age.value_counts(sort=True, bins=10)
# Out:
# (16.336, 24.294]    177
# (24.294, 32.252]    169
# (32.252, 40.21]     118
# (40.21, 48.168]      70
# (0.339, 8.378]       54
# (8.378, 16.336]      46
# (48.168, 56.126]     45
# (56.126, 64.084]     24
# (64.084, 72.042]      9
# (72.042, 80.0]        2
# Name: count, dtype: int64

# %%
titanic['fare'].mode()[0]
# Out:
# np.float64(8.05)

# %%
titanic.sort_values(by='fare', ascending=False, inplace=True)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 679         1       1    male  36.0      0      1  512.3292        C    B
# 258         1       1  female  35.0      0      0  512.3292        C  NaN
# 737         1       1    male  35.0      0      0  512.3292        C    B
# 88          1       1  female  23.0      3      2  263.0000        S    C
# 438         0       1    male  64.0      1      4  263.0000        S    C
# ..        ...     ...     ...   ...    ...    ...       ...      ...  ...
# 806         0       1    male  39.0      0      0    0.0000        S    A
# 815         0       1    male   NaN      0      0    0.0000        S    B
# 466         0       2    male   NaN      0      0    0.0000        S  NaN
# 481         0       2    male   NaN      0      0    0.0000        S  NaN
# 822         0       1    male  38.0      0      0    0.0000        S  NaN
#
# [891 rows x 9 columns]

# %%
titanic.sex == 'male'
# Out:
# 679     True
# 258    False
# 737     True
# 88     False
# 438     True
#        ...
# 806     True
# 815     True
# 466     True
# 481     True
# 822     True
# Name: sex, Length: 891, dtype: bool

# %%
titanic_gents = titanic[titanic.sex == 'male']

# %%
titanic_ladies = titanic[titanic.sex == 'female']

# %%
titanic_gents['fare']
# Out:
# 679    512.3292
# 737    512.3292
# 438    263.0000
# 27     263.0000
# 118    247.5208
#          ...
# 806      0.0000
# 815      0.0000
# 466      0.0000
# 481      0.0000
# 822      0.0000
# Name: fare, Length: 577, dtype: float64

# %%
titanic[titanic.sex == 'male']['fare']
# Out:
# 679    512.3292
# 737    512.3292
# 438    263.0000
# 27     263.0000
# 118    247.5208
#          ...
# 806      0.0000
# 815      0.0000
# 466      0.0000
# 481      0.0000
# 822      0.0000
# Name: fare, Length: 577, dtype: float64

# %%
titanic.loc[titanic.sex == 'male']
# Out:
#      survived  pclass   sex   age  sibsp  parch      fare embarked deck
# 679         1       1  male  36.0      0      1  512.3292        C    B
# 737         1       1  male  35.0      0      0  512.3292        C    B
# 438         0       1  male  64.0      1      4  263.0000        S    C
# 27          0       1  male  19.0      3      2  263.0000        S    C
# 118         0       1  male  24.0      0      1  247.5208        C    B
# ..        ...     ...   ...   ...    ...    ...       ...      ...  ...
# 806         0       1  male  39.0      0      0    0.0000        S    A
# 815         0       1  male   NaN      0      0    0.0000        S    B
# 466         0       2  male   NaN      0      0    0.0000        S  NaN
# 481         0       2  male   NaN      0      0    0.0000        S  NaN
# 822         0       1  male  38.0      0      0    0.0000        S  NaN
#
# [577 rows x 9 columns]

# %%
mask1 = titanic.sex == "male"
mask5 = titanic.sex == "female"
mask2 = titanic.dtypes == "object"
mask3 = titanic.age > 14
mask4 = titanic.age < 14

# %%
mask1
# Out:
# 679     True
# 258    False
# 737     True
# 88     False
# 438     True
#        ...
# 806     True
# 815     True
# 466     True
# 481     True
# 822     True
# Name: sex, Length: 891, dtype: bool

# %%
titanic.loc[mask1]
# Out:
#      survived  pclass   sex   age  sibsp  parch      fare embarked deck
# 679         1       1  male  36.0      0      1  512.3292        C    B
# 737         1       1  male  35.0      0      0  512.3292        C    B
# 438         0       1  male  64.0      1      4  263.0000        S    C
# 27          0       1  male  19.0      3      2  263.0000        S    C
# 118         0       1  male  24.0      0      1  247.5208        C    B
# ..        ...     ...   ...   ...    ...    ...       ...      ...  ...
# 806         0       1  male  39.0      0      0    0.0000        S    A
# 815         0       1  male   NaN      0      0    0.0000        S    B
# 466         0       2  male   NaN      0      0    0.0000        S  NaN
# 481         0       2  male   NaN      0      0    0.0000        S  NaN
# 822         0       1  male  38.0      0      0    0.0000        S  NaN
#
# [577 rows x 9 columns]

# %%
mask2
# Out:
# survived    False
# pclass      False
# sex          True
# age         False
# sibsp       False
# parch       False
# fare        False
# embarked     True
# deck         True
# dtype: bool

# %%
titanic.loc[:, mask2]
# Out:
#         sex embarked deck
# 679    male        C    B
# 258  female        C  NaN
# 737    male        C    B
# 88   female        S    C
# 438    male        S    C
# ..      ...      ...  ...
# 806    male        S    A
# 815    male        S    B
# 466    male        S  NaN
# 481    male        S  NaN
# 822    male        S  NaN
#
# [891 rows x 3 columns]

# %%
titanic.loc[mask1, ~mask2]
# Out:
#      survived  pclass   age  sibsp  parch      fare
# 679         1       1  36.0      0      1  512.3292
# 737         1       1  35.0      0      0  512.3292
# 438         0       1  64.0      1      4  263.0000
# 27          0       1  19.0      3      2  263.0000
# 118         0       1  24.0      0      1  247.5208
# ..        ...     ...   ...    ...    ...       ...
# 806         0       1  39.0      0      0    0.0000
# 815         0       1   NaN      0      0    0.0000
# 466         0       2   NaN      0      0    0.0000
# 481         0       2   NaN      0      0    0.0000
# 822         0       1  38.0      0      0    0.0000
#
# [577 rows x 6 columns]

# %%
men = titanic.loc[mask1 & mask3]
women_n_children = titanic.loc[mask5 | mask4]

# %%
men.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  414.000000  414.000000  414.000000  414.000000  414.000000  414.000000
# mean     0.173913    2.309179   33.129227    0.268116    0.169082   26.533312
# std      0.379493    0.829868   12.922177    0.546260    0.557068   47.151630
# min      0.000000    1.000000   15.000000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   23.000000    0.000000    0.000000    7.895800
# 50%      0.000000    3.000000   30.000000    0.000000    0.000000   10.500000
# 75%      0.000000    3.000000   40.000000    0.000000    0.000000   26.550000
# max      1.000000    3.000000   80.000000    4.000000    5.000000  512.329200

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
women_n_children.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  351.000000  351.000000  298.000000  351.000000  351.000000  351.000000
# mean     0.723647    2.205128   25.039161    0.846154    0.723647   43.441786
# std      0.447832    0.847232   15.314631    1.306787    1.008809   55.676194
# min      0.000000    1.000000    0.420000    0.000000    0.000000    6.750000
# 25%      0.000000    1.000000   14.125000    0.000000    0.000000   12.475000
# 50%      1.000000    2.000000   24.000000    0.000000    0.000000   24.150000
# 75%      1.000000    3.000000   35.000000    1.000000    1.000000   51.931250
# max      1.000000    3.000000   63.000000    8.000000    6.000000  512.329200

# %%
1912 - titanic.age
# Out:
# 679    1876.0
# 258    1877.0
# 737    1877.0
# 88     1889.0
# 438    1848.0
#         ...
# 806    1873.0
# 815       NaN
# 466       NaN
# 481       NaN
# 822    1874.0
# Name: age, Length: 891, dtype: float64

# %%
titanic['birth_year'] = 1912 - titanic.age

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck  \
# 679         1       1    male  36.0      0      1  512.3292        C    B
# 258         1       1  female  35.0      0      0  512.3292        C  NaN
# 737         1       1    male  35.0      0      0  512.3292        C    B
# 88          1       1  female  23.0      3      2  263.0000        S    C
# 438         0       1    male  64.0      1      4  263.0000        S    C
# ..        ...     ...     ...   ...    ...    ...       ...      ...  ...
# 806         0       1    male  39.0      0      0    0.0000        S    A
# 815         0       1    male   NaN      0      0    0.0000        S    B
# 466         0       2    male   NaN      0      0    0.0000        S  NaN
# 481         0       2    male   NaN      0      0    0.0000        S  NaN
# 822         0       1    male  38.0      0      0    0.0000        S  NaN
#
#      birth_year
# 679      1876.0
# 258      1877.0
# 737      1877.0
# ...

# %%
titanic["relatives"] = titanic.sibsp + titanic.parch

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck  \
# 679         1       1    male  36.0      0      1  512.3292        C    B
# 258         1       1  female  35.0      0      0  512.3292        C  NaN
# 737         1       1    male  35.0      0      0  512.3292        C    B
# 88          1       1  female  23.0      3      2  263.0000        S    C
# 438         0       1    male  64.0      1      4  263.0000        S    C
# ..        ...     ...     ...   ...    ...    ...       ...      ...  ...
# 806         0       1    male  39.0      0      0    0.0000        S    A
# 815         0       1    male   NaN      0      0    0.0000        S    B
# 466         0       2    male   NaN      0      0    0.0000        S  NaN
# 481         0       2    male   NaN      0      0    0.0000        S  NaN
# 822         0       1    male  38.0      0      0    0.0000        S  NaN
#
#      birth_year  relatives
# 679      1876.0          1
# ...

# %%
titanic.drop(columns=['sibsp', 'parch'], inplace=True)

# %%
titanic
# Out:
#      survived  pclass     sex   age      fare embarked deck  birth_year  \
# 679         1       1    male  36.0  512.3292        C    B      1876.0
# 258         1       1  female  35.0  512.3292        C  NaN      1877.0
# 737         1       1    male  35.0  512.3292        C    B      1877.0
# 88          1       1  female  23.0  263.0000        S    C      1889.0
# 438         0       1    male  64.0  263.0000        S    C      1848.0
# ..        ...     ...     ...   ...       ...      ...  ...         ...
# 806         0       1    male  39.0    0.0000        S    A      1873.0
# 815         0       1    male   NaN    0.0000        S    B         NaN
# 466         0       2    male   NaN    0.0000        S  NaN         NaN
# 481         0       2    male   NaN    0.0000        S  NaN         NaN
# 822         0       1    male  38.0    0.0000        S  NaN      1874.0
#
#      relatives
# 679          1
# 258          0
# 737          0
# 88           5
# 438          5
# ...

# %%
inflation = 10

# %%
titanic['inflation_adj_fare'] = titanic.fare*inflation

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'fare', 'embarked', 'deck',
#        'birth_year', 'relatives', 'inflation_adj_fare'],
#       dtype='object')

# %%
new_order = ['age', 'birth_year', 'sex', 'fare', 'inflation_adj_fare', 'pclass', 'deck', 'embarked', 'relatives', 'survived']

# %%
titanic['fare_EUR'] = titanic.fare / 1.1

# %%
titanic
# Out:
#      survived  pclass     sex   age      fare embarked deck  birth_year  \
# 679         1       1    male  36.0  512.3292        C    B      1876.0
# 258         1       1  female  35.0  512.3292        C  NaN      1877.0
# 737         1       1    male  35.0  512.3292        C    B      1877.0
# 88          1       1  female  23.0  263.0000        S    C      1889.0
# 438         0       1    male  64.0  263.0000        S    C      1848.0
# ..        ...     ...     ...   ...       ...      ...  ...         ...
# 806         0       1    male  39.0    0.0000        S    A      1873.0
# 815         0       1    male   NaN    0.0000        S    B         NaN
# 466         0       2    male   NaN    0.0000        S  NaN         NaN
# 481         0       2    male   NaN    0.0000        S  NaN         NaN
# 822         0       1    male  38.0    0.0000        S  NaN      1874.0
#
#      relatives  inflation_adj_fare    fare_EUR
# 679          1            5123.292  465.753818
# ...

# %%
titanic.plot(kind="box",subplots=True, figsize=(20, 10), sharex=False, sharey=False)
plt.show()

# %%
titanic_slice = titanic.iloc[:10, [2,3]]

# %%
titanic_slice
# Out:
#         sex   age
# 679    male  36.0
# 258  female  35.0
# 737    male  35.0
# 88   female  23.0
# 438    male  64.0
# 341  female  24.0
# 27     male  19.0
# 742  female  21.0
# 311  female  18.0
# 299  female  50.0

# %%
gbo = titanic_slice.groupby('sex').mean()
gbo
# Out:
#          age
# sex
# female  28.5
# male    38.5

# %%
l = list(gbo)

# %%
l[0]
# Out:
# ('female',
#          sex   age
#  258  female  35.0
#  88   female  23.0
#  341  female  24.0
#  742  female  21.0
#  311  female  18.0
#  299  female  50.0)

# %%
l[1]
# Out:
# ('male',
#        sex   age
#  679  male  36.0
#  737  male  35.0
#  438  male  64.0
#  27   male  19.0)

# %%
titanic.groupby('sex')[['fare','age']].max()
# Out:
#             fare   age
# sex
# female  512.3292  63.0
# male    512.3292  80.0

# %%
titanic.groupby('sex').fare.mean()
# Out:
# sex
# female    44.479818
# male      25.523893
# Name: fare, dtype: float64

# %%
titanic.groupby('pclass').survived.mean()
# Out:
# pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: survived, dtype: float64

# %%
titanic['ad_chi'] = "adult"

# %%
titanic.loc[titanic.age < 18, 'ad_chi'] = "child"

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
#     ad_chi
# 0    adult
# 1    adult
# 2    adult
# 3    adult
# 4    adult
# ..     ...
# ...

# %%
titanic.groupby(['sex', 'ad_chi']).survived.count()

# %%
w_and_c_first = titanic.groupby(['sex', 'ad_chi']).survived.mean().sort_values(ascending=False)

# %%
w_and_c_first.plot(kind='bar', figsize=(20, 10))
plt.xlabel("Groups")
plt.ylabel("Survival Rate")
plt.title("Survival Rate by Sex/Age")
plt.show()

# %%
# Out:
# sex     ad_chi
# female  adult     0.752896
#         child     0.690909
# male    child     0.396552
#         adult     0.165703
# Name: survived, dtype: float64
