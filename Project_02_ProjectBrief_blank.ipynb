# %% [markdown]
# # Project 2: Data Import - Working with Web APIs and JSON (Movies Dataset)

# %% [markdown]
# # Project Brief for Self-Coders

# %% [markdown]
# Here you´ll have the opportunity to code major parts of Project 2 on your own. If you need any help or inspiration, have a look at the Videos or the Jupyter Notebook with the full code. <br> <br>
# Keep in mind that it´s all about __getting the right results/conclusions__. It´s not about finding the identical code. Things can be coded in many different ways. Even if you come to the same conclusions, it´s very unlikely that we have the very same code.

# %% [markdown]
# ## Importing Data from JSON files

# %% [markdown]
# 1. __Import__ the json files __blockbusters.json__, __blockbusters2.json__, __blockbusters3.json__ and load the datasets into Pandas DataFrames.

# %%
import imdb_allpages
import pandas as pd
import numpy as np
from IPython.core.pylabtools import figsize
from IPython.display import HTML
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import requests
import json
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
API_KEY = 'caa25b0e059857eda52f7f7e728221dd'
TOKEN = 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjYWEyNWIwZTA1OTg1N2VkYTUyZjdmN2U3MjgyMjFkZCIsIm5iZiI6MTc0MDc3MjY5NC44MDMsInN1YiI6IjY3YzIxNTU2MDlhOWI4NDk2ZGRiZDVhOSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.bSQWWII0aRK_8SEn3qV7CxrNsJcyj2WJ05JugOHpki8'

# %% [markdown]
# ## Working with APIs and JSON (Part 1)

# %% [markdown]
# 2. __Create an account__ on https://www.themoviedb.org/

# %% [markdown]
# 3. Get your personal __API Key__

# %% [markdown]
# 4. __API-Request__ (movie module): Load all available information for the movie with __movie id = 140607__ into a Pandas DataFrame. <br> See https://developers.themoviedb.org/3/movies/get-movie-details for more information

# %%
def get_specific_movie(id):
    url = f'https://api.themoviedb.org/3/movie/{id}'
    response = requests.get(url, headers={'Authorization': 'Bearer ' + TOKEN})
    return (response, response.json())

def search_by_title(title):
    url = f'https://api.themoviedb.org/3/search/movie?query={title}'
    response = requests.get(url, headers={'Authorization': 'Bearer ' + TOKEN})
    return (response, response.json())

# def search_by_date(date_range):
#     """
#     :param date_range: tuple with a start date and a stop date yyyy-mm-dd
#     :return:
#     """
#     url = f"https://api.themoviedb.org/3/discover/movie?&include_adult-true&primary_release_date.gte={date_range[0]}&primary_release_date.lte={date_range[1]}"
#     response = requests.get(url, headers={'Authorization': 'Bearer ' + TOKEN})
#     return (response, response.json())
#

# %%
star_wars_og = get_specific_movie(11)

# %%
star_wars_og[1]
# Out:
# {'adult': False,
#  'backdrop_path': '/2w4xG178RpB4MDAIfTkqAuSJzec.jpg',
#  'belongs_to_collection': {'id': 10,
#   'name': 'Star Wars Collection',
#   'poster_path': '/aSrMJYmQX8kpF26LijkCsYhBMvm.jpg',
#   'backdrop_path': '/zZDkgOmFMVYpGAkR9Tkxw0CRnxX.jpg'},
#  'budget': 11000000,
#  'genres': [{'id': 12, 'name': 'Adventure'},
#   {'id': 28, 'name': 'Action'},
#   {'id': 878, 'name': 'Science Fiction'}],
#  'homepage': 'http://www.starwars.com/films/star-wars-episode-iv-a-new-hope',
#  'id': 11,
#  'imdb_id': 'tt0076759',
#  'origin_country': ['US'],
#  'original_language': 'en',
#  'original_title': 'Star Wars',
#  'overview': 'Princess Leia is captured and held hostage by the evil Imperial forces in their effort to take over the galactic Empire. Venturesome Luke Skywalker and dashing captain Han Solo team together with the loveable robot duo R2-D2 and C-3PO to rescue the beautiful princess and restore peace and justice in the Empire.',
#  'popularity': 107.66,
#  'poster_path': '/6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg',
#  'production_companies': [{'id': 1,
#    'logo_path': '/tlVSws0RvvtPBwViUyOFAO0vcQS.png',
#    'name': 'Lucasfilm Ltd.',
#    'origin_country': 'US'},
#   {'id': 25,
#    'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png',
#    'name': '20th Century Fox',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '1977-05-25',
#  'revenue': 775398007,
#  'runtime': 121,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'A long time ago in a galaxy far, far away...',
#  'title': 'Star Wars',
#  'video': False,
#  'vote_average': 8.203,
#  'vote_count': 20922}

# %%
sw_tfa = get_specific_movie(140607)

# %%
sw_tfa
# Out:
# (<Response [200]>,
#  {'adult': False,
#   'backdrop_path': '/k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg',
#   'belongs_to_collection': {'id': 10,
#    'name': 'Star Wars Collection',
#    'poster_path': '/aSrMJYmQX8kpF26LijkCsYhBMvm.jpg',
#    'backdrop_path': '/zZDkgOmFMVYpGAkR9Tkxw0CRnxX.jpg'},
#   'budget': 245000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'http://www.starwars.com/films/star-wars-episode-vii',
#   'id': 140607,
#   'imdb_id': 'tt2488496',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Star Wars: The Force Awakens',
#   'overview': 'Thirty years after defeating the Galactic Empire, Han Solo and his allies face a new threat from the evil Kylo Ren and his army of Stormtroopers.',
#   'popularity': 78.023,
#   'poster_path': '/wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg',
#   'production_companies': [{'id': 1,
#     'logo_path': '/tlVSws0RvvtPBwViUyOFAO0vcQS.png',
#     'name': 'Lucasfilm Ltd.',
#     'origin_country': 'US'},
#    {'id': 11461,
#     'logo_path': '/p9FoEt5shEKRWRKVIlvFaEmRnun.png',
#     'name': 'Bad Robot',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2015-12-15',
#   'revenue': 2068223624,
#   'runtime': 136,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Every generation has a story.',
#   'title': 'Star Wars: The Force Awakens',
#   'video': False,
#   'vote_average': 7.264,
#   'vote_count': 19573})

# %%
idiocracy = search_by_title('idiocracy')

# %%
idiocracy
# Out:
# (<Response [200]>,
#  {'page': 1,
#   'results': [{'adult': False,
#     'backdrop_path': '/9Z4msMhKvNp63sOB1ZvxPMPvqz3.jpg',
#     'genre_ids': [35, 878, 12, 53],
#     'id': 7512,
#     'original_language': 'en',
#     'original_title': 'Idiocracy',
#     'overview': "To test its top-secret Human Hibernation Project, the Pentagon picks the most average Americans it can find - an Army private and a prostitute - and sends them to the year 2505 after a series of freak events. But when they arrive, they find a civilization so dumbed-down that they're the smartest people around.",
#     'popularity': 35.404,
#     'poster_path': '/q7sn0A3BkBxvzdwVFOGmJGE2vF8.jpg',
#     'release_date': '2006-09-01',
#     'title': 'Idiocracy',
#     'video': False,
#     'vote_average': 6.3,
#     'vote_count': 3072}],
#   'total_pages': 1,
#   'total_results': 1})

# %%
idiocracy[1]['results'][0]['id']
# Out:
# 7512

# %%
if str(idiocracy[0]) == '<Response [200]>':
    id_for_get = idiocracy[1]['results'][0]['id']

# %%
idiocracy_direct = get_specific_movie(7512)

# %%
idiocracy_direct
# Out:
# (<Response [200]>,
#  {'adult': False,
#   'backdrop_path': '/9Z4msMhKvNp63sOB1ZvxPMPvqz3.jpg',
#   'belongs_to_collection': None,
#   'budget': 30000000,
#   'genres': [{'id': 35, 'name': 'Comedy'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://ahighlight.com',
#   'id': 7512,
#   'imdb_id': 'tt0387808',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Idiocracy',
#   'overview': "To test its top-secret Human Hibernation Project, the Pentagon picks the most average Americans it can find - an Army private and a prostitute - and sends them to the year 2505 after a series of freak events. But when they arrive, they find a civilization so dumbed-down that they're the smartest people around.",
#   'popularity': 35.404,
#   'poster_path': '/q7sn0A3BkBxvzdwVFOGmJGE2vF8.jpg',
#   'production_companies': [{'id': 25,
#     'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png',
#     'name': '20th Century Fox',
#     'origin_country': 'US'},
#    {'id': 19985,
#     'logo_path': None,
#     'name': 'Ternion Pictures',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2006-09-01',
#   'revenue': 495303,
#   'runtime': 84,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'In the future, intelligence is extinct.',
#   'title': 'Idiocracy',
#   'video': False,
#   'vote_average': 6.3,
#   'vote_count': 3072})

# %% [markdown]
# o## Working with APIs and JSON (Part 2)

# %% [markdown]
# 5. __API-Request__ (discover module): Load all movies with __release date between 2020-01-01 and 2020-02-29__ into a Pandas DataFrame. <br>
# See https://www.themoviedb.org/documentation/api/discover and https://developers.themoviedb.org/3/discover/movie-discover for more information.

# %%
date_range_search = imdb_allpages.date_search(('2020-01-01', '2020-02-29'))

# %%
date_range_search
# Out:
# [{'adult': False,
#   'backdrop_path': '/stmYfCUGd8Iy6kAMBr6AmWqx8Bq.jpg',
#   'genre_ids': [28, 878, 35, 10751],
#   'id': 454626,
#   'original_language': 'en',
#   'original_title': 'Sonic the Hedgehog',
#   'overview': 'Powered with incredible speed, Sonic The Hedgehog embraces his new home on Earth. That is, until Sonic sparks the attention of super-uncool evil genius Dr. Robotnik. Now it’s super-villain vs. super-sonic in an all-out race across the globe to stop Robotnik from using Sonic’s unique power for world domination.',
#   'popularity': 124.039,
#   'poster_path': '/aQvJ5WPzZgYVDrxLX4R6cLJCEaQ.jpg',
#   'release_date': '2020-02-12',
#   'title': 'Sonic the Hedgehog',
#   'video': False,
#   'vote_average': 7.308,
#   'vote_count': 9798},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [18],
#   'id': 1299314,
#   'original_language': 'ko',
#   'original_title': '후배부부와 교환섹스 2',
#   'overview': '',
#   'popularity': 79.451,
#   'poster_path': '/4roZrvGt9cTjWroD8iquIvcBddJ.jpg',
#   'release_date': '2020-02-07',
#   'title': '후배부부와 교환섹스 2',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': '/eAIHqfS3kXm7kZl4j7ZBfdegyEz.jpg',
#   'genre_ids': [53, 28, 80],
#   'id': 38700,
#   'original_language': 'en',
#   'original_title': 'Bad Boys for Life',
#   'overview': 'Marcus and Mike are forced to confront new threats, career changes, and midlife crises as they join the newly created elite team AMMO of the Miami police department to take down the ruthless Armando Armas, the vicious leader of a Miami drug cartel.',
#   'popularity': 62.814,
#   'poster_path': '/y95lQLnuNKdPAzw9F9Ab8kJ80c3.jpg',
#   'release_date': '2020-01-15',
#   'title': 'Bad Boys for Life',
#   'video': False,
#   'vote_average': 7.135,
#   'vote_count': 8354},
#  {'adult': False,
#   'backdrop_path': '/3zBjU7mXlzxJKAStRzlNDZRGT0m.jpg',
#   'genre_ids': [28, 80],
#   'id': 495764,
#   'original_language': 'en',
#   'original_title': 'Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn)',
#   'overview': 'Harley Quinn joins forces with a singer, an assassin and a police detective to help a young girl who had a hit placed on her after she stole a rare diamond from a crime lord.',
#   'popularity': 48.401,
#   'poster_path': '/h4VB6m0RwcicVEZvzftYZyKXs6K.jpg',
#   'release_date': '2020-02-05',
#   'title': 'Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn)',
#   'video': False,
#   'vote_average': 6.9,
#   'vote_count': 10351},
#  {'adult': False,
#   'backdrop_path': '/tintsaQ0WLzZsTMkTiqtMB3rfc8.jpg',
#   'genre_ids': [28, 80, 35],
#   'id': 522627,
#   'original_language': 'en',
#   'original_title': 'The Gentlemen',
#   'overview': 'American expat Mickey Pearson has built a highly profitable marijuana empire in London. When word gets out that he’s looking to cash out of the business forever it triggers plots, schemes, bribery and blackmail in an attempt to steal his domain out from under him.',
#   'popularity': 42.65,
#   'poster_path': '/jtrhTYB7xSrJxR1vusu99nvnZ1g.jpg',
#   'release_date': '2020-01-01',
#   'title': 'The Gentlemen',
#   'video': False,
#   'vote_average': 7.7,
#   'vote_count': 5963},
#  {'adult': False,
#   'backdrop_path': '/1GZCV0dwIoAn6jpWPfVAbeMTVC2.jpg',
#   'genre_ids': [12, 10751, 18],
#   'id': 481848,
#   'original_language': 'en',
#   'original_title': 'The Call of the Wild',
#   'overview': 'Buck is a big-hearted dog whose blissful domestic life is turned upside down when he is suddenly uprooted from his California home and transplanted to the exotic wilds of the Yukon during the Gold Rush of the 1890s. As the newest rookie on a mail delivery dog sled team—and later its leader—Buck experiences the adventure of a lifetime, ultimately finding his true place in the world and becoming his own master.',
#   'popularity': 39.582,
#   'poster_path': '/33VdppGbeNxICrFUtW2WpGHvfYc.jpg',
#   'release_date': '2020-02-19',
#   'title': 'The Call of the Wild',
#   'video': False,
#   'vote_average': 7.5,
#   'vote_count': 3767},
#  {'adult': False,
#   'backdrop_path': '/tweDJNQzBGgsWVF5MC8JhSAk07p.jpg',
#   'genre_ids': [53, 878, 27],
#   'id': 570670,
#   'original_language': 'en',
#   'original_title': 'The Invisible Man',
#   'overview': "When Cecilia's abusive ex takes his own life and leaves her his fortune, she suspects his death was a hoax. As a series of coincidences turn lethal, Cecilia works to prove that she is being hunted by someone nobody can see.",
#   'popularity': 30.229,
#   'poster_path': '/5EufsDwXdY2CVttYOk2WtYhgKpa.jpg',
#   'release_date': '2020-02-26',
#   'title': 'The Invisible Man',
#   'video': False,
#   'vote_average': 7.1,
#   'vote_count': 5803},
#  {'adult': False,
#   'backdrop_path': '/77xFxLtD2jGpOrcjJbCez2wZWX1.jpg',
#   'genre_ids': [10749],
#   'id': 698818,
#   'original_language': 'ko',
#   'original_title': '음란 주택: 노예가 된 아내',
#   'overview': 'Hyun-jung, who moved to a local mansion, was delighted with unexpected luck. She hated the noise between the floors so she wanted a quiet place with soundproofing. Since the tenants were mostly working couples, the mansion is quiet like a haunted city.',
#   'popularity': 35.633,
#   'poster_path': '/1VfuzK2Qx1tIGE1nhn2G2ilF7RN.jpg',
#   'release_date': '2020-02-06',
#   'title': 'Obscene House: Slave Wife',
#   'video': False,
#   'vote_average': 5.5,
#   'vote_count': 2},
#  {'adult': False,
#   'backdrop_path': '/txaC2mhUhW0H0r31N6KzRTaz1rL.jpg',
#   'genre_ids': [10749, 35],
#   'id': 565426,
#   'original_language': 'en',
#   'original_title': 'To All the Boys: P.S. I Still Love You',
#   'overview': 'Lara Jean and Peter have just taken their romance from pretend to officially real when another recipient of one of her love letters enters the picture.',
#   'popularity': 30.507,
#   'poster_path': '/maib5VlmEqp5xlN8lptnBSftp2o.jpg',
#   'release_date': '2020-02-03',
#   'title': 'To All the Boys: P.S. I Still Love You',
#   'video': False,
#   'vote_average': 6.8,
#   'vote_count': 2583},
#  {'adult': False,
#   'backdrop_path': '/sizHX5VbwlBihaathTQHVGk1jdi.jpg',
#   'genre_ids': [878, 18, 28],
#   'id': 514207,
#   'original_language': 'ru',
#   'original_title': 'Вторжение',
#   'overview': 'Two years after the fall of the alien ship, the life of a young woman from Moscow has been changed forever. Her growing powers are now at the focus of both human and celestial investigation: an alien force takes an interest in her, and will stop short of nothing, including an invasion. Can love and compassion save humanity, when faced with a much greater and more demanding test this time?',
#   'popularity': 37.042,
#   'poster_path': '/eNkewJGOW44OznlnfXA8ewWPPmI.jpg',
#   'release_date': '2020-02-27',
#   'title': 'Invasion',
#   'video': False,
#   'vote_average': 6.9,
#   'vote_count': 814},
#  {'adult': False,
#   'backdrop_path': '/ww7eC3BqSbFsyE5H5qMde8WkxJ2.jpg',
#   'genre_ids': [27, 878, 28, 12],
#   'id': 443791,
#   'original_language': 'en',
#   'original_title': 'Underwater',
#   'overview': 'After an earthquake destroys their underwater station, six researchers must navigate two miles along the dangerous, unknown depths of the ocean floor to make it to safety in a race against time.',
#   'popularity': 23.669,
#   'poster_path': '/gzlbb3yeVISpQ3REd3Ga1scWGTU.jpg',
#   'release_date': '2020-01-08',
#   'title': 'Underwater',
#   'video': False,
#   'vote_average': 6.287,
#   'vote_count': 3170},
#  {'adult': False,
#   'backdrop_path': '/xFxk4vnirOtUxpOEWgA1MCRfy6J.jpg',
#   'genre_ids': [10751, 16, 12, 35, 14],
#   'id': 508439,
#   'original_language': 'en',
#   'original_title': 'Onward',
#   'overview': 'In a suburban fantasy world, two teenage elf brothers embark on an extraordinary quest to discover if there is still a little magic left out there.',
#   'popularity': 29.339,
#   'poster_path': '/f4aul3FyD3jv3v4bul1IrkWZvzq.jpg',
#   'release_date': '2020-02-29',
#   'title': 'Onward',
#   'video': False,
#   'vote_average': 7.7,
#   'vote_count': 6212},
#  {'adult': False,
#   'backdrop_path': '/27nn2YJBwY7a1etZ0AiIcOrIgu3.jpg',
#   'genre_ids': [10749, 18],
#   'id': 664413,
#   'original_language': 'pl',
#   'original_title': '365 dni',
#   'overview': 'A woman falls victim to a dominant mafia boss, who imprisons her and gives her one year to fall in love with him.',
#   'popularity': 25.732,
#   'poster_path': '/6KwrHucIE3CvNT7kTm2MAlZ4fYF.jpg',
#   'release_date': '2020-02-07',
#   'title': '365 Days',
#   'video': False,
#   'vote_average': 7.028,
#   'vote_count': 9106},
#  {'adult': False,
#   'backdrop_path': '/xcUf6yIheo78btFqihlRLftdR3M.jpg',
#   'genre_ids': [10751, 35, 14, 12],
#   'id': 448119,
#   'original_language': 'en',
#   'original_title': 'Dolittle',
#   'overview': 'After losing his wife seven years earlier, the eccentric Dr. John Dolittle, famed doctor and veterinarian of Queen Victoria’s England, hermits himself away behind the high walls of Dolittle Manor with only his menagerie of exotic animals for company. But when the young queen falls gravely ill, a reluctant Dolittle is forced to set sail on an epic adventure to a mythical island in search of a cure, regaining his wit and courage as he crosses old adversaries and discovers wondrous creatures.',
#   'popularity': 26.11,
#   'poster_path': '/uoplwswBDy7gsOyrbGuKyPFoPCs.jpg',
#   'release_date': '2020-01-02',
#   'title': 'Dolittle',
#   'video': False,
#   'vote_average': 6.6,
#   'vote_count': 3669},
#  {'adult': False,
#   'backdrop_path': '/4FbTBvNO3VTFbFFghipK7Jqz7I6.jpg',
#   'genre_ids': [18],
#   'id': 552532,
#   'original_language': 'en',
#   'original_title': 'Charm City Kings',
#   'overview': 'Mouse desperately wants to join The Midnight Clique, the infamous Baltimore dirt bike riders who rule the summertime streets. When Midnight’s leader, Blax, takes 14-year-old Mouse under his wing, Mouse soon finds himself torn between the straight-and-narrow and a road filled with fast money and violence.',
#   'popularity': 25.175,
#   'poster_path': '/8oiMFMarbRpcusASIX4cjVXoZKI.jpg',
#   'release_date': '2020-01-27',
#   'title': 'Charm City Kings',
#   'video': False,
#   'vote_average': 7.8,
#   'vote_count': 476},
#  {'adult': False,
#   'backdrop_path': '/wD9UaqaSEYqEPa1NSdowL40LI3a.jpg',
#   'genre_ids': [10749],
#   'id': 705862,
#   'original_language': 'ja',
#   'original_title': 'Red',
#   'overview': 'A married woman with a lovely daughter lives a carefree life, until she meets her ex-lover at a friend’s wedding. They haven’t seen each other in ten years, but they begin an affair.',
#   'popularity': 22.675,
#   'poster_path': '/4KykwGCfN45vPhuNUlpey3H1ev5.jpg',
#   'release_date': '2020-02-21',
#   'title': 'Red',
#   'video': False,
#   'vote_average': 4.7,
#   'vote_count': 96},
#  {'adult': False,
#   'backdrop_path': '/xHvTWX9qesT7YsiwuxgCD0Ok4fN.jpg',
#   'genre_ids': [35, 10749],
#   'id': 556678,
#   'original_language': 'en',
#   'original_title': 'Emma.',
#   'overview': 'In 1800s England, a well-meaning but selfish young woman meddles in the love lives of her friends.',
#   'popularity': 21.838,
#   'poster_path': '/uHpHzbHLSsVmAuuGuQSpyVDZmDc.jpg',
#   'release_date': '2020-02-13',
#   'title': 'Emma.',
#   'video': False,
#   'vote_average': 7.0,
#   'vote_count': 1772},
#  {'adult': False,
#   'backdrop_path': '/jgj73WS5IJq8OCGNZJUBGV6mkkK.jpg',
#   'genre_ids': [28, 35],
#   'id': 604362,
#   'original_language': 'ko',
#   'original_title': '히트맨',
#   'overview': "A failing webtoon artist finds he's drawn a target on his own back after publishing a story containing real secrets from his former life as a superspy.",
#   'popularity': 22.378,
#   'poster_path': '/dAt3nolyXLEEuXiIXZwv1iikbcA.jpg',
#   'release_date': '2020-01-22',
#   'title': 'Hitman: Agent Jun',
#   'video': False,
#   'vote_average': 7.164,
#   'vote_count': 70},
#  {'adult': False,
#   'backdrop_path': '/tcrNJfyNEIqaBR8Ogkgnq5xQJnf.jpg',
#   'genre_ids': [10749, 18],
#   'id': 342470,
#   'original_language': 'en',
#   'original_title': 'All the Bright Places',
#   'overview': 'Two teens facing personal struggles form a powerful bond as they embark on a cathartic journey chronicling the wonders of Indiana.',
#   'popularity': 22.521,
#   'poster_path': '/4SafxuMKQiw4reBiWKVZJpJn80I.jpg',
#   'release_date': '2020-02-28',
#   'title': 'All the Bright Places',
#   'video': False,
#   'vote_average': 7.6,
#   'vote_count': 2895},
#  {'adult': False,
#   'backdrop_path': '/i8A48JMwskyuwyKXRZiMnJezKst.jpg',
#   'genre_ids': [53, 80, 18],
#   'id': 526007,
#   'original_language': 'en',
#   'original_title': 'The Night Clerk',
#   'overview': 'Hotel night clerk Bart Bromley is a highly intelligent young man on the Autism spectrum. When a woman is murdered during his shift, Bart becomes the prime suspect. As the police investigation closes in, Bart makes a personal connection with a beautiful guest named Andrea, but soon realises he must stop the real murderer before she becomes the next victim.',
#   'popularity': 21.758,
#   'poster_path': '/hPWjid7yMatyIDHvku7lCMN7zSi.jpg',
#   'release_date': '2020-02-19',
#   'title': 'The Night Clerk',
#   'video': False,
#   'vote_average': 6.2,
#   'vote_count': 815},
#  {'adult': False,
#   'backdrop_path': '/x80ZIVGUJ6plcUBcgVZ6DPKT7vc.jpg',
#   'genre_ids': [12, 14, 27, 9648],
#   'id': 539537,
#   'original_language': 'en',
#   'original_title': 'Fantasy Island',
#   'overview': 'A group of contest winners arrive at an island hotel to live out their dreams, only to find themselves trapped in nightmare scenarios.',
#   'popularity': 14.672,
#   'poster_path': '/8ZMrZGGW65ePWIgRn1260nA1uUm.jpg',
#   'release_date': '2020-02-12',
#   'title': 'Fantasy Island',
#   'video': False,
#   'vote_average': 5.8,
#   'vote_count': 2488},
#  {'adult': False,
#   'backdrop_path': '/xYiPGeQd4AVuLxR9cGdce0B4w3y.jpg',
#   'genre_ids': [53, 18, 27],
#   'id': 715756,
#   'original_language': 'ja',
#   'original_title': '性の劇薬',
#   'overview': 'Katsuragi, an elite office worker who fell from a perfect life, drunkenly attempted to jump and commit suicide. Suddenly, he was helped by a mysterious man, Yoda, but that was the beginning of a horrible life of confinement training...',
#   'popularity': 21.528,
#   'poster_path': '/8c26QTZBBx04wK7dWBmmRQDp0M5.jpg',
#   'release_date': '2020-02-14',
#   'title': 'Dangerous Drugs of Sex',
#   'video': False,
#   'vote_average': 6.4,
#   'vote_count': 26},
#  {'adult': False,
#   'backdrop_path': '/ibgK9YRmUFW774aDVoFvogirg8b.jpg',
#   'genre_ids': [18],
#   'id': 665760,
#   'original_language': 'hr',
#   'original_title': 'Mare',
#   'overview': 'Routinely, but with dedication, Mare runs her small family’s modest household, even though a new washing machine is not the only thing that is missing. When a chance encounter rekindles her libido, she does not hold back for long.',
#   'popularity': 17.186,
#   'poster_path': '/2uQBgKCNkFm94R9pHaUnY4zwYlR.jpg',
#   'release_date': '2020-02-23',
#   'title': 'Mare',
#   'video': False,
#   'vote_average': 5.4,
#   'vote_count': 16},
#  {'adult': False,
#   'backdrop_path': '/tQprwIKzFx83JpM5dVrGRC4UpF.jpg',
#   'genre_ids': [16, 12, 14, 9648, 18, 878],
#   'id': 573730,
#   'original_language': 'ja',
#   'original_title': '劇場版メイドインアビス 深き魂の黎明',
#   'overview': "A continuation of the epic adventure of plucky Riko and Reg who are joined by their new friend Nanachi. Together they descend into the Abyss' treacherous fifth layer, the Sea of Corpses, and encounter the mysterious Bondrewd, a legendary White Whistle whose shadow looms over Nanachi's troubled past. Bondrewd is ingratiatingly hospitable, but the brave adventurers know things are not always as they seem in the enigmatic Abyss.",
#   'popularity': 18.914,
#   'poster_path': '/fsPZdpocYYbvDS2YEE1Xohqo1ni.jpg',
#   'release_date': '2020-01-17',
#   'title': 'Made in Abyss: Dawn of the Deep Soul',
#   'video': False,
#   'vote_average': 7.8,
#   'vote_count': 234},
#  {'adult': False,
#   'backdrop_path': '/jeiVmutYPZyQRSYk7OvyWENGIrA.jpg',
#   'genre_ids': [27, 9648, 53],
#   'id': 555974,
#   'original_language': 'en',
#   'original_title': 'Brahms: The Boy II',
#   'overview': 'After a family moves into the Heelshire Mansion, their young son soon makes friends with a life-like doll called Brahms.',
#   'popularity': 15.389,
#   'poster_path': '/swTC1DSZcvdxTOzmAKrtoUUPiDW.jpg',
#   'release_date': '2020-02-20',
#   'title': 'Brahms: The Boy II',
#   'video': False,
#   'vote_average': 5.9,
#   'vote_count': 1241},
#  {'adult': False,
#   'backdrop_path': '/9plj0RR5LJOQQ77ucRZzi88uRzY.jpg',
#   'genre_ids': [99, 18],
#   'id': 656690,
#   'original_language': 'en',
#   'original_title': 'The Social Dilemma',
#   'overview': 'This documentary-drama hybrid explores the dangerous human impact of social networking, with tech experts sounding the alarm on their own creations.',
#   'popularity': 22.814,
#   'poster_path': '/aoIiOTuG2hASVQnZHJ6iciVkQJc.jpg',
#   'release_date': '2020-01-26',
#   'title': 'The Social Dilemma',
#   'video': False,
#   'vote_average': 7.5,
#   'vote_count': 1614},
#  {'adult': False,
#   'backdrop_path': '/3pIqd1hgZ2xqzWEyiYp4blqE9Fi.jpg',
#   'genre_ids': [53, 36, 18],
#   'id': 522241,
#   'original_language': 'en',
#   'original_title': 'The Courier',
#   'overview': 'Cold War spy Greville Wynne and his Russian source try to put an end to the Cuban Missile Crisis.',
#   'popularity': 18.312,
#   'poster_path': '/zFIjKtZrzhmc7HecdFXXjsLR2Ig.jpg',
#   'release_date': '2020-01-24',
#   'title': 'The Courier',
#   'video': False,
#   'vote_average': 7.055,
#   'vote_count': 1166},
#  {'adult': False,
#   'backdrop_path': '/8HbqSozBJxv6UldR9lMUECUlbLI.jpg',
#   'genre_ids': [878, 12, 28],
#   'id': 430155,
#   'original_language': 'ru',
#   'original_title': 'Кома',
#   'overview': 'A young and talented architect comes to his senses after a horrific accident only to find himself in the odd dystopian world. A world that is filled with the memories of all current coma patients. Just like a human memory this world is fragmental, chaotic and unstable. This is COMA: icecaps, rivers and cities can all exist in a space of a single room and laws of physics are no longer laws as they can be bent.',
#   'popularity': 16.979,
#   'poster_path': '/ijJm0RSeKIr67qkHLtSmtigS6ra.jpg',
#   'release_date': '2020-01-01',
#   'title': 'Coma',
#   'video': False,
#   'vote_average': 6.398,
#   'vote_count': 553},
#  {'adult': False,
#   'backdrop_path': '/f6YSikiGgSx2IEHiDAWwTt3uEki.jpg',
#   'genre_ids': [35, 18, 10749],
#   'id': 802119,
#   'original_language': 'en',
#   'original_title': 'All About Sex',
#   'overview': 'Three friends in their mid-20s struggle to navigate their professional and personal lives, colliding head on with the messy, hilarious and dreadful growing pangs of adulthood.',
#   'popularity': 18.526,
#   'poster_path': '/cNTwgukBFEYtYNMGsKxgrCFm1xF.jpg',
#   'release_date': '2020-01-16',
#   'title': 'All About Sex',
#   'video': False,
#   'vote_average': 6.1,
#   'vote_count': 35},
#  {'adult': False,
#   'backdrop_path': '/yy85YPsJEVxCy97A89cAwdsCUXa.jpg',
#   'genre_ids': [18, 10749],
#   'id': 677115,
#   'original_language': 'zh',
#   'original_title': '비뇨기과 여의사들 2',
#   'overview': 'Jin Hee is a female urologist who runs a urology department with few patients. One day, a new nurse, Yeon-hee, comes in and works. However, she throws her her whole body in the treatment of patients with an unusual professional spirit. This fact is quickly rumored and patients flock in. Skilled female doctor Jin Hee also starts hot treatment to save the hospital...',
#   'popularity': 17.243,
#   'poster_path': '/uksxhYz0Xc7c5AIjoU205XXEVk8.jpg',
#   'release_date': '2020-02-20',
#   'title': 'Female Urologists 2',
#   'video': False,
#   'vote_average': 5.6,
#   'vote_count': 10},
#  {'adult': False,
#   'backdrop_path': '/hRgQVdKh65nFiy2l7KhfWo7DHof.jpg',
#   'genre_ids': [10751],
#   'id': 520765,
#   'original_language': 'en',
#   'original_title': 'Go!',
#   'overview': "Jack is a charismatic larrikin who has just discovered the one thing he's really good at — go-kart racing. With the support of his mentor, Patrick, an old race car driver with a secret past, and his best mates Colin and Mandy, Jack must learn to control his recklessness if he is to defeat the best drivers in Australia, including the ruthless champion Dean, and win the National title.",
#   'popularity': 14.149,
#   'poster_path': '/jnOSpITigPAG2SvmoxTSFJy35sv.jpg',
#   'release_date': '2020-01-16',
#   'title': 'Go!',
#   'video': False,
#   'vote_average': 6.8,
#   'vote_count': 321},
#  {'adult': False,
#   'backdrop_path': '/pQdZmXq0vvKP1RYUrDHQkzMlS4x.jpg',
#   'genre_ids': [16, 28, 12, 14],
#   'id': 571265,
#   'original_language': 'ja',
#   'original_title': 'デジモンアドベンチャー LAST EVOLUTION 絆',
#   'overview': 'Tai is now a university student, living alone, working hard at school, and working every day, but with his future still undecided. Meanwhile, Matt and others continue to work on Digimon incidents and activities that help people with their partner Digimon. When an unprecedented phenomenon occurs, the DigiDestined discover that when they grow up, their relationship with their partner Digimon will come closer to an end.',
#   'popularity': 15.135,
#   'poster_path': '/rElHXdBX2ou2ju1Be3QiuOJrplb.jpg',
#   'release_date': '2020-02-21',
#   'title': 'Digimon Adventure: Last Evolution Kizuna',
#   'video': False,
#   'vote_average': 8.137,
#   'vote_count': 242},
#  {'adult': False,
#   'backdrop_path': '/tYm0Yk9k9W0hb9Xy4coOXqoGfNT.jpg',
#   'genre_ids': [27, 53],
#   'id': 492611,
#   'original_language': 'en',
#   'original_title': 'The Turning',
#   'overview': 'A young woman quits her teaching job to become a private tutor and governess for two wealthy young kids, but soon starts to suspect there’s more to their house than meets the eye.',
#   'popularity': 15.117,
#   'poster_path': '/uiMHiHp9eAjJty8rddoUnL9G5fU.jpg',
#   'release_date': '2020-01-23',
#   'title': 'The Turning',
#   'video': False,
#   'vote_average': 5.7,
#   'vote_count': 981},
#  {'adult': False,
#   'backdrop_path': '/q41en2QTJ20ek58gCZIxzJMhQ9w.jpg',
#   'genre_ids': [14, 28, 12],
#   'id': 666750,
#   'original_language': 'en',
#   'original_title': 'Dragonheart: Vengeance',
#   'overview': 'Lukas, a young farmer whose family is killed by savage raiders in the countryside, sets out on an epic quest for revenge, forming an unlikely trio with a majestic dragon and a swashbuckling, sword-fighting mercenary, Darius.',
#   'popularity': 14.071,
#   'poster_path': '/qs6gz6atyQcAvqC6qZaslOjliUG.jpg',
#   'release_date': '2020-02-04',
#   'title': 'Dragonheart: Vengeance',
#   'video': False,
#   'vote_average': 6.812,
#   'vote_count': 316},
#  {'adult': False,
#   'backdrop_path': '/2EOy2YSJbzKvlzKpEEKULVYZGlN.jpg',
#   'genre_ids': [10749, 35],
#   'id': 658760,
#   'original_language': 'de',
#   'original_title': 'Isi & Ossi',
#   'overview': "Isi and Ossi couldn't be any more different: She's a billionaire's daughter from Heidelberg, he's a struggling boxer from the nearby town of Mannheim. But when Isi meets Ossi, the two quickly realize that they can take advantage of one another: She dates the broke boxer to provoke her parents and get them to fund a long-desired chef training in New York. He tries to rip off the rich daughter to finance his first professional boxing match. Their plans soon develop into emotional chaos that challenges everything the two believe to know about money, career and love.",
#   'popularity': 14.715,
#   'poster_path': '/bZ7H0kCwEM6CQ0dyCs2H4RkU130.jpg',
#   'release_date': '2020-02-14',
#   'title': 'Isi & Ossi',
#   'video': False,
#   'vote_average': 6.9,
#   'vote_count': 912},
#  {'adult': False,
#   'backdrop_path': '/jKnZ3CavwSTsBbgSpAhQU8Z9nOy.jpg',
#   'genre_ids': [28, 35, 80, 53],
#   'id': 457335,
#   'original_language': 'en',
#   'original_title': 'Guns Akimbo',
#   'overview': 'An ordinary guy suddenly finds himself forced to fight a gladiator-like battle for a dark website that streams the violence for viewers. In order to survive and rescue his kidnapped ex-girlfriend, he must battle Nix, a heavily armed and much more experienced fighter.',
#   'popularity': 13.429,
#   'poster_path': '/2kNnf7BwRCEm4bcFkdiE0T4U25s.jpg',
#   'release_date': '2020-02-27',
#   'title': 'Guns Akimbo',
#   'video': False,
#   'vote_average': 6.4,
#   'vote_count': 2343},
#  {'adult': False,
#   'backdrop_path': '/4br4B8C0SRIYcKHUgoaOlGo50MU.jpg',
#   'genre_ids': [27],
#   'id': 575088,
#   'original_language': 'ru',
#   'original_title': 'Яга. Кошмар тёмного леса',
#   'overview': 'The young family who moved to a new apartment on the outskirts of the city. The nanny hired by them for the newborn daughter quickly gained confidence. However, the older boy, Egor, talks about the frightening behavior of a woman, but his parents do not believe him. The surveillance cameras installed by the father for comfort only confirm everything is in order. Then one day, Egor, returning home, finds no trace of either the nanny or the little sister, and the parents are in a strange trance and do not even remember that they had a daughter. Then Egor, together with his friends, goes in search, during which it turns out that the nanny is an ancient Slavic demon, popularly known as Baba Yaga.',
#   'popularity': 16.834,
#   'poster_path': '/sQF8UV3LrYtELqcJluckTOl9q4D.jpg',
#   'release_date': '2020-02-27',
#   'title': 'Baba Yaga: Terror of the Dark Forest',
#   'video': False,
#   'vote_average': 6.4,
#   'vote_count': 352},
#  {'adult': False,
#   'backdrop_path': '/ySHlkHDbXztjdjRJ0pZN7FXRnaW.jpg',
#   'genre_ids': [16, 12, 28, 14],
#   'id': 631132,
#   'original_language': 'ja',
#   'original_title': "ゴブリンスレイヤー -GOBLIN'S CROWN-",
#   'overview': 'Goblin Slayer and his party head up to the snowy mountains in the north after receiving that request from the Sword Maiden to find any information on the Noble Fencer that disappeared after leaving to slay some goblins. A small village gets attacked, they encounter a mysterious chapel, and something about how these goblins are acting bothers the Goblin slayer.  In order to save the captured Noble Fencer, the Goblin Slayer and his party head to an ancient fortress covered in snow to face off with a powerful foe and a horde of goblins!',
#   'popularity': 16.793,
#   'poster_path': '/A7SH888eBwbJDU3m48Vk2FK6ahW.jpg',
#   'release_date': '2020-02-01',
#   'title': "Goblin Slayer: Goblin's Crown",
#   'video': False,
#   'vote_average': 7.422,
#   'vote_count': 269},
#  {'adult': False,
#   'backdrop_path': '/bNZB25TQxt0jEVgJOJ09tD2es7k.jpg',
#   'genre_ids': [18, 27],
#   'id': 575774,
#   'original_language': 'en',
#   'original_title': 'His House',
#   'overview': 'After making a harrowing escape from war-torn South Sudan, a young refugee couple struggle to adjust to their new life in a small English town that has an unspeakable evil lurking beneath the surface.',
#   'popularity': 16.288,
#   'poster_path': '/idh2QAy5NwBRN94ScmtWrukvOgJ.jpg',
#   'release_date': '2020-01-27',
#   'title': 'His House',
#   'video': False,
#   'vote_average': 6.4,
#   'vote_count': 1097},
#  {'adult': False,
#   'backdrop_path': '/dUasP5TGFk1dhTgtNhk5uLRPRx6.jpg',
#   'genre_ids': [10752, 36, 18],
#   'id': 592279,
#   'original_language': 'ru',
#   'original_title': 'Калашников',
#   'overview': 'Tank commander Kalashnikov is severely injured in battle in 1941. The accident leaves him incapacitated and unable to return to the front line.\xa0While recovering in the hospital he begins creating the initial sketches of what will become one of the world’s most legendary weapons. A self-taught inventor, Mikhail Kalashnikov, is only 29 when he develops the now iconic assault riffle\xa0— the AK-47.',
#   'popularity': 17.273,
#   'poster_path': '/ApfjrFsGunqLo5MKYGtFMTSTaMq.jpg',
#   'release_date': '2020-02-20',
#   'title': 'Kalashnikov AK-47',
#   'video': False,
#   'vote_average': 7.4,
#   'vote_count': 296},
#  {'adult': False,
#   'backdrop_path': '/wEVSupeNO7EjjCFieEv2zt4oJei.jpg',
#   'genre_ids': [35, 53, 80],
#   'id': 609242,
#   'original_language': 'es',
#   'original_title': 'El robo del siglo',
#   'overview': 'In 2006, a group of thieves performed what is considered one of the most famous and smart bank heists in the history of Argentina. How they robbed the Rio bank is as surprising as what happened afterwards. This is their story.',
#   'popularity': 13.002,
#   'poster_path': '/1zL4VCVin4S8kOXhszMDqfwWPCM.jpg',
#   'release_date': '2020-01-16',
#   'title': 'The Heist of the Century',
#   'video': False,
#   'vote_average': 7.77,
#   'vote_count': 792},
#  {'adult': False,
#   'backdrop_path': '/uehwVV9xuALZ2SXeHGiX4Ay5dR7.jpg',
#   'genre_ids': [878, 16, 28],
#   'id': 618355,
#   'original_language': 'en',
#   'original_title': 'Superman: Red Son',
#   'overview': 'Set in the thick of the Cold War, Red Son introduces us to a Superman who landed in the USSR during the 1950s and grows up to become a Soviet symbol that fights for the preservation of Stalin’s brand of communism.',
#   'popularity': 15.471,
#   'poster_path': '/frSfz7olCSQsp2SmTyu2ciGGQiX.jpg',
#   'release_date': '2020-02-24',
#   'title': 'Superman: Red Son',
#   'video': False,
#   'vote_average': 7.1,
#   'vote_count': 830},
#  {'adult': False,
#   'backdrop_path': '/2sOzZQ1O87z9FTI0zukmWaJaGmH.jpg',
#   'genre_ids': [27, 53, 9648],
#   'id': 678489,
#   'original_language': 'zh',
#   'original_title': '女鬼橋',
#   'overview': 'Four years after five students mysteriously committed suicide after taking part in a courage test on the ghost bridge in Donghu university, a reporter and a cinematographer are back to that place and try to get everything clear.',
#   'popularity': 13.955,
#   'poster_path': '/iUEu2FZLWZlLKoFqifK5o33mBHk.jpg',
#   'release_date': '2020-02-27',
#   'title': 'The Bridge Curse',
#   'video': False,
#   'vote_average': 6.5,
#   'vote_count': 84},
#  {'adult': False,
#   'backdrop_path': '/8SPp11OFAferF7GnK9ATMihIMWp.jpg',
#   'genre_ids': [9648, 53, 80, 18],
#   'id': 571648,
#   'original_language': 'ko',
#   'original_title': '지푸라기라도 잡고 싶은 짐승들',
#   'overview': 'A struggling restaurant owner, caring for his sick mom, finds a bag of cash in a sauna locker, while a customs officer gets into trouble when his girlfriend runs off with money he borrowed from a loan shark.',
#   'popularity': 13.165,
#   'poster_path': '/lO4hjVBxrVtMmupGraIR3c7Jq1Q.jpg',
#   'release_date': '2020-02-19',
#   'title': 'Beasts Clawing at Straws',
#   'video': False,
#   'vote_average': 7.103,
#   'vote_count': 252},
#  {'adult': False,
#   'backdrop_path': '/jDb3VV38z6wOdKbGA9jn1bagnfC.jpg',
#   'genre_ids': [10751, 28, 35],
#   'id': 592834,
#   'original_language': 'en',
#   'original_title': 'My Spy',
#   'overview': 'A hardened CIA operative finds himself at the mercy of a precocious 9-year-old girl, having been sent undercover to surveil her family.',
#   'popularity': 15.653,
#   'poster_path': '/n2C6jRK9PtPIs99RQhKtqGlsnsO.jpg',
#   'release_date': '2020-01-09',
#   'title': 'My Spy',
#   'video': False,
#   'vote_average': 6.9,
#   'vote_count': 1270},
#  {'adult': False,
#   'backdrop_path': '/en1XAePgWqNSXb82luUMmo5u3cF.jpg',
#   'genre_ids': [14, 27, 9648],
#   'id': 542224,
#   'original_language': 'en',
#   'original_title': 'Gretel & Hansel',
#   'overview': 'A long time ago in a distant fairy tale countryside, a young girl leads her little brother into a dark wood in desperate search of food and work, only to stumble upon a nexus of terrifying evil.',
#   'popularity': 14.397,
#   'poster_path': '/mBBBXseq4k4dI63k06XIrsc02j8.jpg',
#   'release_date': '2020-01-30',
#   'title': 'Gretel & Hansel',
#   'video': False,
#   'vote_average': 6.0,
#   'vote_count': 1449},
#  {'adult': False,
#   'backdrop_path': '/ys0erQoixe1sCjCyQmtxlZ16mI7.jpg',
#   'genre_ids': [18, 53, 9648],
#   'id': 651070,
#   'original_language': 'en',
#   'original_title': 'A Fall from Grace',
#   'overview': 'When a law-abiding woman gets indicted for murdering her husband, her lawyer soon realizes that a larger conspiracy may be at work.',
#   'popularity': 13.386,
#   'poster_path': '/h47JJZ015VF4neia33AFwTU37Yb.jpg',
#   'release_date': '2020-01-17',
#   'title': 'A Fall from Grace',
#   'video': False,
#   'vote_average': 7.0,
#   'vote_count': 935},
#  {'adult': False,
#   'backdrop_path': '/ivEOcnP78Xbp8jwd7O5jazfeKwK.jpg',
#   'genre_ids': [28, 53],
#   'id': 466622,
#   'original_language': 'en',
#   'original_title': 'The Rhythm Section',
#   'overview': 'When she discovers the plane crash that claimed the lives of her family was no accident, Stephanie Patrick enters the dark, complex world of international espionage seeking vengeance. With nothing left to lose, Stephanie transforms from victim to assassin and discovers that neither revenge nor the truth are what they appear.',
#   'popularity': 16.133,
#   'poster_path': '/spTr0VYyRtl36Lkk6nCnnbFXhus.jpg',
#   'release_date': '2020-01-31',
#   'title': 'The Rhythm Section',
#   'video': False,
#   'vote_average': 5.5,
#   'vote_count': 608},
#  {'adult': False,
#   'backdrop_path': '/oKqsZr4Jq1Y3fPZ0ufgzUs2ToK2.jpg',
#   'genre_ids': [27, 53],
#   'id': 532870,
#   'original_language': 'en',
#   'original_title': 'Run Sweetheart Run',
#   'overview': 'A woman runs for her life though the streets of Los Angeles after her blind date suddenly turns violent.',
#   'popularity': 12.57,
#   'poster_path': '/bDkdcKOFSUaeQLgX3HuDXmxaq1d.jpg',
#   'release_date': '2020-01-27',
#   'title': 'Run Sweetheart Run',
#   'video': False,
#   'vote_average': 5.7,
#   'vote_count': 194},
#  {'adult': False,
#   'backdrop_path': '/fFJQYhnjKfgweZCbRNOE1E015DF.jpg',
#   'genre_ids': [18],
#   'id': 627463,
#   'original_language': 'en',
#   'original_title': 'The Assistant',
#   'overview': 'A searing look at a day in the life of an assistant to a powerful executive. As Jane follows her daily routine, she grows increasingly aware of the insidious abuse that threatens every aspect of her position.',
#   'popularity': 14.786,
#   'poster_path': '/zJpJkVgezsR7dp6KQwyxtGIAOZv.jpg',
#   'release_date': '2020-01-31',
#   'title': 'The Assistant',
#   'video': False,
#   'vote_average': 6.3,
#   'vote_count': 462},
#  {'adult': False,
#   'backdrop_path': '/oZibPrp183EI5yjKvVFZ1lhA3Pj.jpg',
#   'genre_ids': [18, 10751],
#   'id': 630220,
#   'original_language': 'it',
#   'original_title': '18 regali',
#   'overview': "Elisa is only forty when an incurable disease takes her from her husband and their daughter. Before her heart stops, Elisa finds a way to stay close to her: a gift for every birthday up to her adult age, 18 gifts to try to accompany her child's growth year after year.",
#   'popularity': 16.978,
#   'poster_path': '/lS7lqDT3NF2LcSPdxXNJY9pMxZ6.jpg',
#   'release_date': '2020-01-02',
#   'title': '18 Presents',
#   'video': False,
#   'vote_average': 7.4,
#   'vote_count': 679},
#  {'adult': False,
#   'backdrop_path': '/lkUYS8K3tqOJsYHCKSWIMbG7ptj.jpg',
#   'genre_ids': [27, 53],
#   'id': 571625,
#   'original_language': 'ko',
#   'original_title': '클로젯',
#   'overview': "After moving into a new house, a young girl begins displaying strange and disturbing behavior until, one day, she disappears behind a closet. While the devastated father is left with no clue about his daughter's disappearance, an exorcist shows up to help.",
#   'popularity': 13.216,
#   'poster_path': '/W2tus8EwEagKCCCPqqocHEM9F2.jpg',
#   'release_date': '2020-02-05',
#   'title': 'The Closet',
#   'video': False,
#   'vote_average': 7.3,
#   'vote_count': 186},
#  {'adult': False,
#   'backdrop_path': '/pcIwP8OdcYk1hFyDLHs3Mrrb7PR.jpg',
#   'genre_ids': [28, 14, 53],
#   'id': 489326,
#   'original_language': 'en',
#   'original_title': 'Mortal',
#   'overview': 'A young boy must discover the origins of his extraordinary powers before he is captured by authorities hell-bent on condemning him for an accidental murder.',
#   'popularity': 13.703,
#   'poster_path': '/aVbqhqYtlxwEGihTEhewZAgDOCX.jpg',
#   'release_date': '2020-02-28',
#   'title': 'Mortal',
#   'video': False,
#   'vote_average': 6.5,
#   'vote_count': 469},
#  {'adult': False,
#   'backdrop_path': '/2nnHO8neaPSdFQJF0HdZOLFufiG.jpg',
#   'genre_ids': [18, 35],
#   'id': 690846,
#   'original_language': 'es',
#   'original_title': 'Patricia, Una Pasión Escondida',
#   'overview': 'Patricia is a successful couples therapist. Your marriage is going through a bad time. But when she meets a student, Pablo will transform her own beliefs about sex.',
#   'popularity': 13.534,
#   'poster_path': '/tWVppr1BlawmBWrlOOGIfr0ujH.jpg',
#   'release_date': '2020-01-21',
#   'title': 'Patricia, A Hidden Passion',
#   'video': False,
#   'vote_average': 5.9,
#   'vote_count': 37},
#  {'adult': False,
#   'backdrop_path': '/2hV2clTCW55dwTLCZcOvvidjjrV.jpg',
#   'genre_ids': [27, 18, 9648, 53],
#   'id': 474764,
#   'original_language': 'en',
#   'original_title': 'The Lodge',
#   'overview': "When a father is forced to abruptly depart for work, he leaves his children, Aidan and Mia, at their holiday home in the care of his new girlfriend, Grace. Isolated and alone, a blizzard traps them inside the lodge as terrifying events summon specters from Grace's dark past.",
#   'popularity': 15.165,
#   'poster_path': '/yake2myhbW7c6dKbmwYDy1i40bm.jpg',
#   'release_date': '2020-01-16',
#   'title': 'The Lodge',
#   'video': False,
#   'vote_average': 6.1,
#   'vote_count': 1279},
#  {'adult': False,
#   'backdrop_path': '/dIFmlaFdfsxngMoepdPpwCI3KFo.jpg',
#   'genre_ids': [18, 27],
#   'id': 639798,
#   'original_language': 'es',
#   'original_title': 'Malasaña 32',
#   'overview': 'Malasaña neighborhood, Madrid, Spain, 1976. While political turmoil ravages the streets all over the country, the Olmedo family arrives in the big city and settles into their new apartment. They soon discover that they are not the only ones roaming its corridors.',
#   'popularity': 11.635,
#   'poster_path': '/neCS8vPAtsj9cJDGNaEH76ImSd7.jpg',
#   'release_date': '2020-01-17',
#   'title': '32 Malasana Street',
#   'video': False,
#   'vote_average': 6.4,
#   'vote_count': 657},
#  {'adult': False,
#   'backdrop_path': '/488roF3zG3SYA8kbp69UFor74Da.jpg',
#   'genre_ids': [18, 28, 10752],
#   'id': 442065,
#   'original_language': 'en',
#   'original_title': 'The Last Full Measure',
#   'overview': 'The incredible true story of Vietnam War hero William H. Pitsenbarger, a U.S. Air Force Pararescuemen medic who personally saved over sixty men. Thirty-two years later, Pentagon staffer Scott Huffman investigates a Congressional Medal of Honor request for Pitsenbarger and uncovers a high-level conspiracy behind the decades-long denial of the medal, prompting Huffman to put his own career on the line to seek justice for the fallen airman.',
#   'popularity': 16.34,
#   'poster_path': '/bMG8c80lyEkBXVgyHVqsdQhjgf6.jpg',
#   'release_date': '2020-01-23',
#   'title': 'The Last Full Measure',
#   'video': False,
#   'vote_average': 7.3,
#   'vote_count': 450},
#  {'adult': False,
#   'backdrop_path': '/a8ppJJIQmEJcLSFfhxupc4aT4KW.jpg',
#   'genre_ids': [18, 28, 53],
#   'id': 571785,
#   'original_language': 'ko',
#   'original_title': '사냥의 시간',
#   'overview': 'Four young men want to leave their dystopian world behind and go to a distant paradise to execute a money robbery, a daring act that will have unexpected consequences.',
#   'popularity': 16.085,
#   'poster_path': '/bkuuvDoPkOJpg0ZDzHkUWt8ZG5A.jpg',
#   'release_date': '2020-02-22',
#   'title': 'Time to Hunt',
#   'video': False,
#   'vote_average': 7.198,
#   'vote_count': 323},
#  {'adult': False,
#   'backdrop_path': '/e7k3Gbeq7TjFP22AOzDI7kVwaUE.jpg',
#   'genre_ids': [27],
#   'id': 523371,
#   'original_language': 'en',
#   'original_title': 'Patients of a Saint',
#   'overview': "There's a zombie outbreak after a medical trial in an international detention and medical facility on an isolated island. An ex US Special Forces/bodyguard woman inmate and a guard form a team.",
#   'popularity': 10.566,
#   'poster_path': '/6uSR3687xtyS207S8nYp1voT9mR.jpg',
#   'release_date': '2020-02-28',
#   'title': 'Patients of a Saint',
#   'video': False,
#   'vote_average': 6.4,
#   'vote_count': 120},
#  {'adult': False,
#   'backdrop_path': '/tzNbo6hymKypA57D8nRHY7TpbK0.jpg',
#   'genre_ids': [12, 14],
#   'id': 547066,
#   'original_language': 'da',
#   'original_title': 'Skammerens Datter II : Slangens Gave',
#   'overview': "The Shamer's Daughter, Dina, with the magical power of compelling people to admit their most secret shame, must save her family with her newly found father. But he is a Blackmaster, with the power to make people see and believe things that aren't true, so Dina must deal with having inherited this horrible power, while forging a relationship with a father she fears and mistrusts.",
#   'popularity': 8.845,
#   'poster_path': '/zQXYZW4hTZyBBr8gS1CJ4CdDxAq.jpg',
#   'release_date': '2020-02-28',
#   'title': "The Shamer's Daughter 2: The Serpent Gift",
#   'video': False,
#   'vote_average': 6.6,
#   'vote_count': 69},
#  {'adult': False,
#   'backdrop_path': '/7dCzb1oa7ACYi66VIrE1wqmftAa.jpg',
#   'genre_ids': [28],
#   'id': 660521,
#   'original_language': 'en',
#   'original_title': 'The Mercenary',
#   'overview': 'When a mission in South America goes wrong a mercenary is left for dead, but he is nursed back to health and reborn with a new outlook on life. But his peaceful days are short-lived when mercenaries he used to work with cross his path again and he is forced to revisit and face his own demons.',
#   'popularity': 15.316,
#   'poster_path': '/9dgJiDjsRmlHk6prxXmBbFZOcLH.jpg',
#   'release_date': '2020-01-07',
#   'title': 'The Mercenary',
#   'video': False,
#   'vote_average': 6.1,
#   'vote_count': 27},
#  {'adult': False,
#   'backdrop_path': '/brLBKS5vQfP1vjiupHqa3xg1XQC.jpg',
#   'genre_ids': [14, 12, 35],
#   'id': 520725,
#   'original_language': 'fr',
#   'original_title': 'Le prince oublié',
#   'overview': 'Djibi lives alone with Sofia, his 8-year-old daughter. Every night, he invents a story to put him to sleep. When Sofia falls asleep, these extraordinary stories come to life somewhere in an imaginary world inhabited by knights, pirates and other dragons. In this world that belongs only to them, Sofia is always the princess to save, and the brave Prince is none other than Djibi himself.  But 3 years later, the entry of Sofia to the college will mark the end of her childhood. To the despair of her father, she no longer needs her stories at night. On the one hand, Djibi will have to accept that his daughter will grow up and move away from him. On the other hand, in the World of Stories, the Prince will have to face the most epic of all his adventures. Find your destiny in a world where it no longer has a place.',
#   'popularity': 11.996,
#   'poster_path': '/iFcSfoMu9hQIX4t0CxIkDJKgIES.jpg',
#   'release_date': '2020-02-12',
#   'title': 'The Lost Prince',
#   'video': False,
#   'vote_average': 5.706,
#   'vote_count': 349},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [80, 18, 10749],
#   'id': 673407,
#   'original_language': 'ko',
#   'original_title': '불량탐정: 먹이사슬',
#   'overview': "Jeong-mi, a pickpocket ex-convict, ends up pickpocketing again to repay Dae-sik off of her father's debt. One day, Hae-joo, who is secretly meeting a detective, has been kidnapped and turned into Dae-sik's prey.  The detective then went on a search to find Hae-joo's whereabouts.",
#   'popularity': 15.095,
#   'poster_path': '/wyGNUFVpXSVGTRHSylyPqn3qZcT.jpg',
#   'release_date': '2020-01-22',
#   'title': 'Bad Detective: Food Chain',
#   'video': False,
#   'vote_average': 6.125,
#   'vote_count': 4},
#  {'adult': False,
#   'backdrop_path': '/ztUOsyAdbIRJAlXtzlJOpGA52wy.jpg',
#   'genre_ids': [27, 9648],
#   'id': 635199,
#   'original_language': 'ja',
#   'original_title': '犬鳴村',
#   'overview': 'After her brother goes missing, a young psychologist visits an infamous haunted and cursed location known as ‘Howling Village’ to investigate his disappearance and uncover her family’s dark history.',
#   'popularity': 13.415,
#   'poster_path': '/doM8q4gqgLSFDbajjvJTlng4ZkN.jpg',
#   'release_date': '2020-02-07',
#   'title': 'Howling Village',
#   'video': False,
#   'vote_average': 5.8,
#   'vote_count': 90},
#  {'adult': False,
#   'backdrop_path': '/lKtAyhCU1zE0gqoTfKUXTyeINI2.jpg',
#   'genre_ids': [53, 18, 10770],
#   'id': 673247,
#   'original_language': 'en',
#   'original_title': 'The Neighbor in the Window',
#   'overview': 'A suburban wife who finds herself and the security of her family threatened by another seemingly friendly neighborhood mom.',
#   'popularity': 10.731,
#   'poster_path': '/mRCTWh1xd7BPorZmETnjzQVaj8W.jpg',
#   'release_date': '2020-02-08',
#   'title': 'The Neighbor in the Window',
#   'video': False,
#   'vote_average': 7.337,
#   'vote_count': 43},
#  {'adult': False,
#   'backdrop_path': '/wU6c64E5tOK30QVNDCAiXAaHnPT.jpg',
#   'genre_ids': [18, 53, 27],
#   'id': 586461,
#   'original_language': 'en',
#   'original_title': 'Swallow',
#   'overview': 'Hunter, a newly pregnant housewife, finds herself increasingly compelled to consume dangerous objects. As her husband and his family tighten their control over her life, she must confront the dark secret behind her new obsession.',
#   'popularity': 10.689,
#   'poster_path': '/40Zrwud1EVxNvcjQkotZo7jmr4L.jpg',
#   'release_date': '2020-01-15',
#   'title': 'Swallow',
#   'video': False,
#   'vote_average': 6.623,
#   'vote_count': 762},
#  {'adult': False,
#   'backdrop_path': '/8k0gIcmvrPGyLS3EzHRhONvVE9D.jpg',
#   'genre_ids': [18],
#   'id': 623305,
#   'original_language': 'fr',
#   'original_title': "L'acrobate",
#   'overview': 'In an ever-expanding but nondescript North American city, Christophe, a middle-aged businessman, unexpectedly encounters Micha, a Russian acrobat recovering from an injury, while house-hunting. An instant attraction is quickly consummated and they embark on a torrid affair that helps each of them cope with their respective trials. A provocative, poignant drama about intimacy in an age of anonymity.',
#   'popularity': 8.744,
#   'poster_path': '/e3L6gL2ywVIP1o2R9jaLBSRlP4c.jpg',
#   'release_date': '2020-02-07',
#   'title': 'The Acrobat',
#   'video': False,
#   'vote_average': 6.4,
#   'vote_count': 19},
#  {'adult': False,
#   'backdrop_path': '/6jtAnToTQAfQmwh6K6JiiqB0qoy.jpg',
#   'genre_ids': [27, 14, 28],
#   'id': 662844,
#   'original_language': 'en',
#   'original_title': 'Angels Fallen',
#   'overview': 'After the tragic loss of his wife battling the forces of darkness, Gabriel is persuaded to rejoin his former team of demon hunters traveling from relatively obscurity in America to the deep unknown regions of Europe. He is joined by his estranged best friend Michael who harbors a dark secret, the mystical Hannah whose visions predict the future, and a motley crew of demon slayers. After losing part of his team Gabriel must confront his tragic past and decide who really is friend or foe.',
#   'popularity': 10.545,
#   'poster_path': '/9mVHxdtlmTZUpgps2cvPqVeJEtb.jpg',
#   'release_date': '2020-01-14',
#   'title': 'Angels Fallen',
#   'video': False,
#   'vote_average': 5.733,
#   'vote_count': 88},
#  {'adult': False,
#   'backdrop_path': '/vLI1uQuvk3lUnTWER0bJ9RSRnKM.jpg',
#   'genre_ids': [35, 18],
#   'id': 547012,
#   'original_language': 'en',
#   'original_title': 'Buffaloed',
#   'overview': 'Set in the underworld of debt-collecting, homegrown hustler Peg Dahl will do anything to escape Buffalo, NY.',
#   'popularity': 9.369,
#   'poster_path': '/7ecianrsS9xYzqoAtVIW8tMcbIX.jpg',
#   'release_date': '2020-02-14',
#   'title': 'Buffaloed',
#   'video': False,
#   'vote_average': 6.7,
#   'vote_count': 240},
#  {'adult': False,
#   'backdrop_path': '/dRPCsvwgB1eyoBEtoGqulNhLd5C.jpg',
#   'genre_ids': [16, 35, 10751],
#   'id': 594530,
#   'original_language': 'en',
#   'original_title': 'Lamp Life',
#   'overview': 'Bo Peep explains what happened to herself and her sheep between the events of Toy Story 2 and Toy Story 4.',
#   'popularity': 8.859,
#   'poster_path': '/mJ95RnlammhYb6ZvBbQFLq8Jqnl.jpg',
#   'release_date': '2020-01-31',
#   'title': 'Lamp Life',
#   'video': False,
#   'vote_average': 7.1,
#   'vote_count': 304},
#  {'adult': False,
#   'backdrop_path': '/mTRrGeLphIlj4JM7EauuEYpS3iv.jpg',
#   'genre_ids': [10749, 10770, 35],
#   'id': 647325,
#   'original_language': 'en',
#   'original_title': 'The Thing About Harry',
#   'overview': "Two high school enemies, uber-jock Harry and out-and-proud Sam, are forced to share a car ride to their Missouri hometown for a friend's engagement party on Valentine's Day. Things take a turn when Sam learns Harry has come out.",
#   'popularity': 11.607,
#   'poster_path': '/sdn5NdFMcsub3QUwlovOA9fPJoW.jpg',
#   'release_date': '2020-02-15',
#   'title': 'The Thing About Harry',
#   'video': False,
#   'vote_average': 6.9,
#   'vote_count': 211},
#  {'adult': False,
#   'backdrop_path': '/cH0AXST2dsHcD62qTbS4Cte6Wjb.jpg',
#   'genre_ids': [35],
#   'id': 526019,
#   'original_language': 'en',
#   'original_title': 'Like a Boss',
#   'overview': 'Two female friends with very different ideals decide to start a beauty company together. One is more practical, while the other wants to earn her fortune and live a lavish lifestyle.',
#   'popularity': 11.269,
#   'poster_path': '/yce0CZPWd0GGudksRJi8p4gDj1M.jpg',
#   'release_date': '2020-01-09',
# ...
#   'release_date': '2020-01-17',
#   'title': 'Al Mallu',
#   'video': False,
#   'vote_average': 3.5,
#   'vote_count': 2},
#  {'adult': False,
#   'backdrop_path': '/6lOcR4KEXCwvK4mZl9lc0ejKIDd.jpg',
#   'genre_ids': [14],
#   'id': 671507,
#   'original_language': 'zh',
#   'original_title': '魔盗白骨衣之昆仑之泪',
#   'overview': '',
#   'popularity': 0.637,
#   'poster_path': '/mCNlEvwUxGaJG6G1y8o2c3f1KHV.jpg',
#   'release_date': '2020-02-05',
#   'title': 'Tears of Kunlun',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': '/gLBbY76XevMiQL29DdCbWkdrt4W.jpg',
#   'genre_ids': [99, 10402],
#   'id': 662130,
#   'original_language': 'en',
#   'original_title': "Days of Rage: The Rolling Stones' Road to Altamont",
#   'overview': "The decade that began with peace and love was shattered in the late 1960s amidst riots, assassinations and a war that wouldn't end. The Rolling Stones became the voice of this new era, which came to a horrific end at the Altamont festival.",
#   'popularity': 1.067,
#   'poster_path': '/jwnTkfu9GPS9bUnkG92OZHhuE4D.jpg',
#   'release_date': '2020-01-07',
#   'title': "Days of Rage: The Rolling Stones' Road to Altamont",
#   'video': False,
#   'vote_average': 7.3,
#   'vote_count': 6},
#  {'adult': False,
#   'backdrop_path': '/1XngUnbPaZggwxYgwwZHn3dIs9j.jpg',
#   'genre_ids': [18],
#   'id': 600816,
#   'original_language': 'ak',
#   'original_title': 'Da Yie',
#   'overview': "Young Matilda and Prince are taken on a life-changing trip by a stranger. Kids, gangsters and Ghana's vibrant coast as you've never seen them.",
#   'popularity': 1.196,
#   'poster_path': '/nL36Oxehw6c5vRZtecJq7AjGKx8.jpg',
#   'release_date': '2020-02-09',
#   'title': 'Da Yie',
#   'video': False,
#   'vote_average': 7.2,
#   'vote_count': 13},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [18, 35],
#   'id': 856093,
#   'original_language': 'en',
#   'original_title': 'Pain',
#   'overview': 'Seven year old Sarah idolizes her Dad. Watching his indoor cricket game is one of her favorite pastimes. She wants to be just like him. One afternoon, at what seems to be a routine game, Sarah is cheering Dad on from the sidelines when',
#   'popularity': 1.191,
#   'poster_path': '/bJ4LFRK2Bwz2JN04IvXGPlCQqGW.jpg',
#   'release_date': '2020-01-01',
#   'title': 'Pain',
#   'video': False,
#   'vote_average': 5.385,
#   'vote_count': 13},
#  {'adult': False,
#   'backdrop_path': '/c9bCfHonoypQ9oZkW2mnfQ2XpCa.jpg',
#   'genre_ids': [18],
#   'id': 822522,
#   'original_language': 'en',
#   'original_title': 'Discord',
#   'overview': "In this digitized distant world two clashing character's path crosses by in London town and that's where the discord starts.",
#   'popularity': 0.511,
#   'poster_path': '/ihXaLTgqstoPbDMLuEGRjVhhd5l.jpg',
#   'release_date': '2020-02-15',
#   'title': 'Discord',
#   'video': False,
#   'vote_average': 7.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/btq6temupqO10dM4tGQ6RC94sON.jpg',
#   'genre_ids': [10749, 14],
#   'id': 660649,
#   'original_language': 'zh',
#   'original_title': '聊斋之极道天师',
#   'overview': '',
#   'popularity': 0.511,
#   'poster_path': '/f9glhMxpIA789fjvMOmKxXSJaRH.jpg',
#   'release_date': '2020-01-03',
#   'title': 'Ghost Stories of Extreme Taoist',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99],
#   'id': 663022,
#   'original_language': 'en',
#   'original_title': 'The National Television Awards Celebrate 25 Years',
#   'overview': 'This one-hour special documentary celebrates 25 star-studded years of the National Television Awards, with contributions from stars including Graham Norton and Simon Cowell.',
#   'popularity': 0.51,
#   'poster_path': '/d5UcTneQeN7yUgptfS881AkYI3r.jpg',
#   'release_date': '2020-01-07',
#   'title': 'The National Television Awards Celebrate 25 Years',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': '/tVqr2dWIKrnpaBsUSESQbIRH492.jpg',
#   'genre_ids': [35, 12],
#   'id': 669638,
#   'original_language': 'zh',
#   'original_title': '野王',
#   'overview': "After the bandits murdered his native tribe, young Shankui began to live in the forest on the Tianmu mountain as a savage hermit, who lost his human form. The wild orangutan was Shankui's only friend, until one day a little girl Kong'er came to the woods in search of weapon for revenge. Savage and girl became friends but bandits's boss hired best chivalrous swordswoman to kill The Mountain King.",
#   'popularity': 0.696,
#   'poster_path': '/tzDAAMphTTy53ereXgcbDTpfhQm.jpg',
#   'release_date': '2020-01-29',
#   'title': 'Mountain King',
#   'video': False,
#   'vote_average': 4.5,
#   'vote_count': 2},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99],
#   'id': 656686,
#   'original_language': 'pt',
#   'original_title': 'Apiyemiyekî?',
#   'overview': 'Apiyemiyekî? addresses the genocide of the Waimiri-Atroari people in 1970s, when during the Brazilian dictatorship indigenous lands in the mid-west were invaded for the construction of the national road BR-174 and the installation of a mining company. Illustrations about the period, created by the indigenous population, including children, reveal a traumatic history, referring us to the present day.',
#   'popularity': 1.183,
#   'poster_path': '/1R8xD9UltlT3zbldv9qRo0THGC2.jpg',
#   'release_date': '2020-01-23',
#   'title': 'Apiyemiyekî?',
#   'video': False,
#   'vote_average': 5.0,
#   'vote_count': 8},
#  {'adult': False,
#   'backdrop_path': '/2ZRnpnBb13Lz3KuusFSsZqpCF8p.jpg',
#   'genre_ids': [53, 9648],
#   'id': 760554,
#   'original_language': 'en',
#   'original_title': 'Glamour',
#   'overview': "A down-and-out detective attempts to solve a disturbing case involving the massacre of models. Can he find the killer before it's too late?",
#   'popularity': 0.916,
#   'poster_path': '/qWBgsU027UeGlLj4M9dNGl9YqNJ.jpg',
#   'release_date': '2020-01-02',
#   'title': 'Glamour',
#   'video': False,
#   'vote_average': 6.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/42pjPhnWXqYdNxBt1A7cjHJ3ElS.jpg',
#   'genre_ids': [99],
#   'id': 667888,
#   'original_language': 'en',
#   'original_title': 'Created Equal: Clarence Thomas in His Own Words',
#   'overview': 'Justice Thomas tells his entire life’s story, looking directly at the camera, speaking frankly to the audience. Unscripted and without narration, the documentary takes the viewer through a complex and often painful life, dealing with race, faith, power, jurisprudence, and personal resilience.',
#   'popularity': 1.182,
#   'poster_path': '/j6hVx4OPxosbDUC4QDOIr5964ze.jpg',
#   'release_date': '2020-01-31',
#   'title': 'Created Equal: Clarence Thomas in His Own Words',
#   'video': False,
#   'vote_average': 6.1,
#   'vote_count': 7},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99],
#   'id': 663075,
#   'original_language': 'en',
#   'original_title': 'Free Burma Rangers',
#   'overview': 'Free Burma Rangers is a documentary film exploring the extraordinary 20-year journey of missionaries Dave and Karen Eubank. The film follows Dave, Karen, and their three young children, as they venture into war zones where they are fighting to bring hope.',
#   'popularity': 0.656,
#   'poster_path': '/mgltMVHOaHxfdatLNCqKUdSCT0y.jpg',
#   'release_date': '2020-02-24',
#   'title': 'Free Burma Rangers',
#   'video': False,
#   'vote_average': 7.8,
#   'vote_count': 9},
#  {'adult': False,
#   'backdrop_path': '/laacMWUpcjXpR23j3kFEIaW8Y7R.jpg',
#   'genre_ids': [18, 10749],
#   'id': 654959,
#   'original_language': 'en',
#   'original_title': 'Dirty',
#   'overview': 'Marco cuts class to spend the afternoon with his boyfriend, Graham. Things do not go as planned.',
#   'popularity': 1.179,
#   'poster_path': '/1VA7aXKcaAAotxXsD9hFvWxgywr.jpg',
#   'release_date': '2020-01-24',
#   'title': 'Dirty',
#   'video': False,
#   'vote_average': 4.8,
#   'vote_count': 8},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99, 10402],
#   'id': 730892,
#   'original_language': 'en',
#   'original_title': 'Patch CV: Controlling Voltage',
#   'overview': 'This documentary film focuses on the rapidly growing modular synthesis movement, the diverse artists creating soundscapes of emotionally charged content, and the developers pushing the boundaries of sonic invention with their community driven creations. Capturing this immediate creative vision and personal process from patch to pulse will be the journey we share.',
#   'popularity': 1.177,
#   'poster_path': '/soEqDN0rTdPVLbd4Ea6DpfTAKmX.jpg',
#   'release_date': '2020-01-01',
#   'title': 'Patch CV: Controlling Voltage',
#   'video': False,
#   'vote_average': 6.5,
#   'vote_count': 14},
#  {'adult': False,
#   'backdrop_path': '/uc7VacaKUndH3AekqMeb3WSh6Rp.jpg',
#   'genre_ids': [35],
#   'id': 661397,
#   'original_language': 'ml',
#   'original_title': 'ധമാക്ക',
#   'overview': "Crooked intellect father makes a plan for his son's marriage to a divorced millionaire. Problem begins when son finds out he has erectile dysfunction at his first night",
#   'popularity': 1.095,
#   'poster_path': '/yk3Lb70tZ5NH6mTf90E9e1NQDht.jpg',
#   'release_date': '2020-01-02',
#   'title': 'Dhamaka',
#   'video': False,
#   'vote_average': 2.1,
#   'vote_count': 7},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 1441506,
#   'original_language': 'en',
#   'original_title': '拳霸少年2',
#   'overview': 'chinese film',
#   'popularity': 0.635,
#   'poster_path': '/fh0KBL6ZO0JIqFpfKRcgFdMipgn.jpg',
#   'release_date': '2020-02-22',
#   'title': '拳霸少年2',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 1150981,
#   'original_language': 'en',
#   'original_title': '唐伯虎之醉美人',
#   'overview': 'plot is unknown',
#   'popularity': 0.503,
#   'poster_path': '/tJ55Ly4Xwv2ZWYVo5DntmxRmdFQ.jpg',
#   'release_date': '2020-02-04',
#   'title': 'Tang Bo Hu Zhi Zui Mei Ren',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': '/qR9qoFEoQgbeJGH0xzQrqipXiU4.jpg',
#   'genre_ids': [18, 35],
#   'id': 654980,
#   'original_language': 'en',
#   'original_title': 'Former Cult Member Hears Music for the First Time',
#   'overview': 'After a woman escapes the captivity of her abusive family, a magazine invites her to a journalistic experiment: to hear music for the first time.',
#   'popularity': 1.065,
#   'poster_path': '/d9seO9yEeiJuWwZ8m7dWMnSXfD7.jpg',
#   'release_date': '2020-01-26',
#   'title': 'Former Cult Member Hears Music for the First Time',
#   'video': False,
#   'vote_average': 5.833,
#   'vote_count': 6},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [18, 35, 10751, 10749],
#   'id': 651189,
#   'original_language': 'id',
#   'original_title': 'Akhir Kisah Cinta Si Doel',
#   'overview': 'Torn between reuniting with one family and leaving another behind, Doel must choose between the two women he loves.',
#   'popularity': 1.173,
#   'poster_path': '/u83rPC8nQQ1QtELfAqw3OR1ccLs.jpg',
#   'release_date': '2020-01-23',
#   'title': "The End of Doel's Love Story",
#   'video': False,
#   'vote_average': 6.3,
#   'vote_count': 6},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [10749],
#   'id': 903733,
#   'original_language': 'fr',
#   'original_title': 'Entre-deux',
#   'overview': 'In the high school basketball team, Gaby is indisputable holder and Juliette her eternal substitute, until the day when their rivalry takes them to a new playground.',
#   'popularity': 0.945,
#   'poster_path': '/xfKWQJoGGzixwaKuLkkIkx5y6jk.jpg',
#   'release_date': '2020-02-07',
#   'title': 'Between Two',
#   'video': False,
#   'vote_average': 7.0,
#   'vote_count': 2},
#  {'adult': False,
#   'backdrop_path': '/okvNuPeZNyf2aWYcusUIqhZdfYt.jpg',
#   'genre_ids': [99],
#   'id': 675483,
#   'original_language': 'en',
#   'original_title': 'Inside Kilian Jornet',
#   'overview': 'The behind the scenes film will show Jornet out of his usual environment and follow the athlete’s world tour last year. It will also look at an unusual year in the life of Kilian Jornet, who suffered two injuries and managed to complete some sports projects he had had in mind for a long time, in addition to receiving great news: his future fatherhood.',
#   'popularity': 0.625,
#   'poster_path': '/2OZOwxdYH5l4j5iZSGUSwVfCVuo.jpg',
#   'release_date': '2020-02-14',
#   'title': 'Inside Kilian Jornet',
#   'video': False,
#   'vote_average': 7.9,
#   'vote_count': 8},
#  {'adult': False,
#   'backdrop_path': '/y5hpC4tpwPidPo3zDp6GJyQ92Bp.jpg',
#   'genre_ids': [18],
#   'id': 667635,
#   'original_language': 'bg',
#   'original_title': '18% сиво',
#   'overview': 'When his wife leaves him, struggling Bulgarian photographer Zack sets out on a wild trip from London to Berlin. It is a journey that reveals the truth about his lost love - and ultimately to uncomfortable discoveries about himself.',
#   'popularity': 0.755,
#   'poster_path': '/s2jWSyYc58Dr68plxVFZD14VGr0.jpg',
#   'release_date': '2020-01-24',
#   'title': '18% Grey',
#   'video': False,
#   'vote_average': 7.0,
#   'vote_count': 4},
#  {'adult': False,
#   'backdrop_path': '/OZhrIBTS6533sXB54P1alEh2Gs.jpg',
#   'genre_ids': [35],
#   'id': 761638,
#   'original_language': 'en',
#   'original_title': 'The Ride',
#   'overview': 'Wayne, a 40-year-old rideshare driver and spiritual coach, recently moved back in with his mom. He discovers that the key to giving his life meaning is to help his unsuspecting passengers let go of their negative thoughts—whether they want his help or not.',
#   'popularity': 1.17,
#   'poster_path': '/sccZZfLTh6dvhE5MkiLvaMxTTqd.jpg',
#   'release_date': '2020-01-28',
#   'title': 'The Ride',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': '/qOOzFROkdLBgSoMNQvAcq3xVCU6.jpg',
#   'genre_ids': [10749, 878, 18],
#   'id': 1439595,
#   'original_language': 'en',
#   'original_title': 'I Am Not Okay with This',
#   'overview': 'Angsty Syd navigates high school awkwardness, family drama and an unrequited crush on her best friend while trying to rein in her budding superpowers.',
#   'popularity': 1.168,
#   'poster_path': '/ekcyOuxDOo7dv8rVBaL9YqVrmaz.jpg',
#   'release_date': '2020-02-26',
#   'title': 'I Am Not Okay with This',
#   'video': False,
#   'vote_average': 10.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [18],
#   'id': 854060,
#   'original_language': 'de',
#   'original_title': 'Phoenix',
#   'overview': "Anton is about to lose the two most important women in his life but it takes the story of the king's son to make him face his fate.",
#   'popularity': 0.5,
#   'poster_path': '/Auk4lQyG2lJprXvzCJarUNbsZyk.jpg',
#   'release_date': '2020-01-21',
#   'title': 'Phoenix',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': '/67EXTpZnkYz6HCagjv6j7otc49B.jpg',
#   'genre_ids': [18],
#   'id': 616207,
#   'original_language': 'bg',
#   'original_title': 'Котка в стената',
#   'overview': 'Cat in the Wall tells the true story of how a cat, stuck in a wall, changes the lives of aspirational migrants, benefit fraudsters and gentrified Brexiteers.',
#   'popularity': 1.168,
#   'poster_path': '/bZlGlbbyyClyP2aARxK6RATgWoL.jpg',
#   'release_date': '2020-02-07',
#   'title': 'Cat in the Wall',
#   'video': False,
#   'vote_average': 5.7,
#   'vote_count': 15},
#  {'adult': False,
#   'backdrop_path': '/6nFLvm2YuhsmfjWmB9xRkn1nNp9.jpg',
#   'genre_ids': [10770, 35],
#   'id': 664481,
#   'original_language': 'de',
#   'original_title': 'Viele Kühe und ein schwarzes Schaf',
#   'overview': '',
#   'popularity': 0.724,
#   'poster_path': '/diMw24IPVrsZrp60E5mh7RiUBPf.jpg',
#   'release_date': '2020-01-17',
#   'title': 'Viele Kühe und ein schwarzes Schaf',
#   'video': False,
#   'vote_average': 5.2,
#   'vote_count': 3},
#  {'adult': False,
#   'backdrop_path': '/66a3Djng3h4n0byO1J1pqIfezxl.jpg',
#   'genre_ids': [35],
#   'id': 1341805,
#   'original_language': 'es',
#   'original_title': 'Daniel Sosa: Especial de Reyes Magos',
#   'overview': '',
#   'popularity': 1.134,
#   'poster_path': '/2l8X21dcpzY0yGIxSa8txuUsIzm.jpg',
#   'release_date': '2020-01-05',
#   'title': 'Daniel Sosa: Especial de Reyes Magos',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0},
#  ...]

# %%
str(date_range_search[0])
# Out:
# "{'adult': False, 'backdrop_path': '/stmYfCUGd8Iy6kAMBr6AmWqx8Bq.jpg', 'genre_ids': [28, 878, 35, 10751], 'id': 454626, 'original_language': 'en', 'original_title': 'Sonic the Hedgehog', 'overview': 'Powered with incredible speed, Sonic The Hedgehog embraces his new home on Earth. That is, until Sonic sparks the attention of super-uncool evil genius Dr. Robotnik. Now it’s super-villain vs. super-sonic in an all-out race across the globe to stop Robotnik from using Sonic’s unique power for world domination.', 'popularity': 124.039, 'poster_path': '/aQvJ5WPzZgYVDrxLX4R6cLJCEaQ.jpg', 'release_date': '2020-02-12', 'title': 'Sonic the Hedgehog', 'video': False, 'vote_average': 7.308, 'vote_count': 9798}"

# %%
date_search_results = pd.DataFrame(date_range_search)

# %%
date_search_results
# Out:
#       adult                     backdrop_path             genre_ids       id  \
# 0     False  /stmYfCUGd8Iy6kAMBr6AmWqx8Bq.jpg  [28, 878, 35, 10751]   454626
# 1     False                              None                  [18]  1299314
# 2     False  /eAIHqfS3kXm7kZl4j7ZBfdegyEz.jpg          [53, 28, 80]    38700
# 3     False  /3zBjU7mXlzxJKAStRzlNDZRGT0m.jpg              [28, 80]   495764
# 4     False  /tintsaQ0WLzZsTMkTiqtMB3rfc8.jpg          [28, 80, 35]   522627
# ...     ...                               ...                   ...      ...
# 6149  False                              None              [35, 80]   583751
# 6150  False                              None         [878, 99, 35]  1442991
# 6151  False  /etpHmM761lMJJf3LDnwVBPivHCo.jpg                  [99]  1442612
# 6152  False                              None                    []  1442402
# 6153  False  /axebbILeZI9fFUBkTPFJ2uzIT8M.jpg              [16, 28]  1289041
#
#      original_language                                     original_title  \
# 0                   en                                 Sonic the Hedgehog
# 1                   ko                                       후배부부와 교환섹스 2
# 2                   en                                  Bad Boys for Life
# 3                   en  Birds of Prey (and the Fantabulous Emancipatio...
# 4                   en                                      The Gentlemen
# ...                ...                                                ...
# 6149                fr                                    À coeur battant
# 6150                pt    Seres Humanos Do Passado - Episódio: A Extinção
# 6151                en                           Tibet: Roof of the World
# 6152                en                                            Borders
# 6153                zh                                               武圣关公
#
#                                                overview  popularity  \
# 0     Powered with incredible speed, Sonic The Hedge...     124.039
# 1                                                            79.451
# 2     Marcus and Mike are forced to confront new thr...      62.814
# 3     Harley Quinn joins forces with a singer, an as...      48.401
# 4     American expat Mickey Pearson has built a high...      42.650
# ...                                                 ...         ...
# 6149  Unemployed Julian spends his time caring for h...       0.001
# 6150                                                          0.000
# 6151  Join us as we explore life on the highest moun...       0.600
# 6152  The contemporary Chinese artist Liu Xiaodong t...       0.600
# 6153                                                          0.000
#
#                            poster_path release_date  \
# 0     /aQvJ5WPzZgYVDrxLX4R6cLJCEaQ.jpg   2020-02-12
# 1     /4roZrvGt9cTjWroD8iquIvcBddJ.jpg   2020-02-07
# 2     /y95lQLnuNKdPAzw9F9Ab8kJ80c3.jpg   2020-01-15
# 3     /h4VB6m0RwcicVEZvzftYZyKXs6K.jpg   2020-02-05
# 4     /jtrhTYB7xSrJxR1vusu99nvnZ1g.jpg   2020-01-01
# ...                                ...          ...
# 6149  /3gQI7bdHQ8itXK0djOavOSQpKK6.jpg   2020-01-29
# 6150  /ki55gn5pepHJeqxD7bvCVnAgZnj.jpg   2020-01-07
# 6151  /1IQ5NAi2VERsFqGnhbmm8TXnc7S.jpg   2020-01-01
# 6152  /cz4f0WmeAXUazKPgdZBEKkeKBnV.jpg   2020-01-01
# 6153  /9npvPc2LKeUjvNzgbC2TeVXK6k7.jpg   2020-01-11
#
#                                                   title  video  vote_average  \
# 0                                    Sonic the Hedgehog  False         7.308
# 1                                          후배부부와 교환섹스 2  False         0.000
# 2                                     Bad Boys for Life  False         7.135
# 3     Birds of Prey (and the Fantabulous Emancipatio...  False         6.900
# 4                                         The Gentlemen  False         7.700
# ...                                                 ...    ...           ...
# 6149                                      Beating Heart  False         0.000
# 6150    Seres Humanos Do Passado - Episódio: A Extinção  False         0.000
# 6151                           Tibet: Roof of the World  False         0.000
# 6152                                            Borders  False         0.000
# 6153                                               武圣关公  False         0.000
#
#       vote_count
# 0           9798
# 1              0
# 2           8354
# 3          10351
# 4           5963
# ...          ...
# 6149           0
# 6150           0
# 6151           0
# 6152           0
# 6153           0
#
# [6154 rows x 14 columns]

# %% [markdown]
# ##  Importing and Saving the Movies Dataset (Best Practice)

# %% [markdown]
# 6. __API-Request__ (movie module): Load all available information for the movies with movie id = [__299534, 19995, 140607, 299536, 597, 135397, 420818, 24428, 168259, 99861, 284054, 12445, 181808, 330457, 351286, 109445, 321612, 260513__] into a Pandas DataFrame and __save the dataset in a local json file__.

# %%
list_of_movies = [299534, 19995, 140607, 299536, 597, 135397, 420818, 24428, 168259, 99861, 284054, 12445, 181808, 330457, 351286, 109445, 321612, 260513]

# %% [markdown]
# # +++++++++ See some Hints below +++++++++++++

# %%
json_list = []
for movie in list_of_movies:
    result = get_specific_movie(movie)[1]
    json_list.append(result)

# %%
json_list
# Out:
# [{'adult': False,
#   'backdrop_path': '/7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg',
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'budget': 356000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'}],
#   'homepage': 'https://www.marvel.com/movies/avengers-endgame',
#   'id': 299534,
#   'imdb_id': 'tt4154796',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Avengers: Endgame',
#   'overview': "After the devastating events of Avengers: Infinity War, the universe is in ruins due to the efforts of the Mad Titan, Thanos. With the help of remaining allies, the Avengers must assemble once more in order to undo Thanos' actions and restore order to the universe once and for all, no matter what consequences may be in store.",
#   'popularity': 116.248,
#   'poster_path': '/ulzhLuWrPK07P1YkdWQLZnQh1JL.jpg',
#   'production_companies': [{'id': 420,
#     'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#     'name': 'Marvel Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2019-04-24',
#   'revenue': 2799439100,
#   'runtime': 181,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Japanese', 'iso_639_1': 'ja', 'name': '日本語'},
#    {'english_name': 'Xhosa', 'iso_639_1': 'xh', 'name': ''}],
#   'status': 'Released',
#   'tagline': 'Avenge the fallen.',
#   'title': 'Avengers: Endgame',
#   'video': False,
#   'vote_average': 8.2,
#   'vote_count': 26066},
#  {'adult': False,
#   'backdrop_path': '/vL5LR6WdxWPjLPFRLe133jXWsh5.jpg',
#   'belongs_to_collection': {'id': 87096,
#    'name': 'Avatar Collection',
#    'poster_path': '/3C5brXxnBxfkeKWwA1Fh4xvy4wr.jpg',
#    'backdrop_path': '/gxnvX9kF7RRUQYvB52dMLPgeJkt.jpg'},
#   'budget': 237000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.avatar.com/movies/avatar',
#   'id': 19995,
#   'imdb_id': 'tt0499549',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Avatar',
#   'overview': 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.',
#   'popularity': 131.292,
#   'poster_path': '/kyeqWdyUXW608qlYkRqosgbbJyK.jpg',
#   'production_companies': [{'id': 444,
#     'logo_path': None,
#     'name': 'Dune Entertainment',
#     'origin_country': 'US'},
#    {'id': 574,
#     'logo_path': '/nLNW1TeFUYU0M5U0qmYUzOIwlB6.png',
#     'name': 'Lightstorm Entertainment',
#     'origin_country': 'US'},
#    {'id': 25,
#     'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png',
#     'name': '20th Century Fox',
#     'origin_country': 'US'},
#    {'id': 290,
#     'logo_path': '/jrgCuaQsY9ouP5ILZf4Dq4ZOkIX.png',
#     'name': 'Ingenious Media',
#     'origin_country': 'GB'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'},
#    {'iso_3166_1': 'GB', 'name': 'United Kingdom'}],
#   'release_date': '2009-12-15',
#   'revenue': 2923706026,
#   'runtime': 162,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Spanish', 'iso_639_1': 'es', 'name': 'Español'}],
#   'status': 'Released',
#   'tagline': 'Enter the world of Pandora.',
#   'title': 'Avatar',
#   'video': False,
#   'vote_average': 7.6,
#   'vote_count': 31969},
#  {'adult': False,
#   'backdrop_path': '/k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg',
#   'belongs_to_collection': {'id': 10,
#    'name': 'Star Wars Collection',
#    'poster_path': '/aSrMJYmQX8kpF26LijkCsYhBMvm.jpg',
#    'backdrop_path': '/zZDkgOmFMVYpGAkR9Tkxw0CRnxX.jpg'},
#   'budget': 245000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'http://www.starwars.com/films/star-wars-episode-vii',
#   'id': 140607,
#   'imdb_id': 'tt2488496',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Star Wars: The Force Awakens',
#   'overview': 'Thirty years after defeating the Galactic Empire, Han Solo and his allies face a new threat from the evil Kylo Ren and his army of Stormtroopers.',
#   'popularity': 78.023,
#   'poster_path': '/wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg',
#   'production_companies': [{'id': 1,
#     'logo_path': '/tlVSws0RvvtPBwViUyOFAO0vcQS.png',
#     'name': 'Lucasfilm Ltd.',
#     'origin_country': 'US'},
#    {'id': 11461,
#     'logo_path': '/p9FoEt5shEKRWRKVIlvFaEmRnun.png',
#     'name': 'Bad Robot',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2015-12-15',
#   'revenue': 2068223624,
#   'runtime': 136,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Every generation has a story.',
#   'title': 'Star Wars: The Force Awakens',
#   'video': False,
#   'vote_average': 7.264,
#   'vote_count': 19573},
#  {'adult': False,
#   'backdrop_path': '/mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg',
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'budget': 300000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.marvel.com/movies/avengers-infinity-war',
#   'id': 299536,
#   'imdb_id': 'tt4154756',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Avengers: Infinity War',
#   'overview': 'As the Avengers and their allies have continued to protect the world from threats too large for any one hero to handle, a new danger has emerged from the cosmic shadows: Thanos. A despot of intergalactic infamy, his goal is to collect all six Infinity Stones, artifacts of unimaginable power, and use them to inflict his twisted will on all of reality. Everything the Avengers have fought for has led up to this moment - the fate of Earth and existence itself has never been more uncertain.',
#   'popularity': 247.095,
#   'poster_path': '/7WsyChQLEftFiDOVTGkv3hFpyyt.jpg',
#   'production_companies': [{'id': 420,
#     'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#     'name': 'Marvel Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2018-04-25',
#   'revenue': 2052415039,
#   'runtime': 149,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Xhosa', 'iso_639_1': 'xh', 'name': ''}],
#   'status': 'Released',
#   'tagline': 'Destiny arrives all the same',
#   'title': 'Avengers: Infinity War',
#   'video': False,
#   'vote_average': 8.2,
#   'vote_count': 30231},
#  {'adult': False,
#   'backdrop_path': '/sDH1LkdFOkQmTJaF1sIIniQyFOk.jpg',
#   'belongs_to_collection': None,
#   'budget': 200000000,
#   'genres': [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}],
#   'homepage': 'https://www.paramountmovies.com/movies/titanic',
#   'id': 597,
#   'imdb_id': 'tt0120338',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Titanic',
#   'overview': "101-year-old Rose DeWitt Bukater tells the story of her life aboard the Titanic, 84 years later. A young Rose boards the ship with her mother and fiancé. Meanwhile, Jack Dawson and Fabrizio De Rossi win third-class tickets aboard the ship. Rose tells the whole story from Titanic's departure through to its death—on its first and last voyage—on April 15, 1912.",
#   'popularity': 151.192,
#   'poster_path': '/9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg',
#   'production_companies': [{'id': 4,
#     'logo_path': '/gz66EfNoYPqHTYI4q9UEN4CbHRc.png',
#     'name': 'Paramount Pictures',
#     'origin_country': 'US'},
#    {'id': 25,
#     'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png',
#     'name': '20th Century Fox',
#     'origin_country': 'US'},
#    {'id': 574,
#     'logo_path': '/nLNW1TeFUYU0M5U0qmYUzOIwlB6.png',
#     'name': 'Lightstorm Entertainment',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '1997-11-18',
#   'revenue': 2264162353,
#   'runtime': 194,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'French', 'iso_639_1': 'fr', 'name': 'Français'},
#    {'english_name': 'German', 'iso_639_1': 'de', 'name': 'Deutsch'},
#    {'english_name': 'Swedish', 'iso_639_1': 'sv', 'name': 'svenska'},
#    {'english_name': 'Italian', 'iso_639_1': 'it', 'name': 'Italiano'},
#    {'english_name': 'Russian', 'iso_639_1': 'ru', 'name': 'Pусский'}],
#   'status': 'Released',
#   'tagline': 'Nothing on Earth could come between them.',
#   'title': 'Titanic',
#   'video': False,
#   'vote_average': 7.906,
#   'vote_count': 25742},
#  {'adult': False,
#   'backdrop_path': '/aIGIYJTyOkEVUmEd3z5x6diYsFx.jpg',
#   'belongs_to_collection': {'id': 328,
#    'name': 'Jurassic Park Collection',
#    'poster_path': '/qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg',
#    'backdrop_path': '/njFixYzIxX8jsn6KMSEtAzi4avi.jpg'},
#   'budget': 150000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://www.jurassicworld.com/',
#   'id': 135397,
#   'imdb_id': 'tt0369610',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Jurassic World',
#   'overview': 'Twenty-two years after the events of Jurassic Park, Isla Nublar now features a fully functioning dinosaur theme park, Jurassic World, as originally envisioned by John Hammond.',
#   'popularity': 110.674,
#   'poster_path': '/rhr4y79GpxQF9IsfJItRXVaoGs4.jpg',
#   'production_companies': [{'id': 56,
#     'logo_path': '/cEaxANEisCqeEoRvODv2dO1I0iI.png',
#     'name': 'Amblin Entertainment',
#     'origin_country': 'US'},
#    {'id': 33,
#     'logo_path': '/3wwjVpkZtnog6lSKzWDjvw2Yi00.png',
#     'name': 'Universal Pictures',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2015-06-06',
#   'revenue': 1671537444,
#   'runtime': 124,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'The park is open.',
#   'title': 'Jurassic World',
#   'video': False,
#   'vote_average': 6.693,
#   'vote_count': 20544},
#  {'adult': False,
#   'backdrop_path': '/1TUg5pO1VZ4B0Q1amk3OlXvlpXV.jpg',
#   'belongs_to_collection': {'id': 762512,
#    'name': 'The Lion King (Reboot) Collection',
#    'poster_path': '/dGpIRn4Nqi63JO1RlKxjcPbQSAw.jpg',
#    'backdrop_path': '/jIgM7YNVft0YGeXsqrh3oG5TWLx.jpg'},
#   'budget': 260000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 16, 'name': 'Animation'}],
#   'homepage': 'https://movies.disney.com/the-lion-king-2019',
#   'id': 420818,
#   'imdb_id': 'tt6105098',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'The Lion King',
#   'overview': "Simba idolizes his father, King Mufasa, and takes to heart his own royal destiny. But not everyone in the kingdom celebrates the new cub's arrival. Scar, Mufasa's brother—and former heir to the throne—has plans of his own. The battle for Pride Rock is ravaged with betrayal, tragedy and drama, ultimately resulting in Simba's exile. With help from a curious pair of newfound friends, Simba will have to figure out how to grow up and take back what is rightfully his.",
#   'popularity': 152.319,
#   'poster_path': '/dzBtMocZuJbjLOXvrl4zGYigDzh.jpg',
#   'production_companies': [{'id': 2,
#     'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png',
#     'name': 'Walt Disney Pictures',
#     'origin_country': 'US'},
#    {'id': 7297,
#     'logo_path': '/l29JYQVZbTcjZXoz4CUYFpKRmM3.png',
#     'name': 'Fairview Entertainment',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2019-07-12',
#   'revenue': 1662020819,
#   'runtime': 118,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'The king has returned.',
#   'title': 'The Lion King',
#   'video': False,
#   'vote_average': 7.1,
#   'vote_count': 10237},
#  {'adult': False,
#   'backdrop_path': '/9BBTo63ANSmhC4e6r62OJFuK2GL.jpg',
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'budget': 220000000,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'}],
#   'homepage': 'https://www.marvel.com/movies/the-avengers',
#   'id': 24428,
#   'imdb_id': 'tt0848228',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'The Avengers',
#   'overview': 'When an unexpected enemy emerges and threatens global safety and security, Nick Fury, director of the international peacekeeping agency known as S.H.I.E.L.D., finds himself in need of a team to pull the world back from the brink of disaster. Spanning the globe, a daring recruitment effort begins!',
#   'popularity': 171.67,
#   'poster_path': '/RYMX2wcKCBAr24UyPD7xwmjaTn.jpg',
#   'production_companies': [{'id': 420,
#     'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#     'name': 'Marvel Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2012-04-25',
#   'revenue': 1518815515,
#   'runtime': 143,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Hindi', 'iso_639_1': 'hi', 'name': 'हिन्दी'},
#    {'english_name': 'Russian', 'iso_639_1': 'ru', 'name': 'Pусский'}],
#   'status': 'Released',
#   'tagline': 'Some assembly required.',
#   'title': 'The Avengers',
#   'video': False,
#   'vote_average': 7.7,
#   'vote_count': 31286},
#  {'adult': False,
#   'backdrop_path': '/cHkhb5A4gQRK6zs6Pv7zorHs8Nk.jpg',
#   'belongs_to_collection': {'id': 9485,
#    'name': 'The Fast and the Furious Collection',
#    'poster_path': '/zOCnMPoUxgJK1RFPfN4PcnT16gr.jpg',
#    'backdrop_path': '/z5A5W3WYJc3UVEWljSGwdjDgQ0j.jpg'},
#   'budget': 190000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 53, 'name': 'Thriller'},
#    {'id': 80, 'name': 'Crime'}],
#   'homepage': 'https://www.uphe.com/movies/furious-7',
#   'id': 168259,
#   'imdb_id': 'tt2820852',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Furious 7',
#   'overview': 'Deckard Shaw seeks revenge against Dominic Toretto and his family for his comatose brother.',
#   'popularity': 70.576,
#   'poster_path': '/wurKlC3VKUgcfsn0K51MJYEleS2.jpg',
#   'production_companies': [{'id': 333,
#     'logo_path': '/5xUJfzPZ8jWJUDzYtIeuPO4qPIa.png',
#     'name': 'Original Film',
#     'origin_country': 'US'},
#    {'id': 1225,
#     'logo_path': '/rIxhJMR7oK8b2fMakmTfRLY2TZv.png',
#     'name': 'One Race',
#     'origin_country': 'US'},
#    {'id': 33,
#     'logo_path': '/3wwjVpkZtnog6lSKzWDjvw2Yi00.png',
#     'name': 'Universal Pictures',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2015-04-01',
#   'revenue': 1515400000,
#   'runtime': 137,
#   'spoken_languages': [{'english_name': 'Arabic',
#     'iso_639_1': 'ar',
#     'name': 'العربية'},
#    {'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'},
#    {'english_name': 'Spanish', 'iso_639_1': 'es', 'name': 'Español'},
#    {'english_name': 'Thai', 'iso_639_1': 'th', 'name': 'ภาษาไทย'}],
#   'status': 'Released',
#   'tagline': 'Vengeance hits home.',
#   'title': 'Furious 7',
#   'video': False,
#   'vote_average': 7.229,
#   'vote_count': 10729},
#  {'adult': False,
#   'backdrop_path': '/6YwkGolwdOMNpbTOmLjoehlVWs5.jpg',
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'budget': 365000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.marvel.com/movies/avengers-age-of-ultron',
#   'id': 99861,
#   'imdb_id': 'tt2395427',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Avengers: Age of Ultron',
#   'overview': 'When Tony Stark tries to jumpstart a dormant peacekeeping program, things go awry and Earth’s Mightiest Heroes are put to the ultimate test as the fate of the planet hangs in the balance. As the villainous Ultron emerges, it is up to The Avengers to stop him from enacting his terrible plans, and soon uneasy alliances and unexpected action pave the way for an epic and unique global adventure.',
#   'popularity': 96.707,
#   'poster_path': '/4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg',
#   'production_companies': [{'id': 420,
#     'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#     'name': 'Marvel Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2015-04-22',
#   'revenue': 1405403694,
#   'runtime': 141,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'A new age has come.',
#   'title': 'Avengers: Age of Ultron',
#   'video': False,
#   'vote_average': 7.3,
#   'vote_count': 23242},
#  {'adult': False,
#   'backdrop_path': '/b6ZJZHUdMEFECvGiDpJjlfUWela.jpg',
#   'belongs_to_collection': {'id': 529892,
#    'name': 'Black Panther Collection',
#    'poster_path': '/VtMkk2s92SnDUt8eYyUyYaSJQK.jpg',
#    'backdrop_path': '/nsiBzWsmmerBMuD8TKHpYBTnfhD.jpg'},
#   'budget': 200000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.marvel.com/movies/black-panther',
#   'id': 284054,
#   'imdb_id': 'tt1825683',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Black Panther',
#   'overview': "King T'Challa returns home to the reclusive, technologically advanced African nation of Wakanda to serve as his country's new leader. However, T'Challa soon finds that he is challenged for the throne by factions within his own country as well as without. Using powers reserved to Wakandan kings, T'Challa assumes the Black Panther mantle to join with ex-girlfriend Nakia, the queen-mother, his princess-kid sister, members of the Dora Milaje (the Wakandan 'special forces') and an American secret agent, to prevent Wakanda from being dragged into a world war.",
#   'popularity': 97.588,
#   'poster_path': '/uxzzxijgPIY7slzFvMotPv8wjKA.jpg',
#   'production_companies': [{'id': 420,
#     'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#     'name': 'Marvel Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2018-02-13',
#   'revenue': 1349926083,
#   'runtime': 135,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Korean', 'iso_639_1': 'ko', 'name': '한국어/조선말'},
#    {'english_name': 'Swahili', 'iso_639_1': 'sw', 'name': 'Kiswahili'},
#    {'english_name': 'Xhosa', 'iso_639_1': 'xh', 'name': ''}],
#   'status': 'Released',
#   'tagline': 'Long live the king.',
#   'title': 'Black Panther',
#   'video': False,
#   'vote_average': 7.4,
#   'vote_count': 22404},
#  {'adult': False,
#   'backdrop_path': '/n5A7brJCjejceZmHyujwUTVgQNC.jpg',
#   'belongs_to_collection': {'id': 1241,
#    'name': 'Harry Potter Collection',
#    'poster_path': '/s4hXqX1VyWMc2ctJRuNBDB7YNJ3.jpg',
#    'backdrop_path': '/kmEsQL2vOTA0jnM28fXS45Ky8kX.jpg'},
#   'budget': 125000000,
#   'genres': [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'name': 'Adventure'}],
#   'homepage': 'https://www.warnerbros.com/movies/harry-potter-and-deathly-hallows-part-2/',
#   'id': 12445,
#   'imdb_id': 'tt1201607',
#   'origin_country': ['GB'],
#   'original_language': 'en',
#   'original_title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'overview': "Harry, Ron and Hermione continue their quest to vanquish the evil Voldemort once and for all. Just as things begin to look hopeless for the young wizards, Harry discovers a trio of magical objects that endow him with powers to rival Voldemort's formidable skills.",
#   'popularity': 100.291,
#   'poster_path': '/c54HpQmuwXjHq2C9wmoACjxoom3.jpg',
#   'production_companies': [{'id': 174,
#     'logo_path': '/zhD3hhtKB5qyv7ZeL4uLpNxgMVU.png',
#     'name': 'Warner Bros. Pictures',
#     'origin_country': 'US'},
#    {'id': 437,
#     'logo_path': '/nu20mtwbEIhUNnQ5NXVhHsNknZj.png',
#     'name': 'Heyday Films',
#     'origin_country': 'GB'}],
#   'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   'release_date': '2011-07-12',
#   'revenue': 1341511219,
#   'runtime': 130,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'It all ends.',
#   'title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'video': False,
#   'vote_average': 8.089,
#   'vote_count': 20843},
#  {'adult': False,
#   'backdrop_path': '/5Iw7zQTHVRBOYpA0V6z0yypOPZh.jpg',
#   'belongs_to_collection': {'id': 10,
#    'name': 'Star Wars Collection',
#    'poster_path': '/aSrMJYmQX8kpF26LijkCsYhBMvm.jpg',
#    'backdrop_path': '/zZDkgOmFMVYpGAkR9Tkxw0CRnxX.jpg'},
#   'budget': 200000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.starwars.com/films/star-wars-episode-viii-the-last-jedi',
#   'id': 181808,
#   'imdb_id': 'tt2527336',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Star Wars: The Last Jedi',
#   'overview': 'Rey develops her newly discovered abilities with the guidance of Luke Skywalker, who is unsettled by the strength of her powers. Meanwhile, the Resistance prepares to do battle with the First Order.',
#   'popularity': 96.636,
#   'poster_path': '/ySaaKHOLAQU5HoZqWmzDIj1VvZ1.jpg',
#   'production_companies': [{'id': 1,
#     'logo_path': '/tlVSws0RvvtPBwViUyOFAO0vcQS.png',
#     'name': 'Lucasfilm Ltd.',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2017-12-13',
#   'revenue': 1332698830,
#   'runtime': 152,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Darkness rises...and light to meet it.',
#   'title': 'Star Wars: The Last Jedi',
#   'video': False,
#   'vote_average': 6.783,
#   'vote_count': 15456},
#  {'adult': False,
#   'backdrop_path': '/AoSZyb37ljMAxw0RdeQEBHKtgcc.jpg',
#   'belongs_to_collection': {'id': 386382,
#    'name': 'Frozen Collection',
#    'poster_path': '/13Op41T3cALJedrKqYPrlc3cIbO.jpg',
#    'backdrop_path': '/s3vdRkK7KZFUDC8HEJo2GRKyVhW.jpg'},
#   'budget': 150000000,
#   'genres': [{'id': 10751, 'name': 'Family'},
#    {'id': 16, 'name': 'Animation'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 35, 'name': 'Comedy'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'homepage': 'https://movies.disney.com/frozen-2',
#   'id': 330457,
#   'imdb_id': 'tt4520988',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Frozen II',
#   'overview': 'Elsa, Anna, Kristoff and Olaf head far into the forest to learn the truth about an ancient mystery of their kingdom.',
#   'popularity': 67.678,
#   'poster_path': '/mINJaa34MtknCYl5AjtNJzWj8cD.jpg',
#   'production_companies': [{'id': 2,
#     'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png',
#     'name': 'Walt Disney Pictures',
#     'origin_country': 'US'},
#    {'id': 6125,
#     'logo_path': '/tzsMJBJZINu7GHzrpYzpReWhh66.png',
#     'name': 'Walt Disney Animation Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2019-11-20',
#   'revenue': 1453683476,
#   'runtime': 103,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'The past is not what it seems.',
#   'title': 'Frozen II',
#   'video': False,
#   'vote_average': 7.2,
#   'vote_count': 9830},
#  {'adult': False,
#   'backdrop_path': '/6WA9stUMbIkEPxn3D5SWlA8FIi7.jpg',
#   'belongs_to_collection': {'id': 328,
#    'name': 'Jurassic Park Collection',
#    'poster_path': '/qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg',
#    'backdrop_path': '/njFixYzIxX8jsn6KMSEtAzi4avi.jpg'},
#   'budget': 170000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://www.uphe.com/movies/jurassic-world-fallen-kingdom',
#   'id': 351286,
#   'imdb_id': 'tt4881806',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Jurassic World: Fallen Kingdom',
#   'overview': "Three years after Jurassic World was destroyed, Isla Nublar now sits abandoned. When the island's dormant volcano begins roaring to life, Owen and Claire mount a campaign to rescue the remaining dinosaurs from this extinction-level event.",
#   'popularity': 90.127,
#   'poster_path': '/270MrJNqJovumHXGE6SSt0zwUIF.jpg',
#   'production_companies': [{'id': 56,
#     'logo_path': '/cEaxANEisCqeEoRvODv2dO1I0iI.png',
#     'name': 'Amblin Entertainment',
#     'origin_country': 'US'},
#    {'id': 33,
#     'logo_path': '/3wwjVpkZtnog6lSKzWDjvw2Yi00.png',
#     'name': 'Universal Pictures',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2018-06-06',
#   'revenue': 1310466296,
#   'runtime': 129,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Russian', 'iso_639_1': 'ru', 'name': 'Pусский'}],
#   'status': 'Released',
#   'tagline': 'The park is gone.',
#   'title': 'Jurassic World: Fallen Kingdom',
#   'video': False,
#   'vote_average': 6.54,
#   'vote_count': 11937},
#  {'adult': False,
#   'backdrop_path': '/u2bZhH3nTf0So0UIC1QxAqBvC07.jpg',
#   'belongs_to_collection': {'id': 386382,
#    'name': 'Frozen Collection',
#    'poster_path': '/13Op41T3cALJedrKqYPrlc3cIbO.jpg',
#    'backdrop_path': '/s3vdRkK7KZFUDC8HEJo2GRKyVhW.jpg'},
#   'budget': 150000000,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'homepage': 'http://movies.disney.com/frozen',
#   'id': 109445,
#   'imdb_id': 'tt2294629',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Frozen',
#   'overview': "Young princess Anna of Arendelle dreams about finding true love at her sister Elsa’s coronation. Fate takes her on a dangerous journey in an attempt to end the eternal winter that has fallen over the kingdom. She's accompanied by ice delivery man Kristoff, his reindeer Sven, and snowman Olaf. On an adventure where she will find out what friendship, courage, family, and true love really means.",
#   'popularity': 100.715,
#   'poster_path': '/mmWheq3cFI4tYrZDiATOkCNTqgK.jpg',
#   'production_companies': [{'id': 2,
#     'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png',
#     'name': 'Walt Disney Pictures',
#     'origin_country': 'US'},
#    {'id': 6125,
#     'logo_path': '/tzsMJBJZINu7GHzrpYzpReWhh66.png',
#     'name': 'Walt Disney Animation Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2013-11-20',
#   'revenue': 1274219009,
#   'runtime': 102,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Only the act of true love will thaw a frozen heart.',
#   'title': 'Frozen',
#   'video': False,
#   'vote_average': 7.245,
#   'vote_count': 16724},
#  {'adult': False,
#   'backdrop_path': '/uU1Mt4JWhDvl4vKb3AfxNsorkoM.jpg',
#   'belongs_to_collection': None,
#   'budget': 160000000,
#   'genres': [{'id': 10751, 'name': 'Family'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 10749, 'name': 'Romance'}],
#   'homepage': 'http://movies.disney.com/beauty-and-the-beast-2017',
#   'id': 321612,
#   'imdb_id': 'tt2771200',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Beauty and the Beast',
#   'overview': "A live-action adaptation of Disney's version of the classic tale of a cursed prince and a beautiful young woman who helps him break the spell.",
#   'popularity': 89.15,
#   'poster_path': '/hKegSKIDep2ewJWPUQD7u0KqFIp.jpg',
#   'production_companies': [{'id': 2,
#     'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png',
#     'name': 'Walt Disney Pictures',
#     'origin_country': 'US'},
#    {'id': 10227,
#     'logo_path': '/3YfRy3DBl4abcqkzGx4RVNz12yl.png',
#     'name': 'Mandeville Films',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2017-03-16',
#   'revenue': 1266115964,
#   'runtime': 129,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'French', 'iso_639_1': 'fr', 'name': 'Français'}],
#   'status': 'Released',
#   'tagline': 'Be our guest.',
#   'title': 'Beauty and the Beast',
#   'video': False,
#   'vote_average': 7.0,
#   'vote_count': 15542},
#  {'adult': False,
#   'backdrop_path': '/mabuNsGJgRuCTuGqjFkWe1xdu19.jpg',
#   'belongs_to_collection': {'id': 468222,
#    'name': 'The Incredibles Collection',
#    'poster_path': '/tK26lcRU8o9bHygB2HysgM61wDH.jpg',
#    'backdrop_path': '/6oi6V1O9MJRNnfV8E9JMntmFqBD.jpg'},
#   'budget': 200000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'}],
#   'homepage': 'https://movies.disney.com/incredibles-2',
#   'id': 260513,
#   'imdb_id': 'tt3606756',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Incredibles 2',
#   'overview': 'Elastigirl springs into action to save the day, while Mr. Incredible faces his greatest challenge yet – taking care of the problems of his three children.',
#   'popularity': 55.938,
#   'poster_path': '/9lFKBtaVIhP7E2Pk0IY1CwTKTMZ.jpg',
#   'production_companies': [{'id': 2,
#     'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png',
#     'name': 'Walt Disney Pictures',
#     'origin_country': 'US'},
#    {'id': 3,
#     'logo_path': '/1TjvGVDMYsj6JBxOAkUHpPEwLf7.png',
#     'name': 'Pixar',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2018-06-14',
#   'revenue': 1242805359,
#   'runtime': 118,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': "It's time to get back to being incredible.",
#   'title': 'Incredibles 2',
#   'video': False,
#   'vote_average': 7.456,
#   'vote_count': 12978}]

# %%
hits = pd.DataFrame(json_list)

# %%
hits.to_csv("hits_raw.csv", index=False)

# %%
hits_saved = pd.read_csv("hits_raw.csv")
hits_saved.genres[0]
# Out:
# "[{'id': 12, 'name': 'Adventure'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 28, 'name': 'Action'}]"

# %% [markdown]
# # ++++++++++++++ Hints +++++++++++++++++++++

# %% [markdown]
# __Hints for 1.__ <br>
# To load json files you can use

# %%
with open("movies.json") as f:
    data = json.load(f)

# %% [markdown]
# and

# %%
pd.json_normalize(data)
# Out:
#                                            title      id     revenue  \
# 0                                         Avatar   19995  2923706026
# 1                              Avengers: Endgame  299534  2799439100
# 2                                        Titanic     597  2264162353
# 3                   Star Wars: The Force Awakens  140607  2068223624
# 4                         Avengers: Infinity War  299536  2052415039
# 5                                 Jurassic World  135397  1671537444
# 6                                  The Lion King  420818  1663000000
# 7                                   The Avengers   24428  1518815515
# 8                                      Furious 7  168259  1515400000
# 9                                      Frozen II  330457  1453683476
# 10                       Avengers: Age of Ultron   99861  1405403694
# 11                                 Black Panther  284054  1349926083
# 12  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 13                      Star Wars: The Last Jedi  181808  1332698830
# 14                Jurassic World: Fallen Kingdom  351286  1310466296
# 15                                        Frozen  109445  1274219009
# 16                          Beauty and the Beast  321612  1266115964
# 17                                 Incredibles 2  260513  1242805359
#
#                                                genres  runtime  \
# 0   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      162
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...      181
# 2   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      194
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...      136
# 4   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...      149
# 5   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      124
# 6   [{'id': 16, 'name': 'Animation'}, {'id': 12, '...      118
# 7   [{'id': 878, 'name': 'Science Fiction'}, {'id'...      143
# 8   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...      137
# 9   [{'id': 10751, 'name': 'Family'}, {'id': 16, '...      103
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      141
# 11  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      135
# 12  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...      130
# 13  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...      152
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      129
# 15  [{'id': 16, 'name': 'Animation'}, {'id': 10751...      102
# 16  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...      129
# 17  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      118
#
#     belongs_to_collection.id           belongs_to_collection.name  \
# 0                    87096.0                    Avatar Collection
# 1                    86311.0              The Avengers Collection
# 2                        NaN                                  NaN
# 3                       10.0                 Star Wars Collection
# 4                    86311.0              The Avengers Collection
# 5                      328.0             Jurassic Park Collection
# 6                   762512.0    The Lion King (Reboot) Collection
# 7                    86311.0              The Avengers Collection
# 8                     9485.0  The Fast and the Furious Collection
# 9                   386382.0                    Frozen Collection
# 10                   86311.0              The Avengers Collection
# 11                  529892.0             Black Panther Collection
# 12                    1241.0              Harry Potter Collection
# 13                      10.0                 Star Wars Collection
# 14                     328.0             Jurassic Park Collection
# 15                  386382.0                    Frozen Collection
# 16                       NaN                                  NaN
# 17                  468222.0           The Incredibles Collection
#
#    belongs_to_collection.poster_path belongs_to_collection.backdrop_path  \
# 0   /uO2yU3QiGHvVp0L5e5IatTVRkYk.jpg    /gxnvX9kF7RRUQYvB52dMLPgeJkt.jpg
# 1   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 2                                NaN                                 NaN
# 3   /r8Ph5MYXL04Qzu4QBbq2KjqwtkQ.jpg    /zZDkgOmFMVYpGAkR9Tkxw0CRnxX.jpg
# 4   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 5   /jcUXVtJ6s0NG0EaxllQCAUtqdr0.jpg    /njFixYzIxX8jsn6KMSEtAzi4avi.jpg
# 6   /dGpIRn4Nqi63JO1RlKxjcPbQSAw.jpg    /jIgM7YNVft0YGeXsqrh3oG5TWLx.jpg
# 7   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 8   /rKKSOVv6iU3nULrKQmd9uEx9gez.jpg    /56h4DCt0ogIRI7B71xD5iA5hES1.jpg
# 9   /c3APXwvmWGdt1SKdNJkCjxUAa6j.jpg    /hKV4Xp0T31zpxlpPtETrWDxMSl1.jpg
# 10  /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 11   /VtMkk2s92SnDUt8eYyUyYaSJQK.jpg    /nsiBzWsmmerBMuD8TKHpYBTnfhD.jpg
# 12  /eVPs2Y0LyvTLZn6AP5Z6O2rtiGB.jpg    /xN6SBJVG8jqqKQrgxthn3J2m49S.jpg
# 13  /r8Ph5MYXL04Qzu4QBbq2KjqwtkQ.jpg    /zZDkgOmFMVYpGAkR9Tkxw0CRnxX.jpg
# 14  /jcUXVtJ6s0NG0EaxllQCAUtqdr0.jpg    /njFixYzIxX8jsn6KMSEtAzi4avi.jpg
# 15  /c3APXwvmWGdt1SKdNJkCjxUAa6j.jpg    /hKV4Xp0T31zpxlpPtETrWDxMSl1.jpg
# 16                               NaN                                 NaN
# 17  /xMX1jZyObVeWUxDQmt53X6jzIO4.jpg    /6oi6V1O9MJRNnfV8E9JMntmFqBD.jpg
#
#     belongs_to_collection
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                     NaN
# 10                    NaN
# 11                    NaN
# 12                    NaN
# 13                    NaN
# 14                    NaN
# 15                    NaN
# 16                    NaN
# 17                    NaN

# %% [markdown]
# the json files have the following orientation (important when using pd.read_json()):
# - blockbusters.json -> record
# - blockbusters2.json -> column
# - blockbusters3.json -> split

# %% [markdown]
# __Hints for 4., 5., 6.__<br>
# Make API GET-requests with the library requests (import requests):

# %%
# data = requests.get(url).json()

# %% [markdown]
# __Hints for 4. and 6.,__ <br> url structure for movie module:

# %% [markdown]
# "https://api.themoviedb.org/3/movie/insert_movie_id?api_key=insert_api_key" (replace "insert_movie_id" with movie id and "insert_api_key" with your personal api-key)

# %% [markdown]
# __Hints for 5.__<br>
# url structure for discover module:

# %% [markdown]
# "https://api.themoviedb.org/3/discover/movie?api_key=insert_api_key&query1&query2..." (replace "insert_api_key" with your personal api-key and add appropriate queries)
